# %%
import warnings

warnings.filterwarnings("ignore")
import os

if "jbook" in os.getcwd():
    os.chdir(os.path.abspath(os.path.join("../..")))

# %% [markdown]
# # Data Quality Assessment
# By identifying and rectifying data quality issues early, we can avoid potential pitfalls that might compromise the integrity and accuracy of downstream modeling efforts. In this stage, we employ a series of tasks to identify and address any noise or irregularities within the dataset.
#
# 2. **Non-English Text**: We check for and address non-English text in reviews and app names, as they may not be relevant to our analysis or could require special handling.
# 3. **Inappropriate Content**: URLs, phone numbers, email addresses, and other personally identifiable information are considered as spam, and will be removed from the dataset or masked.
# 4. **Profanity**: We detect and handle profane content to ensure that our dataset adheres to appropriate usage standards, especially if it's intended for public or sensitive applications.
# 5. **Excessive Special Characters**: Special characters can disrupt text analysis and need to be managed, either by cleaning or encoding them appropriately.
# 6. **Emojis**: Emojis can carry significant meaning in certain contexts but might also introduce noise. We identify and decide on their treatment—whether to retain, remove, or translate them into textual representations.
# 7. **Invalid Dates**: We verify that date values fall within expected ranges and formats, correcting or flagging anomalies for further review.
# 8. **Invalid Ratings**: Ratings that fall outside the expected scale (e.g., 1 to 5) are identified and corrected or flagged.
# 9. **Duplicate Rows**: We identify and remove duplicate entries to ensure that each observation is unique, preventing skewed analyses and inflated metrics.
# 10. **Null Values**: We detect and handle missing data appropriately, which could involve imputation, deletion, or flagging incomplete records for further investigation.
#
#
# By conducting these data quality checks, we ensure that our dataset is clean, reliable, and ready for detailed analysis. This foundational step sets the stage for accurate insights and robust conclusions in the subsequent phases of our data processing pipeline.

# %%
import fasttext

from discover.analysis.dqa import DataQualityAnalysis
from discover.container import DiscoverContainer
from discover.infra.config.flow import FlowConfigReader
from discover.flow.data_prep.dqa.stage import DQAStage
from discover.infra.service.cache.cache import DiscoverCache

fasttext.FastText.eprint = lambda x: None

# %% [markdown]
# ## Parameters

# %%
RESET_CACHE = False

# %% [markdown]
# ## Dependency Container

# %%
container = DiscoverContainer()
container.init_resources()
container.wire(
    modules=[
        "discover.flow.data_prep.stage",
        "discover.flow.data_prep.dqa",
        "discover.analysis.base",
    ],
)

# %% [markdown]
# ## Cache Management
# Changes to pipelines may necessitate resetting the cache. Here's the place where that happens.

# %%
if RESET_CACHE:
    cache = DiscoverCache()
    cache.reset()
# Out:
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %% [markdown]
# ## Data Quality Assessment Pipeline
# The data quality assessment process conducts the 9 data quality checks, marking the observations that require attention.

# %%
# Obtain the configuration
reader = FlowConfigReader()
config = reader.get_config("phases", namespace=False)
stage_config = config["dataprep"]["stages"][2]

# Build and run Data Ingestion Stage
stage = DQAStage.build(stage_config=stage_config, force=True)
asset_id = stage.run()
# Out:
# [10/20/2024 01:12:32 AM] [INFO] [discover.infra.persistence.repo.dataset.DatasetRepo] [_remove_dataset_file_by_filepath] : Removed dataset file at workspace/dev/dataset/01_dataprep/appvocai_discover-01_dataprep-02_dqa-review-dataset.parquet from repository.
# [10/20/2024 01:12:32 AM] [INFO] [discover.infra.persistence.repo.dataset.DatasetRepo] [remove] : Removed dataset dataset-dataprep-dqa-review from the repository.
# # ============================================================================ #
# #                        Data Quality Assessment Stage                         #
# # ============================================================================ #
#
# Starting Data Quality Assessment Stage Sun, 20 Oct 2024 01:12:32
#
# 	Starting EntropyTask Sun, 20 Oct 2024 01:12:33
# 	EntropyTask detected 193 anomalies in the dqa_entropy column, 0.33% of 59021 records.
# 	Completed EntropyTask Sun, 20 Oct 2024 01:12:33. Runtime: 0.95 seconds
#
# 	Starting DetectDuplicateTask Sun, 20 Oct 2024 01:12:33
# 	DetectDuplicateTask detected 0 anomalies in the dqa_duplicate_rows column, 0.0% of 59021 records.
# 	Completed DetectDuplicateTask Sun, 20 Oct 2024 01:12:34. Runtime: 0.16 seconds
#
# 	Starting DetectDuplicateTask Sun, 20 Oct 2024 01:12:34
# 	DetectDuplicateTask detected 0 anomalies in the dqa_duplicate_id column, 0.0% of 59021 records.
# 	Completed DetectDuplicateTask Sun, 20 Oct 2024 01:12:34. Runtime: 0.01 seconds
#
# 	Starting DetectDuplicateTask Sun, 20 Oct 2024 01:12:34
# 	DetectDuplicateTask detected 3282 anomalies in the dqa_duplicate_review column, 5.56% of 59021 records.
# 	Completed DetectDuplicateTask Sun, 20 Oct 2024 01:12:34. Runtime: 0.04 seconds
#
# 	Starting DetectNullValuesTask Sun, 20 Oct 2024 01:12:34
# 	DetectNullValuesTask detected 0 anomalies in the dqa_has_null column, 0.0% of 59021 records.
# 	Completed DetectNullValuesTask Sun, 20 Oct 2024 01:12:34. Runtime: 0.02 seconds
#
# 	Starting DetectInvalidRatingsTask Sun, 20 Oct 2024 01:12:34
# 	DetectInvalidRatingsTask detected 0 anomalies in the dqa_invalid_rating column, 0.0% of 59021 records.
# 	Completed DetectInvalidRatingsTask Sun, 20 Oct 2024 01:12:34. Runtime: 0.0 seconds
#
# 	Starting DetectNonEnglishTask Sun, 20 Oct 2024 01:12:34
# 	DetectNonEnglishTask detected 2276 anomalies in the dqa_non_english_review column, 3.86% of 59021 records.
# 	Completed DetectNonEnglishTask Sun, 20 Oct 2024 01:12:57. Runtime: 23.55 seconds
#
# 	Starting DetectNonEnglishTask Sun, 20 Oct 2024 01:12:57
# 	DetectNonEnglishTask detected 1402 anomalies in the dqa_non_english_app_name column, 2.38% of 59021 records.
# 	Completed DetectNonEnglishTask Sun, 20 Oct 2024 01:13:12. Runtime: 15.0 seconds
#
# 	Starting DetectEmojiTask Sun, 20 Oct 2024 01:13:12
# 	DetectEmojiTask detected 3490 anomalies in the dqa_has_emoji column, 5.91% of 59021 records.
# 	Completed DetectEmojiTask Sun, 20 Oct 2024 01:13:13. Runtime: 0.55 seconds
#
# 	Starting DetectSpecialCharacterTask Sun, 20 Oct 2024 01:13:13
# 	DetectSpecialCharacterTask detected 809 anomalies in the dqa_excessive_special_chars column, 1.37% of 59021 records.
# 	Completed DetectSpecialCharacterTask Sun, 20 Oct 2024 01:13:13. Runtime: 0.44 seconds
#
# 	Starting DetectInvalidDatesTask Sun, 20 Oct 2024 01:13:13
# 	DetectInvalidDatesTask detected 0 anomalies in the dqa_invalid_date column, 0.0% of 59021 records.
# 	Completed DetectInvalidDatesTask Sun, 20 Oct 2024 01:13:14. Runtime: 0.51 seconds
#
# 	Starting DetectProfanityTask Sun, 20 Oct 2024 01:13:14
# 	Completed DetectProfanityTask Sun, 20 Oct 2024 01:13:14. Runtime: 0.04 seconds
#
# 	Starting DetectEmailTask Sun, 20 Oct 2024 01:13:14
# 	DetectEmailTask detected 0 anomalies in the dqa_contains_email column, 0.0% of 59021 records.
# 	Completed DetectEmailTask Sun, 20 Oct 2024 01:13:14. Runtime: 0.44 seconds
#
# 	Starting DetectURLTask Sun, 20 Oct 2024 01:13:14
# 	DetectURLTask detected 0 anomalies in the dqa_contains_url column, 0.0% of 59021 records.
# 	Completed DetectURLTask Sun, 20 Oct 2024 01:13:15. Runtime: 0.42 seconds
#
# 	Starting DetectPhoneNumberTask Sun, 20 Oct 2024 01:13:15
# 	DetectPhoneNumberTask detected 26 anomalies in the dqa_contains_phone_number column, 0.04% of 59021 records.
# 	Completed DetectPhoneNumberTask Sun, 20 Oct 2024 01:13:15. Runtime: 0.48 seconds
#
# 	Starting DetectSpellingErrorsTask Sun, 20 Oct 2024 01:13:15
# 11
# 1
# False1False1
# 1
#
# 0
# False
# 10
# 1
# False1
# False
# TrueFalse
# 1
#
# 0
# True
#
# 1False
# False
#
#
# False200
#
#
# TrueFalse0
#
#
#
# False00
#
#
# False0
# TrueTrue
#
# 00
# True
#
#
# 1TrueTrue
#
# 1
# 0True
# 0
#
# TrueTrue
# 0
#
# False
# 0
# 1
# False
# 1True
# True0
#
# 0
# True
#
# 0
# True
# False
#
# 1False01
#
# TrueTrue
# 0
#
# True
#
# 0
# 0
#
# False0FalseTrue
#
# 1True0
#
#
#
#
# True0
#
# True
# 1True00
#
# FalseTrue
# 0
#
#
#
# 0True
#
# 0
# False0TrueTrue
#
# 1
# 1
# True
#
#
# True
# 0True
#
# 11True00
#
# False
# False0
#
#
#
#
# True
# 10
#
# False0TrueTrue
#
# 0False
# True11
#
#
#
# 0False
#
# True
#
#
# True00
#
# 0True
# 21FalseFalse
#
#
# 0True
#
# 0
#
#
#
# True0True
# True
#
# FalseFalse102
#
#
# True
# 0
# True
#
#
#
# 01True
#
# 00
# FalseFalse1True
#
#
# 0True
#
# 0
#
#
#
# 0TrueTrueFalse
# True
# False
# 1
# 10
#
#
# True0True
#
#
#
# True0
#
#
# 01
# 1FalseFalse0
# True
# True0
#
#
#
#
#
# 0
#
# True
# TrueFalse0
# 0TrueFalse001
# True
#
#
#
# True
#
#
#
#
# 1
# 00TrueTrue
# 0True1TrueFalse
# 0
#
#
#
# 0
#
#
#
#
# False
# TrueTrue0
# 0TrueFalse1
# True
#
#
# True1
# 2
#
#
#
# 10True0
#
# 0
# 0FalseTrue
#
# 1
#
# 0False
#
# False
#
# FalseTrue
# True0
#
# True
# 1True0
#
# False
#
# True0
# 0
#
#
# 0
# 00True
#
#
# False0True1
#
# 1
#
# 0TrueTrue
#
#
#
# TrueTrue
# True0
#
#
# 00TrueFalse
#
# False
# True
# 0
# 1
#
#
# 00
# 0True
#
# True
# 0True0
#
#
# 0
# True0
# False
#
#
# TrueTrue
# True
# 0
# 0
# 0True
# True
#
# True
# 0
# True
# 0
# 0
# 1
# 0True
# True
#
# True0
# 0
# 0
#
# True
# 0True
#
# True
#
# FalseTrue0
# 0
#
# 1TrueTrue
#
#
# True
# 0
# True0
#
#
# 0True
# 10
# True
#
# False
# 10
# 0
#
# True0
# True
# True
#
# 0
# TrueFalse
#
# 0
#
# 0FalseTrue
#
# 0
# TrueTrue
# 1
# 0
#
# True0
#
#
# True
# True0
# 0
# True
# 002
# False
#
# True
# 0
# True
#
#
#
# 00True
# True
#
# 0TrueFalseTrue
#
#
# 21
# True
# 1
#
#
# TrueTrue0
#
# 0
# True
# 010
#
#
# FalseFalse
#
# 0False
#
#
# 00True
#
# True
# 0
# TrueFalseTrue
#
#
# 2
# 1True
#
# 1
#
# TrueTrue00
#
# True
# 0
# 10
#
#
# False
# False
# False
#
#
# 100True
# True
#
# False1TrueTrue
#
#
#
# 0
# 0
# 0
#
#
# TrueFalseTrue0
# 1
# 0
# False00
#
#
#
# True
# True
# True
#
#
# 001TrueFalse
#
# True
# 0TrueTrue
#
#
#
# 0
# 1
# 0
#
#
# TrueTrue
# False00
#
# 10True0
#
#
# True
#
# FalseTrue
#
#
#
# 00
#
# TrueTrue
# False1TrueTrue0
#
#
# 0
#
# 01
#
#
#
# TrueTrue00
# 1
#
# False00True
#
#
#
# TrueTrue
# False
#
#
#
# 0True1True
#
# False
# TrueTrue
# 2
#
#
# 00
# 20
#
# True
# 0False0
#
# 0
#
# 00
# False
#
#
# TrueTrue
# TrueFalse
#
# 0
# True0True
# True
#
#
# TrueTrue
# 0
#
#
# 00
# 10
#
# True
# 0True0
#
# 1
#
# 00
#
# True
#
# TrueTrue
# FalseTrue
#
#
# 0TrueTrue1
# False
#
#
# TrueTrue
# 0
#
#
# 0
# 001
#
#
# True11False
# 0
#
# 0
# 0True
#
#
#
# True
# TrueTrueFalse
#
#
# 0FalseFalse
# 2True
#
#
# TrueTrue
# 0
#
#
# 0
# 011
#
#
# True10False
# 0
#
#
# 0True0
#
#
# True
#
# TrueFalseFalse
#
#
# 1FalseTrue0
# True
#
#
# TrueTrue0
#
#
#
#
# 100
#
#
# False1True00
# 0
#
# True01
#
#
#
#
# False
# True
# True
# 0
# TrueFalse0True
#
# True0
# True
# False
#
#
#
# 0
#
# 0True
# 0
# 02True
# 00True
#
# 0
# 1
#
#
# True
#
# True
# 0True
#
# FalseTrue0
# TrueTrue0
#
# True
#
# False
#
#
#
#
# 1True0
# 0
# 0True0True01
#
# 1
# 0
#
#
#
#
#
#
# False0
# TrueTrue
# True0True0TrueFalse
#
# False
#
# True
#
#
#
#
#
# 0
# True00
# True00True01
#
# 0
#
# 1
#
#
#
#
#
# True
# 1True
# 0TrueTrueTrueFalseTrue1
# True
#
# False
#
#
#
#
#
# False
# 0
# 0
# 0True0000False
#
#
# 01
#
#
#
#
#
#
# 0TrueTrue
#
# True0TrueTrueTrueTrue0
#
# False
# True
#
#
#
#
#
#
# True00
#
# True010True01
#
#
# 00
#
#
#
#
#
#
# TrueTrue
#
# 0TrueFalseTrue01True
# False
# TrueTrue
#
#
#
#
#
#
# 0
#
#
# True100FalseTrue01
# 00
# 0
#
#
#
#
#
#
# True
#
# False
# 0TrueTrue00TrueFalse
# TrueTrue
# True
#
#
#
#
#
#
# 0
#
# 1True
# 0TrueTrue0
# 0
# 1
# 0
# 2
#
# 1
# TrueFalse
#
# 0
# True0
#
# 0True
#
# True
# False
# True
# FalseFalse
#
#
# 0True
# 1
# True
# 2
# True00
#
# 0
# 0
# 0
#
#
# 2True
# 0
# False
# 1
# False0True
#
# True
# True
# True
# True
#
#
# False
# True0
# 0
# FalseTrue
# 00
# 0
#
# 0
# 0
# 0
#
#
# 1True
# 0
# True
# 0
# 0TrueTrue
#
# True
#
# TrueTrue
# True
#
#
# False2
# True
# 1
# True
# True00
#
# 0
#
# 0
# 2
# 1
# 0
# False
# False
# 1
# 00
# True
# True
# True
# True
# False
#
# False
# True
#
# 0
# FalseTrue
# True1
# 00
#
# 0
# 0
#
# 0
#
# 1
# 0True
# 0
# 00False
#
# TrueTrue
#
# True
# True
#
# TrueFalse
#
# 0
# True
# True
# TrueTrue0
# 0
# 0
# 1
#
#
# 0
#
#
# 00
# True0
# 000
# TrueTrue
#
#
# True
# False
#
#
# True
#
# TrueTrue
# 0True
# TrueTrueTrue
# 00
#
#
#
# 11
#
#
#
#
# 100True0
#
# 002TrueTrue
#
#
#
#
# FalseFalse
#
#
#
#
# FalseTrueTrue1True
# True
# TrueFalse0
# 1
#
#
#
# 1
#
# 0
#
# 00
# False000
#
# 0True0
# False
#
#
#
#
# True
#
# False
# True
# True0TrueTrueTrue
# True1
# True
# 1
#
#
# 0
#
#
#
#
# 1
# 000True
# 00False10
#
#
# False
#
# True
#
#
#
#
# FalseTrue
# TrueTrue0
# TrueTrue0FalseTrue
#
# 0
#
#
# 0
#
#
#
#
# 00
# 00True
# True11
# 0True
#
#
#
# True1
#
#
#
# True
# TrueTrueTrue0
#
# 0FalseFalseTrue
#
# 0
#
#
# False1
#
#
#
# 0
# 00True0
#
# 0True00True
#
#
#
#
# 0False
#
#
#
#
# TrueTrueTrueTrue0
# True
# TrueTrue01
#
#
#
#
#
# 0
# True
#
#
# 00True00
# 1
# 10TrueFalse
#
#
#
#
# True
# 0
#
#
#
# TrueTrue0TrueTrue
# False
# FalseTrue01
#
#
#
# 0
#
# True
#
#
#
# True00
# 021
# 11TrueFalse
#
#
# True
#
#
#
# 0
#
# 0
# True
# TrueTrueFalseFalseFalse
# False0
#
# 12
#
#
#
#
# True
#
# True0
#
# 01010
# True
# 1
# FalseFalse
#
#
#
#
# 0
# 0
# True
#
# TrueFalseTrueFalse
# True0
# False
# 00
#
#
#
# True
#
# True
# 0
#
# 0000
# 0True0
#
# TrueTrue
#
#
#
# 0
#
#
# 0True
#
# TrueTrueTrue
# TrueTrue0True
# 0
# 0
#
#
# True
#
#
#
# True
# 0
# 000
# 0True1
# True
# True
#
# 20
#
#
#
# 0
# True
# TrueTrue
#
# TrueTrue0False
# 0
# 0
# True
# False
#
#
#
# True
# 0
# 1
# 1
# 1True00
# True
# True
#
# 0
# 1
#
#
#
# 0True
# False
# FalseFalse
# 0TrueTrue
# 0
# 0
# True
#
# False
#
# True
#
#
# 00
# 00
# True0
# 0True
#
# True0
#
#
# 0
# 0
#
# TrueTrue
#
# TrueTrue
# 0
# TrueTrue0
#
# 0True
#
# True
#
# True
#
# 00
#
# 10
# True1
# 0True
# True
# 0
#
# 0
#
# 0
#
# True
# True
# False
# True0False
# True0
#
# 1True
# True
#
#
# True
#
# 00
#
#
# 11True0
#
# True1False0
# 1
#
#
#
# True
# 1
#
#
# True
# FalseFalse0True
# 0
# 0FalseTrueFalse
#
#
#
#
#
# 0False
#
#
# 0
# 11True0True
#
# True00
#
# 1
#
#
#
# True0
#
#
# True
# FalseFalseTrue00
#
# 0TrueTrue
# False
#
#
#
#
# True
#
#
#
# 1210TrueTrue
# True0
# 00
#
# 2
#
#
# 0
#
#
#
# False
# FalseFalseTrue00
# 0TrueTrueTrue
# False
#
#
#
#
# True
#
#
#
#
# 110TrueTrue
# 01True000
#
#
#
#
# 0
#
#
#
#
#
# FalseFalseTrue0
# True1False0TrueTrueTrue
#
#
#
# True
#
#
#
#
#
#
# 100True
# False00True110
#
#
#
#
# 1
#
#
#
#
#
# FalseTrueTrue1
# 1TrueTrue0FalseFalseTrue
#
#
#
# False
#
#
#
#
#
#
# 000False
# False00True100
#
#
#
#
# 2
#
#
#
#
#
# TrueTrueTrue10
# True0TrueFalseTrueTrue
#
#
#
#
# False
#
#
#
#
#
# 001TrueFalse
# 00True000
#
#
#
#
# 0
#
#
#
#
#
# TrueTrueFalse00
# True0TrueTrueTrueTrue
#
#
#
#
# True
#
#
#
#
#
# 001TrueTrue0
# 0True000
#
#
#
#
# 0
#
#
#
#
#
# TrueTrueFalse00
# TrueTrueTrueTrue1True
#
#
#
#
# True
#
#
#
#
#
# 001TrueTrue
# 00000False
#
#
#
#
# 0
#
#
#
#
#
# TrueTrue0False0TrueTrue
# TrueTrueTrue1
#
#
#
#
#
#
# True
#
#
#
# 0True0True100
# 002False
#
#
#
#
#
#
# 1
#
#
#
# True0True1FalseTrueTrue
# TrueTrueFalse0
#
#
#
#
#
#
# False
#
# 1
#
# True0False00
# 0101True
#
#
#
#
#
# 0
#
#
#
#
# TrueFalse10TrueTrue
# TrueFalseTrueFalse
#
# 1
#
#
#
# True
#
#
#
# 01
# TrueFalse01
# 0010
#
# False
#
#
#
#
# 0
#
#
# TrueFalse
# TrueFalse01True
# TrueFalse
# True
# 1
#
#
#
#
# True
#
#
# 000
# True00False
# 020
#
# False
#
#
#
#
# 0
#
#
# TrueTrueTrue0
# TrueTrue
# FalseTrueTrue1
#
#
#
# 0
#
# True
#
#
#
# 000True
# 001
#
# 1False
#
#
# True
# 0
#
#
# True1TrueTrue0
#
# FalseTrueTrue
# False
#
#
#
#
# 1
#
# 0
# True0
# False0True0
# 1
# 10
#
#
# 0
#
#
#
# FalseTrue
#
# 00True
# TrueTrueFalse1
#
# FalseTrue
#
#
# True
#
#
#
# 0
# 1
# True0True
# 000False1
#
# 0
#
#
# 0
#
#
#
# True
#
# False2True1TrueTrue
# 1True
# FalseTrue
#
#
#
#
#
# True
#
# 1
#
# 0FalseFalse0
# 10False0
# 0
#
#
# 20
#
#
#
#
# False
# True
#
# 12TrueFalseTrueTrue1
# FalseTrue
# True
#
#
#
#
#
#
#
# 2
# 1
# FalseFalse000False00
# 00
#
#
#
#
#
#
#
#
# False
# 0
# True0FalseTrueTrueTrueTrue
# 2True
# True
#
#
#
#
#
#
#
# 0
#
# TrueTrue00010False
# 00
# 1
#
#
#
#
#
#
#
# True
# 0
# 0TrueTrueTrueFalseTrue1True
# False
# True
#
#
#
#
#
#
#
# 0
# True
# True0001False01
# 0
#
#
#
#
#
#
#
#
# True
# 001TrueTrueTrueFalseFalseTrue
# True
#
# 2
#
#
#
#
#
#
#
# True0
# FalseTrue10000
# 0
# 1False
#
#
#
#
#
#
#
# 0True
#
# 00FalseTrueTrueTrueTrueTrue
#
# False0
#
#
#
#
#
#
#
# True
#
# 1TrueTrue000101
# 0True
#
#
#
#
#
#
#
#
# 0
#
# False10TrueTrueTrueFalseTrueFalse
# True1
#
#
#
#
#
#
#
#
# True
#
# 0FalseTrue001001
# 0False
#
#
#
#
#
#
#
#
# 0
#
# True01TrueTrueFalseTrueTrueFalseTrue
#
#
# 1
#
#
#
#
#
#
#
# True
# True0False0000000
# False
#
#
#
#
#
#
#
#
#
#
# 00TrueTrueTrueTrueTrue2TrueTrueTrue0
#
#
#
#
#
#
#
#
#
#
#
# TrueTrue01000True0False11
#
#
#
#
#
#
#
#
#
#
# 0
# 0TrueTrueFalseTrueTrueTrue00
# FalseFalse
#
#
#
#
#
#
#
#
# True
#
# True0110TrueTrue11
# 0
#
#
#
#
#
#
#
# 0
#
# True0TrueFalse0False0
# FalseTrue2
# False
#
#
#
#
#
#
# True
#
#
# 0True01TrueTrue0
#
# 10
# False
#
#
# 2
#
# 0True
#
# 0
# TrueFalse
# 10True
#
# FalseTrue
# 0
#
# False
#
# True
# 0
#
# True
# 0
# 1TrueFalse0
#
# 0
#
# True01
#
#
#
# 0True
# 0
# True
#
# False00True
#
# True
# 0
# TrueFalse
#
#
#
# 0True
#
# True
# 0
# TrueTrue00
#
# 0True
# 0
# 0
#
#
#
# True0
#
# 0
# True
# 00TrueTrue
#
# True0
# True
# True
#
#
#
# True
# 1
# True
# 0
# TrueTrue00
#
# 2True
# 0
#
# 0
#
#
# False1
#
# 0
# True0
# 1TrueTrue
#
# False
# True
# 1
# True
#
#
# False
# 1True
# 1
# True
# False10
#
# 1
#
# 0False
# 0
#
#
# False0
# 0False
#
#
# 00False
# True
# False
#
# True0True
#
#
#
# 0True
# True
# 1
#
# True0True1
#
#
# 10
# True0
#
#
#
# True10
#
# False
#
# 10TrueFalse
#
#
# FalseTrue
# 0True
#
#
# 0
# TrueFalse
#
# 1
#
# FalseTrue
#
# 11
# 00
# True0
#
# True
# 0
#
#
# 1False
# 0
#
#
# FalseFalse2

# %% [markdown]
# ## Data Quality Impressions
# Let's get a summary of the data quality issues by type.

# %%
dqa = DataQualityAnalysis()
dqa.summarize()
# Out:
# [10/20/2024 01:09:35 AM] [ERROR] [discover.infra.persistence.dal.fao.base.CentralizedFileSystemFAO] [_read] : Exception occurred while reading a Parquet file from workspace/dev/dataset/01_dataprep/appvocai_discover-01_dataprep-02_dqa-review-dataset.parquet.
# Cannot yet unify dictionaries with nulls
# Traceback (most recent call last):
#   File "/home/john/projects/appvocai-discover/discover/infra/persistence/dal/fao/centralized.py", line 68, in _read
#     return pd.read_parquet(path=filepath, **self._storage_config["read_kwargs"])
#   File "/home/john/miniconda3/envs/appvocai/lib/python3.10/site-packages/pandas/io/parquet.py", line 667, in read_parquet
#     return impl.read(
#   File "/home/john/miniconda3/envs/appvocai/lib/python3.10/site-packages/pandas/io/parquet.py", line 281, in read
#     result = pa_table.to_pandas(**to_pandas_kwargs)
#   File "pyarrow/array.pxi", line 885, in pyarrow.lib._PandasConvertible.to_pandas
#   File "pyarrow/table.pxi", line 5002, in pyarrow.lib.Table._to_pandas
#   File "/home/john/miniconda3/envs/appvocai/lib/python3.10/site-packages/pyarrow/pandas_compat.py", line 784, in table_to_dataframe
#     result = pa.lib.table_to_blocks(options, table, categories,
#   File "pyarrow/table.pxi", line 3941, in pyarrow.lib.table_to_blocks
#   File "pyarrow/error.pxi", line 92, in pyarrow.lib.check_status
# pyarrow.lib.ArrowInvalid: Cannot yet unify dictionaries with nulls
# [10/20/2024 01:09:35 AM] [ERROR] [discover.infra.persistence.repo.dataset.DatasetRepo] [get] : Exception occurred while reading dataset dataset-dataprep-dqa-review contents from file.
# Traceback (most recent call last):
#   File "/home/john/projects/appvocai-discover/discover/infra/persistence/dal/fao/centralized.py", line 68, in _read
#     return pd.read_parquet(path=filepath, **self._storage_config["read_kwargs"])
#   File "/home/john/miniconda3/envs/appvocai/lib/python3.10/site-packages/pandas/io/parquet.py", line 667, in read_parquet
#     return impl.read(
#   File "/home/john/miniconda3/envs/appvocai/lib/python3.10/site-packages/pandas/io/parquet.py", line 281, in read
#     result = pa_table.to_pandas(**to_pandas_kwargs)
#   File "pyarrow/array.pxi", line 885, in pyarrow.lib._PandasConvertible.to_pandas
#   File "pyarrow/table.pxi", line 5002, in pyarrow.lib.Table._to_pandas
#   File "/home/john/miniconda3/envs/appvocai/lib/python3.10/site-packages/pyarrow/pandas_compat.py", line 784, in table_to_dataframe
#     result = pa.lib.table_to_blocks(options, table, categories,
#   File "pyarrow/table.pxi", line 3941, in pyarrow.lib.table_to_blocks
#   File "pyarrow/error.pxi", line 92, in pyarrow.lib.check_status
# pyarrow.lib.ArrowInvalid: Cannot yet unify dictionaries with nulls
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/john/projects/appvocai-discover/discover/infra/persistence/repo/dataset.py", line 254, in get
#     dataset.content = self._read_file(dataset=dataset)
#   File "/home/john/projects/appvocai-discover/discover/infra/persistence/repo/dataset.py", line 286, in _read_file
#     return self._read_centralized_file(dataset=dataset)
#   File "/home/john/projects/appvocai-discover/discover/infra/persistence/repo/dataset.py", line 299, in _read_centralized_file
#     return self._fao_cfs.read(filepath=dataset.storage_location)
#   File "/home/john/projects/appvocai-discover/discover/infra/persistence/dal/fao/base.py", line 86, in read
#     return self._read(filepath=filepath, **kwargs)
#   File "/home/john/projects/appvocai-discover/discover/infra/persistence/dal/fao/centralized.py", line 78, in _read
#     raise FileIOException(msg, e) from e
# discover.infra.persistence.dal.fao.exception.FileIOException: Exception occurred while reading a Parquet file from workspace/dev/dataset/01_dataprep/appvocai_discover-01_dataprep-02_dqa-review-dataset.parquet.
# Cannot yet unify dictionaries with nulls
# Original exception: Cannot yet unify dictionaries with nulls
# ---------------------------------------------------------------------------
# ArrowInvalid                              Traceback (most recent call last)
# File ~/projects/appvocai-discover/discover/infra/persistence/dal/fao/centralized.py:68, in CentralizedFileSystemFAO._read(self, filepath)
#      67 try:
# ---> 68     return pd.read_parquet(path=filepath, **self._storage_config["read_kwargs"])
#      69 except FileNotFoundError as e:
#
# File ~/miniconda3/envs/appvocai/lib/python3.10/site-packages/pandas/io/parquet.py:667, in read_parquet(path, engine, columns, storage_options, use_nullable_dtypes, dtype_backend, filesystem, filters, **kwargs)
#     665 check_dtype_backend(dtype_backend)
# --> 667 return impl.read(
#     668     path,
#     669     columns=columns,
#     670     filters=filters,
#     671     storage_options=storage_options,
#     672     use_nullable_dtypes=use_nullable_dtypes,
#     673     dtype_backend=dtype_backend,
#     674     filesystem=filesystem,
#     675     **kwargs,
#     676 )
#
# File ~/miniconda3/envs/appvocai/lib/python3.10/site-packages/pandas/io/parquet.py:281, in PyArrowImpl.read(self, path, columns, filters, use_nullable_dtypes, dtype_backend, storage_options, filesystem, **kwargs)
#     274 pa_table = self.api.parquet.read_table(
#     275     path_or_handle,
#     276     columns=columns,
#    (...)
#     279     **kwargs,
#     280 )
# --> 281 result = pa_table.to_pandas(**to_pandas_kwargs)
#     283 if manager == "array":
#
# File ~/miniconda3/envs/appvocai/lib/python3.10/site-packages/pyarrow/array.pxi:885, in pyarrow.lib._PandasConvertible.to_pandas()
#
# File ~/miniconda3/envs/appvocai/lib/python3.10/site-packages/pyarrow/table.pxi:5002, in pyarrow.lib.Table._to_pandas()
#
# File ~/miniconda3/envs/appvocai/lib/python3.10/site-packages/pyarrow/pandas_compat.py:784, in table_to_dataframe(options, table, categories, ignore_metadata, types_mapper)
#     783 column_names = table.column_names
# --> 784 result = pa.lib.table_to_blocks(options, table, categories,
#     785                                 list(ext_columns_dtypes.keys()))
#     786 if _pandas_api.is_ge_v3():
#
# File ~/miniconda3/envs/appvocai/lib/python3.10/site-packages/pyarrow/table.pxi:3941, in pyarrow.lib.table_to_blocks()
#
# File ~/miniconda3/envs/appvocai/lib/python3.10/site-packages/pyarrow/error.pxi:92, in pyarrow.lib.check_status()
#
# ArrowInvalid: Cannot yet unify dictionaries with nulls
#
# The above exception was the direct cause of the following exception:
#
# FileIOException                           Traceback (most recent call last)
# File ~/projects/appvocai-discover/discover/infra/persistence/repo/dataset.py:254, in DatasetRepo.get(self, asset_id)
#     253 try:
# --> 254     dataset.content = self._read_file(dataset=dataset)
#     255     return dataset
#
# File ~/projects/appvocai-discover/discover/infra/persistence/repo/dataset.py:286, in DatasetRepo._read_file(self, dataset)
#     285 else:
# --> 286     return self._read_centralized_file(dataset=dataset)
#
# File ~/projects/appvocai-discover/discover/infra/persistence/repo/dataset.py:299, in DatasetRepo._read_centralized_file(self, dataset)
#     290 """
#     291 Reads a dataset's content from a centralized file system.
#     292
#    (...)
#     297     pd.DataFrame: The content of the dataset.
#     298 """
# --> 299 return self._fao_cfs.read(filepath=dataset.storage_location)
#
# File ~/projects/appvocai-discover/discover/infra/persistence/dal/fao/base.py:86, in FileSystemFAO.read(self, filepath, **kwargs)
#      73 """
#      74 Reads data from a file at the specified filepath.
#      75
#    (...)
#      84     Union[pd.DataFrame, pyspark.sql.DataFrame]: The data read from the file.
#      85 """
# ---> 86 return self._read(filepath=filepath, **kwargs)
#
# File ~/projects/appvocai-discover/discover/infra/persistence/dal/fao/centralized.py:78, in CentralizedFileSystemFAO._read(self, filepath)
#      77 self._logger.exception(msg)
# ---> 78 raise FileIOException(msg, e) from e
#
# FileIOException: Exception occurred while reading a Parquet file from workspace/dev/dataset/01_dataprep/appvocai_discover-01_dataprep-02_dqa-review-dataset.parquet.
# Cannot yet unify dictionaries with nulls
# Original exception: Cannot yet unify dictionaries with nulls
#
# The above exception was the direct cause of the following exception:
#
# DatasetIOError                            Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 dqa = DataQualityAnalysis()
#       2 dqa.summarize()
#
# File ~/projects/appvocai-discover/discover/app/dqa.py:44, in DataQualityAnalysis.__init__(self)
#      36 super().__init__()
#      38 self._asset_id = idgen.get_asset_id(
#      39     asset_type="dataset",
#      40     phase=PhaseDef.DATAPREP,
#      41     stage=DataPrepStageDef.DQA,
#      42     name="review",
#      43 )
# ---> 44 self._data = self._load_data(asset_id=self._asset_id)
#
# File ~/projects/appvocai-discover/discover/app/dqa.py:94, in DataQualityAnalysis._load_data(self, asset_id)
#      93 def _load_data(self, asset_id: str) -> pd.DataFrame:
# ---> 94     return super()._load_data(asset_id=asset_id)
#
# File ~/projects/appvocai-discover/discover/app/base.py:73, in Analysis._load_data(self, asset_id)
#      62 def _load_data(self, asset_id: str) -> Union[pd.DataFrame, pyspark.sql.DataFrame]:
#      63     """
#      64     Loads data from the dataset repository using the given asset ID.
#      65
#    (...)
#      71         either be a Pandas DataFrame or a PySpark DataFrame depending on the data source.
#      72     """
# ---> 73     return self._repo.get(asset_id=asset_id).content
#
# File ~/projects/appvocai-discover/discover/infra/persistence/repo/dataset.py:268, in DatasetRepo.get(self, asset_id)
#     266 msg = f"Exception occurred while reading dataset {dataset.asset_id} contents from file."
#     267 self._logger.exception(msg)
# --> 268 raise DatasetIOError(msg, e) from e
#
# DatasetIOError: Exception occurred while reading dataset dataset-dataprep-dqa-review contents from file.
# Original exception: Exception occurred while reading a Parquet file from workspace/dev/dataset/01_dataprep/appvocai_discover-01_dataprep-02_dqa-review-dataset.parquet.
# Cannot yet unify dictionaries with nulls
# Original exception: Cannot yet unify dictionaries with nulls

# %% [markdown]
# The data quality assessment (DQA) conducted on the AppVoC dataset revealed several key issues that need to be addressed to ensure the integrity and reliability of the analysis. These issues include:
#
# - **Non-English**: Notable proportions of the app names (15%) and review content (4.9%) were flagged as being non-English.
# - **Emoji**: Approximately 6% of the reviews have emoji characters.
# - **Duplicates**: A small percentage (5.6%) have duplicate reviews.
# - **Special Characters**: A small percentage (< 2%) of reviews were noted for the presence of special characters in excessive proportions.
# - **Profanity**: About 1% of the reviews have language considered profane.
# - **Random Text**: Random text, indicated by high entropy scores, is present in less than 0.5% of the text.
# - **Sensitive Information**: The presence of sensitive information, such as email addresses, and phone numbers are relatively minimal.
#
# On the other hand:
# - **Null Values**: Fortunately, there were no null values detected in the dataset.
# - **Invalid Entries**: There were no invalid dates or invalid ratings found.
#
# Given these findings, the next step is to visually inspect a sample of the anomalies, then identify and treat the high-impact data quality issues.

# %% [markdown]
# ## Data Anomalies

# %%
dqa.get_non_english_apps()

# %% [markdown]
# This may involve, without limitation:
#
# - **Removing Duplicates**: Eliminating observations with duplicate review IDs.
# - **Handling Outliers**: Identifying and appropriately managing outliers in vote sums, and vote counts.
# - **Addressing Non-English Text**: Filtering or translating non-English reviews.
# - **filtering Noise**: Filtering or removing excessive special characters from reviews.
# - **Ensuring Clean Content**: Censor or remove reviews containing profanity.
# - **Remove Personal Data**: Personal identifying information such as phone numbers, and email addresses, would be removed.
#
# Cue the action!
