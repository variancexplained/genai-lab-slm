# %%
from appinsight.infrastructure.storage.file import IOService
from appinsight.data.analysis.overview import DatasetOverview

# %%
FP = "data/dev/03_clean/reviews.pkl"

# %%
df = IOService.read(FP)
ds = DatasetOverview(data=df)
ds.info
ds.structure
ds.dtypes
ds.overview
ds.size
ds.summarize()
# Out:
# <style type="text/css">
# </style>
# <table id="T_4775e">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_4775e_level0_col0" class="col_heading level0 col0" >Column</th>
#       <th id="T_4775e_level0_col1" class="col_heading level0 col1" >DataType</th>
#       <th id="T_4775e_level0_col2" class="col_heading level0 col2" >Complete</th>
#       <th id="T_4775e_level0_col3" class="col_heading level0 col3" >Null</th>
#       <th id="T_4775e_level0_col4" class="col_heading level0 col4" >Completeness</th>
#       <th id="T_4775e_level0_col5" class="col_heading level0 col5" >Unique</th>
#       <th id="T_4775e_level0_col6" class="col_heading level0 col6" >Duplicate</th>
#       <th id="T_4775e_level0_col7" class="col_heading level0 col7" >Uniqueness</th>
#       <th id="T_4775e_level0_col8" class="col_heading level0 col8" >Size (Bytes)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
# ...
