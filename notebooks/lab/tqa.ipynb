# %% [markdown]
# # Text Quality Assessment

# %%
import numpy as np
import pandas as pd
from tqdm import tqdm

from discover.container import DiscoverContainer
from discover.assets.idgen import AssetIDGen
from discover.core.flow import DataPrepStageDef, PhaseDef

pd.options.display.max_rows = 999

# %%
PPL_FULL = 4.673929214477539
FP_WEIGHTS = "notes/tqa_weights.csv"

# %%
container = DiscoverContainer()
container.init_resources()
container.wire(
    modules=[
        "discover.flow.data_prep.stage",
        "discover.app.base",
    ],
)

# %% [markdown]
# ## Compute Weights

# %%
tqa_weights = pd.read_csv(FP_WEIGHTS)
tqa_weights
# Out:
#     Unnamed: 0                        Filter  Perplexity
# 0            0             tqf_has_adjective    4.546495
# 1            1                tqf_has_adverb    4.583549
# 2            2            tqf_has_determiner    4.462878
# 3            3                  tqf_has_noun    4.512285
# 4            4  tqf_has_terminal_punctuation    4.651699
# 5            5                  tqf_has_verb    4.389349
# 6            6    tqf_high_punctuation_ratio    5.892704
# 7            7          tqf_word_count_range    4.521953
# 8            8           tqf_stop_word_match    4.549662
# 9            9          tqf_first_letter_cap    4.761631
# 10          10               tqf_no_all_caps    4.678274
# 11          11      tqf_high_word_repetition    4.503226
# 12          12          tqf_no_special_chars    4.916765

# %%
tqa_weights["Weight"] = tqa_weights["Perplexity"].apply(
    lambda x: max(0.0, ((PPL_FULL - x) / PPL_FULL))
)
tqa_weights
# Out:
#     Unnamed: 0                        Filter  Perplexity    Weight
# 0            0             tqf_has_adjective    4.546495  0.027265
# 1            1                tqf_has_adverb    4.583549  0.019337
# 2            2            tqf_has_determiner    4.462878  0.045155
# 3            3                  tqf_has_noun    4.512285  0.034584
# 4            4  tqf_has_terminal_punctuation    4.651699  0.004756
# 5            5                  tqf_has_verb    4.389349  0.060887
# 6            6    tqf_high_punctuation_ratio    5.892704  0.000000
# 7            7          tqf_word_count_range    4.521953  0.032516
# 8            8           tqf_stop_word_match    4.549662  0.026587
# 9            9          tqf_first_letter_cap    4.761631  0.000000
# 10          10               tqf_no_all_caps    4.678274  0.000000
# 11          11      tqf_high_word_repetition    4.503226  0.036522
# 12          12          tqf_no_special_chars    4.916765  0.000000

# %% [markdown]
# ## Load Dataset

# %%
idgen = AssetIDGen()
asset_id = idgen.get_asset_id(
    asset_type="dataset",
    phase=PhaseDef.DATAPREP,
    stage=DataPrepStageDef.TQA,
    name="review",
)
# Instantiate the repository
repo = container.repo.dataset_repo()
# Load the dataset from the repository
dataset = repo.get(asset_id, distributed=False)
# Filter tqa_score outliers
df = dataset.content.loc[dataset.content["tqa_score"] < 5]
print(f"Dataset has {len(df)} observations.")
# Out:
# Dataset has 55691 observations.

# %% [markdown]
# ## Get Filter Columns

# %%
filters = df.columns[df.columns.str.contains("tqf")].tolist()
filters = [filter for filter in filters if filter != "tqf_high_digit_ratio"]
filters
# Out:
# ['tqf_has_adjective',
#  'tqf_has_adverb',
#  'tqf_has_determiner',
#  'tqf_has_noun',
#  'tqf_has_terminal_punctuation',
#  'tqf_has_verb',
#  'tqf_high_punctuation_ratio',
#  'tqf_word_count_range',
#  'tqf_stop_word_match',
#  'tqf_first_letter_cap',
#  'tqf_no_all_caps',
#  'tqf_high_word_repetition',
#  'tqf_no_special_chars']

# %% [markdown]
# ## Compute Scores

# %%
flags = df[filters].to_numpy()
np.shape(flags)
scores = flags.dot(tqa_weights["Weight"])
df["tqa_scores2"] = scores
# Out:
# /tmp/ipykernel_269446/976417660.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['tqa_scores2'] = scores

# %%
df.head().T
# Out:
#                                                                                  0  \
# app_id                                                                   521227008
# id                                                                      6820417815
# app_name                                            Audiobooks.com: Get audiobooks
# category_id                                                                   6018
# author                                                        d1e8eb407847e0422c7b
# rating                                                                           4
# content                          Ive been looking to get listen to audiobooks a...
# vote_sum                                                                         0
# vote_count                                                                       0
# date                                                           2021-01-02 04:17:00
# eda_review_length                                                                  106
# pos_n_nouns                                                                     18
# pos_n_verbs                                                                     14
# pos_n_adjectives                                                                13
# pos_n_adverbs                                                                   11
# pos_n_determiners                                                               11
# pos_p_nouns                                                               0.160714
# pos_p_verbs                                                                  0.125
# pos_p_adjectives                                                          0.116071
# pos_p_adverbs                                                             0.098214
# pos_p_determiners                                                         0.098214
# stats_char_count                                                               538
# stats_digits_count                                                             535
# stats_digits_proportion                                                   0.994424
# stats_special_chars_count                                                        7
# stats_special_chars_proportion                                            0.013011
# stats_word_count                                                               106
# stats_unique_word_count                                                         74
# stats_unique_word_proportion                                              0.698113
# stats_word_repetition_ratio                                               0.301887
# stats_word_length_min                                                            1
# stats_word_length_max                                                           12
# stats_word_length_mean                                                    4.084906
# stats_word_length_std                                                     2.331563
# eda_review_age                                                               974
# stats_rating_avg                                                               4.0
# eda_rating_deviation                                                         0.0
# stats_eda_review_length_avg                                                      111.5
# eda_review_length_deviation                                                 -5.5
# tqf_has_adjective                                                             True
# tqf_has_adverb                                                                True
# tqf_has_determiner                                                            True
# tqf_has_noun                                                                  True
# tqf_has_terminal_punctuation                                                  True
# tqf_has_verb                                                                  True
# tqf_high_digit_ratio                                                          True
# tqf_high_punctuation_ratio                                                   False
# tqf_word_count_range                                                          True
# tqf_stop_word_match                                                           True
# tqf_first_letter_cap                                                          True
# tqf_no_all_caps                                                               True
# tqf_high_word_repetition                                                      True
# tqf_no_special_chars                                                          True
# tqm_pos_count_score                                                       0.056338
# tqm_pos_diversity_score                                                   0.206324
# tqm_structural_complexity_score                                           0.196524
# tqm_pos_intensity_score                                                    0.05283
# tqm_tqa_check_score                                                       0.069777
# tqa_score                                                                 0.581792
# category                                                                      Book
# tqa_scores2                                                               0.287609
#
#                                                                                  1  \
# app_id                                                                   466446054
# id                                                                      6821034342
# app_name                                               cloudLibrary by bibliotheca
# category_id                                                                   6018
# author                                                        d2b8d2519dbd0a3d9e76
# rating                                                                           5
# content                          The interface isnt as slick as kindle or audib...
# vote_sum                                                                         0
# vote_count                                                                       0
# date                                                           2021-01-02 07:47:00
# eda_review_length                                                                   12
# pos_n_nouns                                                                      3
# pos_n_verbs                                                                      0
# pos_n_adjectives                                                                 3
# pos_n_adverbs                                                                    2
# pos_n_determiners                                                                1
# pos_p_nouns                                                               0.230769
# pos_p_verbs                                                                    0.0
# pos_p_adjectives                                                          0.230769
# pos_p_adverbs                                                             0.153846
# pos_p_determiners                                                         0.076923
# stats_char_count                                                                61
# stats_digits_count                                                              61
# stats_digits_proportion                                                        1.0
# stats_special_chars_count                                                        1
# stats_special_chars_proportion                                            0.016393
# stats_word_count                                                                12
# stats_unique_word_count                                                         11
# stats_unique_word_proportion                                              0.916667
# stats_word_repetition_ratio                                               0.083333
# stats_word_length_min                                                            2
# stats_word_length_max                                                            9
# stats_word_length_mean                                                    4.166667
# stats_word_length_std                                                     2.114763
# eda_review_age                                                               974
# stats_rating_avg                                                          2.416667
# eda_rating_deviation                                                    2.583333
# stats_eda_review_length_avg                                                       41.5
# eda_review_length_deviation                                                -29.5
# tqf_has_adjective                                                             True
# tqf_has_adverb                                                                True
# tqf_has_determiner                                                            True
# tqf_has_noun                                                                  True
# tqf_has_terminal_punctuation                                                  True
# tqf_has_verb                                                                 False
# tqf_high_digit_ratio                                                          True
# tqf_high_punctuation_ratio                                                   False
# tqf_word_count_range                                                          True
# tqf_stop_word_match                                                          False
# tqf_first_letter_cap                                                          True
# tqf_no_all_caps                                                               True
# tqf_high_word_repetition                                                     False
# tqf_no_special_chars                                                          True
# tqm_pos_count_score                                                       0.008048
# tqm_pos_diversity_score                                                   0.192948
# tqm_structural_complexity_score                                           0.201203
# tqm_pos_intensity_score                                                   0.066667
# tqm_tqa_check_score                                                       0.069508
# tqa_score                                                                 0.538374
# category                                                                      Book
# tqa_scores2                                                               0.163613
#
#                                                                                  2  \
# app_id                                                                  1492654676
# id                                                                      6824778204
# app_name                                            POCKET COMICS: Premium Webtoon
# category_id                                                                   6018
# author                                                        92be615c4beec31b0db6
# rating                                                                           3
# content                          I love the app and the fact that on good stori...
# vote_sum                                                                         0
# vote_count                                                                       0
# date                                                           2021-01-03 05:46:00
# eda_review_length                                                                   97
# pos_n_nouns                                                                     18
# pos_n_verbs                                                                     13
# pos_n_adjectives                                                                 9
# pos_n_adverbs                                                                    6
# pos_n_determiners                                                               10
# pos_p_nouns                                                               0.174757
# pos_p_verbs                                                               0.126214
# pos_p_adjectives                                                          0.087379
# pos_p_adverbs                                                             0.058252
# pos_p_determiners                                                         0.097087
# stats_char_count                                                               479
# stats_digits_count                                                             477
# stats_digits_proportion                                                   0.995825
# stats_special_chars_count                                                        8
# stats_special_chars_proportion                                            0.016701
# stats_word_count                                                                97
# stats_unique_word_count                                                         66
# stats_unique_word_proportion                                              0.680412
# stats_word_repetition_ratio                                               0.319588
# stats_word_length_min                                                            1
# stats_word_length_max                                                           11
# stats_word_length_mean                                                    3.948454
# stats_word_length_std                                                     1.766651
# eda_review_age                                                               973
# stats_rating_avg                                                              2.75
# eda_rating_deviation                                                        0.25
# stats_eda_review_length_avg                                                       70.0
# eda_review_length_deviation                                                 27.0
# tqf_has_adjective                                                             True
# tqf_has_adverb                                                                True
# tqf_has_determiner                                                            True
# tqf_has_noun                                                                  True
# tqf_has_terminal_punctuation                                                  True
# tqf_has_verb                                                                  True
# tqf_high_digit_ratio                                                          True
# tqf_high_punctuation_ratio                                                   False
# tqf_word_count_range                                                          True
# tqf_stop_word_match                                                           True
# tqf_first_letter_cap                                                          True
# tqf_no_all_caps                                                               True
# tqf_high_word_repetition                                                      True
# tqf_no_special_chars                                                         False
# tqm_pos_count_score                                                       0.046278
# tqm_pos_diversity_score                                                   0.188934
# tqm_structural_complexity_score                                           0.161434
# tqm_pos_intensity_score                                                   0.047423
# tqm_tqa_check_score                                                       0.069624
# tqa_score                                                                 0.513693
# category                                                                      Book
# tqa_scores2                                                               0.287609
#
#                                                                                  3  \
# app_id                                                                  1248062869
# id                                                                      6826980171
# app_name                                            Lure: Interactive Chat Stories
# category_id                                                                   6018
# author                                                        62b165e509cd67d2b2f3
# rating                                                                           1
# content                          Hi the app is amazing and stories are really g...
# vote_sum                                                                         0
# vote_count                                                                       0
# date                                                           2021-01-03 18:37:00
# eda_review_length                                                                   65
# pos_n_nouns                                                                      9
# pos_n_verbs                                                                     11
# pos_n_adjectives                                                                 3
# pos_n_adverbs                                                                    5
# pos_n_determiners                                                                3
# pos_p_nouns                                                               0.142857
# pos_p_verbs                                                               0.174603
# pos_p_adjectives                                                          0.047619
# pos_p_adverbs                                                             0.079365
# pos_p_determiners                                                         0.047619
# stats_char_count                                                               304
# stats_digits_count                                                             302
# stats_digits_proportion                                                   0.993421
# stats_special_chars_count                                                        2
# stats_special_chars_proportion                                            0.006579
# stats_word_count                                                                63
# stats_unique_word_count                                                         53
# stats_unique_word_proportion                                               0.84127
# stats_word_repetition_ratio                                                0.15873
# stats_word_length_min                                                            0
# stats_word_length_max                                                           11
# stats_word_length_mean                                                    3.809524
# stats_word_length_std                                                     2.224375
# eda_review_age                                                               973
# stats_rating_avg                                                          2.333333
# eda_rating_deviation                                                   -1.333333
# stats_eda_review_length_avg                                                      123.0
# eda_review_length_deviation                                                -58.0
# tqf_has_adjective                                                             True
# tqf_has_adverb                                                                True
# tqf_has_determiner                                                            True
# tqf_has_noun                                                                  True
# tqf_has_terminal_punctuation                                                 False
# tqf_has_verb                                                                  True
# tqf_high_digit_ratio                                                          True
# tqf_high_punctuation_ratio                                                   False
# tqf_word_count_range                                                          True
# tqf_stop_word_match                                                           True
# tqf_first_letter_cap                                                          True
# tqf_no_all_caps                                                               True
# tqf_high_word_repetition                                                     False
# tqf_no_special_chars                                                          True
# tqm_pos_count_score                                                       0.028169
# tqm_pos_diversity_score                                                   0.185755
# tqm_structural_complexity_score                                           0.201159
# tqm_pos_intensity_score                                                   0.044444
# tqm_tqa_check_score                                                           0.03
# tqa_score                                                                 0.489527
# category                                                                      Book
# tqa_scores2                                                               0.246331
#
#                                                                                  4
# app_id                                                                  1076402606
# id                                                                      6828395114
# app_name                                                       Libby, by OverDrive
# category_id                                                                   6018
# author                                                        6ca53a438d4c9ff67a79
# rating                                                                           5
# content                          I love how easy it is to borrow books using th...
# vote_sum                                                                         0
# vote_count                                                                       0
# date                                                           2021-01-04 03:45:00
# eda_review_length                                                                   56
# pos_n_nouns                                                                      8
# pos_n_verbs                                                                     12
# pos_n_adjectives                                                                 5
# pos_n_adverbs                                                                    5
# pos_n_determiners                                                                3
# pos_p_nouns                                                               0.129032
# pos_p_verbs                                                               0.193548
# pos_p_adjectives                                                          0.080645
# pos_p_adverbs                                                             0.080645
# pos_p_determiners                                                         0.048387
# stats_char_count                                                               293
# stats_digits_count                                                             293
# stats_digits_proportion                                                        1.0
# stats_special_chars_count                                                        6
# stats_special_chars_proportion                                            0.020478
# stats_word_count                                                                56
# stats_unique_word_count                                                         48
# stats_unique_word_proportion                                              0.857143
# stats_word_repetition_ratio                                               0.142857
# stats_word_length_min                                                            1
# stats_word_length_max                                                           13
# stats_word_length_mean                                                        4.25
# stats_word_length_std                                                      2.51602
# eda_review_age                                                               972
# stats_rating_avg                                                          4.570667
# eda_rating_deviation                                                    0.429333
# stats_eda_review_length_avg                                                  36.469333
# eda_review_length_deviation                                            19.530667
# tqf_has_adjective                                                             True
# tqf_has_adverb                                                                True
# tqf_has_determiner                                                            True
# tqf_has_noun                                                                  True
# tqf_has_terminal_punctuation                                                  True
# tqf_has_verb                                                                  True
# tqf_high_digit_ratio                                                          True
# tqf_high_punctuation_ratio                                                   False
# tqf_word_count_range                                                          True
# tqf_stop_word_match                                                           True
# tqf_first_letter_cap                                                          True
# tqf_no_all_caps                                                               True
# tqf_high_word_repetition                                                     False
# tqf_no_special_chars                                                          True
# tqm_pos_count_score                                                       0.030181
# tqm_pos_diversity_score                                                    0.19763
# tqm_structural_complexity_score                                           0.220761
# tqm_pos_intensity_score                                                   0.053571
# tqm_tqa_check_score                                                       0.069386
# tqa_score                                                                 0.571529
# category                                                                      Book
# tqa_scores2                                                               0.251087

# %% [markdown]
# ## Correlation Between Scores

# %%
df.loc[df["stats_special_chars_proportion"] > 0.2][
    ["content", "stats_special_chars_proportion"]
]
# Out:
#                                                  content  \
# 424                     oh.... our table.... is broken!
# 1407                                       Great book!!!
# 1641                                  I LOVE DIS APP!!!!
# 1642                Let us buy books on Amazon!!!!!!!!!!
# 1955                                             Great!!
# 3057                    Always clear.... Always works!!!
# 4299      I dont like when my time disappears!!!!!!!!!!!
# 5174                                           Love it!!
# 6290                                          Love it!!!
# 6492                                           AWESOME!!
# 6518                                        I love it!!!
# 6868                                           Love it!!
# 7044                                           For fun!!
# 7711                                      I love it ! :)
# 7831   I rlly love ur app. While my mom says its stup...
# 8344                                       Just great!!!
# 8715                                DO NOT DOWNLOAD!!!!!
# 8905                                        Best show!!!
# 8908                                             [PHONE]
# 9263                                             [PHONE]
# 9270                                      Great show!!!!
# 9851   Its the best game ever!!!!!!!!!!!!!!!!! Its li...
# 10070                                         Amazing!!!
# 10247  Rip off!!!!!!!!!! Wont open entire season as s...
# 10248          Its great but TOOO MANNNYYYY. ADS!!!!!!!!
# 11131                                   The best exp!!!!
# 11175                                        WOW love!!!
# 11372                                          Amazing!!
# 11562                                          Awesome!!
# 11597                                     Outstanding!!!
# 12219                                        Perfect !!!
# 12702                                           Thief !!
# 12913  I recommend it to anybody. it is so helpful an...
# 14316                                           AWSOME!!
# 14462                                               Yum!
# 14600                                         Awesome!!!
# 14917                                         Bad app!!!
# 15326                                           Bagels!!
# 15603                                      Thank you! :)
# 15619            I use this app every day. Fix it!!!!!!!
# 17386                                            Great!!
# 17580                                           Try it!!
# 17709                                          Amazing!!
# 18791                                        Exciting!!!
# 19237                                      Amazing UI!!!
# 19493                                         Love it!!!
# 20062  Amazing!!!! I would get this app right now!!!!...
# 21035                                     Its awesome!!!
# 21918                                               *app
# 21956                                         Love it...
# 21978                                           Really?!
# 22085                                         Niceeee!!!
# 22379                                            Yikes..
# 22569                       Thumbs up! ! ! ! come, come,
# 22761                                            Great!!
# 23370                                         Love it!!!
# 24717                                       Great app!!!
# 25391                                       Great App!!!
# 25605                           How do I use this... ???
# 25737                                I love this app!!!!
# 26056                        I love this app......Period
# 26061                                          I,love,it
# 26662                                       Great app!!!
# 26873                                            [PHONE]
# 27189                                   Awesome AAAA++++
# 27619                                          Love It!!
# 27870                                  Awesome tool!!!!!
# 28168                                   Great stuff. !!!
# 29247                                               yay.
# 30022                                               Yup!
# 30619                           Amazing I love it!!!!!!!
# 31573                                  Love this app!!!!
# 31747                                       Great App!!!
# 32345                                           Thanks!!
# 32480                                       Thus far ...
# 32712                                     TO MUCH ADS!!!
# 32805                                               Yes.
# 33311                                        Good job!!!
# 33499                                          Awesome!!
# 34546                               Stop censoring!!!!!!
# 34696                                   YES!!! Love it !
# 34821                                 Just stop them....
# 35049                                        Too good...
# 35250                                       I love it...
# 35549                                          Love it!!
# 36820  Wheres the iOS [URL] ??? App malfunctioning!!!...
# 37139                                         GET OUT!!!
# 37886                                       It hit me!!!
# 39132                                        and Ever!!!
# 39137                                               Wow!
# 39154                   Its ok ig ....... sike I love it
# 39439                           Powerful app!!!!! Period
# 39514                    Is the best of the best!!!!!!!!
# 41393                                           Thanks!!
# 41931  I love this app!!!!!!!!!!!!!!!! Remember to fo...
# 42755                                          Love it!!
# 43068                                               W w.
# 45044                   This is the best app ever!!!!!!!
# 45052                                               H(be
# 45067                                     What a joke!!!
# 45118                                       I love it!!!
# 45691                                       I love it!!!
# 46236                                  Love this app!!!!
# 46680                                               yup.
# 46983                                     Agradecida !!!
# 47316                                               +rep
# 47367                                               Yup.
# 47861                                     Amazing app!!!
# 49083                                               yes!
# 49241                                            [PHONE]
# 50110                        Good battery life too......
# 50237           New to the site..... so far..... so good
# 50456             What happened to all my notes!?!?!?!?!
# 51549                                         Love it!!!
# 52172                                            [PHONE]
# 52348                                               g t!
# 52618                                     Amazing app!!!
# 53087                                          Love it!!
# 53559                                So I deleted it!!!!
# 54141  29:&:&:&:!:!:!: bug with reviews, I writing nt...
# 54883                                 I love it tysm!!!!
# 55626                                            [PHONE]
#
#        stats_special_chars_proportion
# 424                          0.281250
# 1407                         0.230769
# 1641                         0.222222
# 1642                         0.277778
# 1955                         0.285714
# 3057                         0.218750
# 4299                         0.239130
# 5174                         0.222222
# 6290                         0.300000
# 6492                         0.222222
# 6518                         0.250000
# 6868                         0.222222
# 7044                         0.222222
# 7711                         0.214286
# 7831                         0.293233
# 8344                         0.230769
# 8715                         0.250000
# 8905                         0.250000
# 8908                         0.285714
# 9263                         0.285714
# 9270                         0.285714
# 9851                         0.283333
# 10070                        0.300000
# 10247                        0.211538
# 10248                        0.219512
# 11131                        0.250000
# 11175                        0.272727
# 11372                        0.222222
# 11562                        0.222222
# 11597                        0.214286
# 12219                        0.272727
# 12702                        0.250000
# 12913                        0.239437
# 14316                        0.250000
# 14462                        0.250000
# 14600                        0.300000
# 14917                        0.300000
# 15326                        0.250000
# 15603                        0.230769
# 15619                        0.205128
# 17386                        0.285714
# 17580                        0.250000
# 17709                        0.222222
# 18791                        0.272727
# 19237                        0.230769
# 19493                        0.300000
# 20062                        0.240000
# 21035                        0.214286
# 21918                        0.250000
# 21956                        0.300000
# 21978                        0.250000
# 22085                        0.300000
# 22379                        0.285714
# 22569                        0.214286
# 22761                        0.285714
# 23370                        0.300000
# 24717                        0.250000
# 25391                        0.250000
# 25605                        0.250000
# 25737                        0.210526
# 26056                        0.222222
# 26061                        0.222222
# 26662                        0.250000
# 26873                        0.285714
# 27189                        0.250000
# 27619                        0.222222
# 27870                        0.294118
# 28168                        0.250000
# 29247                        0.250000
# 30022                        0.250000
# 30619                        0.291667
# 31573                        0.235294
# 31747                        0.250000
# 32345                        0.250000
# 32480                        0.250000
# 32712                        0.214286
# 32805                        0.250000
# 33311                        0.272727
# 33499                        0.222222
# 34546                        0.300000
# 34696                        0.250000
# 34821                        0.222222
# 35049                        0.272727
# 35250                        0.250000
# 35549                        0.222222
# 36820                        0.240000
# 37139                        0.300000
# 37886                        0.250000
# 39132                        0.272727
# 39137                        0.250000
# 39154                        0.218750
# 39439                        0.208333
# 39514                        0.258065
# 41393                        0.250000
# 41931                        0.242857
# 42755                        0.222222
# 43068                        0.250000
# 45044                        0.218750
# 45052                        0.250000
# 45067                        0.214286
# 45118                        0.250000
# 45691                        0.250000
# 46236                        0.235294
# 46680                        0.250000
# 46983                        0.214286
# 47316                        0.250000
# 47367                        0.250000
# 47861                        0.214286
# 49083                        0.250000
# 49241                        0.285714
# 50110                        0.222222
# 50237                        0.250000
# 50456                        0.236842
# 51549                        0.300000
# 52172                        0.285714
# 52348                        0.250000
# 52618                        0.214286
# 53087                        0.222222
# 53559                        0.210526
# 54141                        0.280000
# 54883                        0.222222
# 55626                        0.285714

# %%
s1 = df["tqa_score"]
s2 = df["tqa_scores2"]
print(f"The correlation between s1 and s2 is: {s1.corr(s2)}")
print(s1.describe())
s2.describe()
# Out:
# The correlation between s1 and s2 is: 0.7063475218195396
# count    55691.000000
# mean         0.483371
# std          0.101457
# min          0.000000
# 25%          0.449221
# 50%          0.503377
# 75%          0.544764
# max          2.631612
# Name: tqa_score, dtype: float64
# count    55691.000000
# mean         0.205710
# std          0.073945
# min          0.000000
# 25%          0.173911
# 50%          0.231750
# 75%          0.251087
# max          0.287609
# Name: tqa_scores2, dtype: float64
