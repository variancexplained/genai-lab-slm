# %% [markdown]
# # DBA

# %%
from appinsight.container import AppInsightContainer
from sqlalchemy import text

# %%
container = AppInsightContainer()
db = container.db.sqlite()

# %%
with open("scripts/sqlite3/dataset.sql") as file:
    query = file.read()
    db.command(query=query)
