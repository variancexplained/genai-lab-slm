# %%
import warnings

warnings.filterwarnings("ignore")
import os

if "jbook" in os.getcwd():
    os.chdir(os.path.abspath(os.path.join("../..")))

# %% [markdown]
# # Feature Engineering

# %% [markdown]
# ## Import Libraries

# %%
from discover.container import DiscoverContainer
from discover.infra.config.flow import FlowConfigReader
from discover.flow.data_prep.feature.stage import FeatureEngineeringStage

# %% [markdown]
# ## Dependency Container

# %%
container = DiscoverContainer()
container.init_resources()
container.wire(
    modules=[
        "discover.flow.data_prep.stage",
    ],
)

# %% [markdown]
# ## Feature Engineering Pipeline

# %%
# Obtain the configuration
reader = FlowConfigReader()
config = reader.get_config("phases", namespace=False)
stage_config = config["dataprep"]["stages"]["feature"]

# Build and run Data Ingestion Stage
stage = FeatureEngineeringStage.build(stage_config=stage_config, force=True)
asset_id = stage.run()
# Out:
# # ============================================================================== #
# #                           Feature Engineering Stage                            #
# # ============================================================================== #
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[8], line 8
#       6 # Build and run Data Ingestion Stage
#       7 stage = FeatureEngineeringStage.build(stage_config=stage_config, force=True)
# ----> 8 asset_id = stage.run()
#
# File ~/projects/appvocai-discover/discover/infra/service/logging/stage.py:49, in stage_logger.<locals>.wrapper(self, *args, **kwargs)
#      46 start_fmt = dt4mtr.to_HTTP_format(start)
#      48 # Execute the original function being decorated, passing all args and kwargs.
# ---> 49 result = func(self, *args, **kwargs)
#      51 # Log runtime.
#      52 end = datetime.now()
#
# File ~/projects/appvocai-discover/discover/flow/data_prep/stage.py:160, in DataPrepStage.run(self)
#     157 if self._repo.exists(asset_id=self._destination_asset_id):
#     158     self._repo.remove(asset_id=self._destination_asset_id)
# --> 160 data = self._load_source_data()
#     162 for task in self._tasks:
#     163     data = task.run(data=data)
#
# File ~/projects/appvocai-discover/discover/flow/data_prep/feature/stage.py:67, in FeatureEngineeringStage._load_source_data(self)
#      60 """Loads the source dataset from the repository using the source asset ID."""
#      61 source_asset_id = AssetIDGen.get_asset_id(
#      62     asset_type=self._source_config.asset_type,
#      63     phase=PhaseDef.from_value(value=self._source_config.phase),
#      64     stage=DataPrepStageDef.from_value(value=self._source_config.stage),
#      65     name=self._source_config.name,
#      66 )
# ---> 67 dataset = self._repo.get(asset_id=source_asset_id, distributed=True, nlp=True)
#      68 # Spark adds a column for the pandas index if it exists, which is renamed here.
#      69 if "__index_level_0__" in dataset.content.columns:
#
# File ~/projects/appvocai-discover/discover/infra/persistence/repo/dataset.py:258, in DatasetRepo.get(self, asset_id, distributed, nlp)
#     256 # Step 2: Get the dataset contents from file, add to dataset object and return
#     257 try:
# --> 258     dataset.content = self._read_file(
#     259         dataset=dataset, distributed=distributed, nlp=nlp
#     260     )
#     261     return dataset
#     262 except FileNotFoundError as e:
#
# File ~/projects/appvocai-discover/discover/infra/persistence/repo/dataset.py:316, in DatasetRepo._read_file(self, dataset, distributed, nlp)
#     306 """
#     307 Reads a dataset's content based on its storage configuration.
#     308
#    (...)
#     313     Union[pd.DataFrame, pyspark.sql.DataFrame]: The dataset's content.
#     314 """
#     315 if dataset.distributed or distributed:
# --> 316     return self._read_distributed_file(dataset=dataset, nlp=nlp)
#     317 else:
#     318     return self._read_centralized_file(dataset=dataset)
#
# File ~/projects/appvocai-discover/discover/infra/persistence/repo/dataset.py:347, in DatasetRepo._read_distributed_file(self, dataset, nlp)
#     337 """
#     338 Reads a dataset's content from a distributed file system.
#     339
#    (...)
#     344     pyspark.sql.DataFrame: The content of the dataset.
#     345 """
#     346 nlp = dataset.nlp or nlp
# --> 347 return self._fao_dfs.read(filepath=dataset.storage_location, nlp=nlp)
#
# File ~/projects/appvocai-discover/discover/infra/persistence/dal/fao/base.py:86, in FileSystemFAO.read(self, filepath, **kwargs)
#      70 def read(
#      71     self, filepath: str, **kwargs
#      72 ) -> Union[pd.DataFrame, pyspark.sql.DataFrame]:
#      73     """
#      74     Reads data from a file at the specified filepath.
#      75
#    (...)
#      84         Union[pd.DataFrame, pyspark.sql.DataFrame]: The data read from the file.
#      85     """
# ---> 86     return self._read(filepath=filepath, **kwargs)
#
# File ~/projects/appvocai-discover/discover/infra/persistence/dal/fao/distributed.py:81, in DistributedFileSystemFAO._read(self, filepath, nlp)
#      62 """
#      63 Reads a Parquet file from a specified filepath using PySpark.
#      64
#    (...)
#      78         Parquet file, including cases where the file is not found.
#      79 """
#      80 try:
# ---> 81     spark_session = self._session_pool.get_or_create(nlp=nlp)
#      82 except FileNotFoundError as e:
#      83     msg = f"Exception occurred while reading a Parquet file from {filepath}.File does not exist.\n{e}"
#
# File ~/projects/appvocai-discover/discover/infra/service/spark/session.py:115, in SparkSessionPool.get_or_create(self, nlp)
#     109     spark_session = self._create_session(
#     110         memory=self._spark_config.memory,
#     111         parquet_block_size=self._spark_config.parquet_block_size,
#     112         retries=self._spark_config.retries,
#     113     )
#     114 else:
# --> 115     spark_session = self._create_nlp_session(
#     116         memory=self._spark_config.memory,
#     117         parquet_block_size=self._spark_config.parquet_block_size,
#     118         retries=self._spark_config.retries,
#     119     )
#     120 atexit.register(shutdown, spark_session)
#     121 return spark_session
#
# File ~/projects/appvocai-discover/discover/infra/service/spark/session.py:249, in SparkSessionPool._create_nlp_session(self, memory, parquet_block_size, retries)
#     218 log4j_conf_path = "file:" + os.path.abspath("log4j.properties")
#     219 self._logger.debug(
#     220     f"Creating an SparkNLP session. log4j Configuration: {log4j_conf_path}"
#     221 )
#     222 spark = (
#     223     SparkSession.builder.appName("appvocai-discover-nlp")
#     224     .master("local[*]")
#     225     .config("spark.driver.memory", memory)
#     226     .config("spark.executor.memory", memory)
#     227     .config("spark.sql.parquet.block.size", parquet_block_size)
#     228     .config("spark.sql.execution.arrow.pyspark.enabled", "true")
#     229     .config(
#     230         "spark.sql.execution.arrow.pyspark.fallback.enabled", "false"
#     231     )
#     232     .config(
#     233         "spark.serializer", "org.apache.spark.serializer.KryoSerializer"
#     234     )
#     235     .config("spark.kryoserializer.buffer.max", "2000M")
#     236     .config("spark.driver.maxResultSize", "0")
#     237     .config(
#     238         "spark.jars.packages",
#     239         "com.johnsnowlabs.nlp:spark-nlp_2.12:5.3.3",
#     240     )
#     241     .config(
#     242         "spark.driver.extraJavaOptions",
#     243         f"-Dlog4j.configurationFile={log4j_conf_path}",
#     244     )
#     245     .config(
#     246         "spark.executor.extraJavaOptions",
#     247         f"-Dlog4j.configurationFile={log4j_conf_path}",
#     248     )
# --> 249     .getOrCreate()
#     250 )
#     251 spark.sparkContext.setLogLevel("ERROR")
#     252 return spark
#
# File ~/miniconda3/envs/appvocai/lib/python3.10/site-packages/pyspark/sql/session.py:503, in SparkSession.Builder.getOrCreate(self)
#     500     session = SparkSession(sc, options=self._options)
#     501 else:
#     502     getattr(
# --> 503         getattr(session._jvm, "SparkSession$"), "MODULE$"
#     504     ).applyModifiableSettings(session._jsparkSession, self._options)
#     505 return session
#
# File ~/miniconda3/envs/appvocai/lib/python3.10/site-packages/py4j/java_gateway.py:1712, in JVMView.__getattr__(self, name)
#    1709 if name == UserHelpAutoCompletion.KEY:
#    1710     return UserHelpAutoCompletion()
# -> 1712 answer = self._gateway_client.send_command(
#    1713     proto.REFLECTION_COMMAND_NAME +
#    1714     proto.REFL_GET_UNKNOWN_SUB_COMMAND_NAME + name + "\n" + self._id +
#    1715     "\n" + proto.END_COMMAND_PART)
#    1716 if answer == proto.SUCCESS_PACKAGE:
#    1717     return JavaPackage(name, self._gateway_client, jvm_id=self._id)
#
# File ~/miniconda3/envs/appvocai/lib/python3.10/site-packages/py4j/java_gateway.py:1036, in GatewayClient.send_command(self, command, retry, binary)
#    1015 def send_command(self, command, retry=True, binary=False):
#    1016     """Sends a command to the JVM. This method is not intended to be
#    1017        called directly by Py4J users. It is usually called by
#    1018        :class:`JavaMember` instances.
#    (...)
#    1034      if `binary` is `True`.
#    1035     """
# -> 1036     connection = self._get_connection()
#    1037     try:
#    1038         response = connection.send_command(command)
#
# File ~/miniconda3/envs/appvocai/lib/python3.10/site-packages/py4j/clientserver.py:284, in JavaClient._get_connection(self)
#     281     pass
#     283 if connection is None or connection.socket is None:
# --> 284     connection = self._create_new_connection()
#     285 return connection
#
# File ~/miniconda3/envs/appvocai/lib/python3.10/site-packages/py4j/clientserver.py:291, in JavaClient._create_new_connection(self)
#     287 def _create_new_connection(self):
#     288     connection = ClientServerConnection(
#     289         self.java_parameters, self.python_parameters,
#     290         self.gateway_property, self)
# --> 291     connection.connect_to_java_server()
#     292     self.set_thread_connection(connection)
#     293     return connection
#
# File ~/miniconda3/envs/appvocai/lib/python3.10/site-packages/py4j/clientserver.py:443, in ClientServerConnection.connect_to_java_server(self)
#     440     self.is_connected = True
#     441     self.initiated_from_client = True
# --> 443     self._authenticate_connection()
#     444 except Py4JAuthenticationError:
#     445     self.close(reset=True)
#
# File ~/miniconda3/envs/appvocai/lib/python3.10/site-packages/py4j/clientserver.py:459, in ClientServerConnection._authenticate_connection(self)
#     454 if self.java_parameters.auth_token:
#     455     cmd = "{0}\n{1}\n".format(
#     456         proto.AUTH_COMMAND_NAME,
#     457         self.java_parameters.auth_token
#     458     )
# --> 459     answer = self.send_command(cmd)
#     460     error, _ = proto.is_error(answer)
#     461     if error:
#
# File ~/miniconda3/envs/appvocai/lib/python3.10/site-packages/py4j/clientserver.py:511, in ClientServerConnection.send_command(self, command)
#     509 try:
#     510     while True:
# --> 511         answer = smart_decode(self.stream.readline()[:-1])
#     512         logger.debug("Answer received: {0}".format(answer))
#     513         # Happens when a the other end is dead. There might be an empty
#     514         # answer before the socket raises an error.
#
# File ~/miniconda3/envs/appvocai/lib/python3.10/socket.py:705, in SocketIO.readinto(self, b)
#     703 while True:
#     704     try:
# --> 705         return self._sock.recv_into(b)
#     706     except timeout:
#     707         self._timeout_occurred = True
#
# KeyboardInterrupt:
# [Stage 34:> (0 + 15) / 15][Stage 35:>  (0 + 9) / 15][Stage 36:>  (0 + 0) / 15]
