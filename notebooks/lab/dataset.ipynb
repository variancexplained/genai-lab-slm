# %% [markdown]
# # Dataset Lab

# %%
from discover.infra.utils.file.io import IOService

# %%
from datetime import datetime


fp = "data/raw/reviews"
df = IOService.read(fp)
df2 = df.loc[df["date"] > datetime(2023, 1, 1)]
df2.head()
# Out:
#                 id     app_id                      app_name category_id  \
# 12719  10177751481  379693831  Audible: Audio Entertainment        6018
# 12722  10174873952  379693831  Audible: Audio Entertainment        6018
# 12723  10143484989  379693831  Audible: Audio Entertainment        6018
# 12724  10162566169  379693831  Audible: Audio Entertainment        6018
# 12725  10141087483  379693831  Audible: Audio Entertainment        6018
#
#                      author  rating  \
# 12719  0adc7b114a95fca74f1d     5.0
# 12722  8513752c1f2b823ee2d5     5.0
# 12723  f42a8fcce66c13bb97fb     5.0
# 12724  69c87165abf3230be356     2.0
# 12725  8dbad62e3d5c43dfdf56     5.0
#
#                                                  content  vote_sum  \
# 12719  Excelente libro estoy pasando por una rotura d...         0
# 12722  El mejor libro que he leído en mi vida! Lo vol...         0
# 12723                  Un excelente libro. Buen narrado.         0
# ...
