# %% [markdown]
# # Dataset Lab

# %%
from discover.infra.utils.file.io import IOService
import pandas as pd

# %%
from datetime import datetime


fp = "workspace/dev/dataset/01_dataprep/appvocai_discover-01_dataprep-02_nlp-review-dataset.parquet"
df = IOService.read(fp)
df.head()
# Out:
#            id      app_id                        app_name category_id  \
# 0  6820417815   521227008  Audiobooks.com: Get audiobooks        6018
# 1  6821034342   466446054     cloudLibrary by bibliotheca        6018
# 2  6824778204  1492654676  POCKET COMICS: Premium Webtoon        6018
# 3  6826980171  1248062869  Lure: Interactive Chat Stories        6018
# 4  6828395114  1076402606             Libby, by OverDrive        6018
#
#                  author  rating  \
# 0  d1e8eb407847e0422c7b       4
# 1  d2b8d2519dbd0a3d9e76       5
# 2  92be615c4beec31b0db6       3
# 3  62b165e509cd67d2b2f3       1
# 4  6ca53a438d4c9ff67a79       5
#
#                                              content  vote_sum  vote_count  \
# 0  Ive been looking to get listen to audiobooks a...         0           0
# 1  The interface isnt as slick as kindle or audib...         0           0
# 2  I love the app and the fact that on good stori...         0           0
# 3  Hi the app is amazing and stories are really g...         0           0
# 4  I love how easy it is to borrow books using th...         0           0
#
#                  date  review_length  dc_non_english_app_name  \
# 0 2021-01-02 04:17:00            106                    False
# 1 2021-01-02 07:47:00             12                    False
# 2 2021-01-03 05:46:00             97                    False
# 3 2021-01-03 18:37:00             65                    False
# 4 2021-01-04 03:45:00             56                    False
#
#    dc_non_english_review  __index_level_0__  \
# 0                  False             486629
# 1                  False             595713
# 2                  False             755309
# 3                  False             749155
# 4                  False             416719
#
#                                               tokens  \
# 0  [Ive, been, looking, to, get, listen, to, audi...
# 1  [The, interface, isnt, as, slick, as, kindle, ...
# 2  [I, love, the, app, and, the, fact, that, on, ...
# 3  [Hi, the, app, is, amazing, and, stories, are,...
# 4  [I, love, how, easy, it, is, to, borrow, books...
#
#                                                  pos category
# 0  [AUX, AUX, VERB, PART, VERB, VERB, ADP, VERB, ...     Book
# 1  [DET, NOUN, NOUN, ADV, ADJ, ADP, NOUN, CCONJ, ...     Book
# 2  [PRON, VERB, DET, NOUN, CCONJ, DET, NOUN, SCON...     Book
# 3  [INTJ, DET, NOUN, AUX, ADJ, CCONJ, NOUN, AUX, ...     Book
# 4  [PRON, VERB, ADV, ADJ, PRON, VERB, PART, VERB,...     Book
