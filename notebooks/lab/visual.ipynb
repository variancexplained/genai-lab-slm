# %% [markdown]
# # Visualization Lab

# %%
import numpy as np
from genailabslm.infra.utils.file.io import IOService
from genailabslm.app.bivariate import CorrelationPlot
from genailabslm.app.eda import EDA

# %%
fp = "workspace/prod/dataset/01_dataprep/appvocai_discover-01_dataprep-02_clean-review-dataset.parquet"

# %%
df = IOService.read(filepath=fp)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[12], line 2
#       1 df = IOService.read(filepath=fp)
# ----> 2 eda = EDA(df=df)
#       3 eda.overview()
#
# File ~/projects/genai-lab-slm/discover/app/eda.py:89, in EDA.__init__(self, df)
#      88 def __init__(self, df: pd.DataFrame) -> None:
# ---> 89     self._df = df[columns.keys()]
#      90     self._df = self._df.convert_dtypes(convert_string=True)
#      91     self._distribution = Distribution()
#
# File ~/miniconda3/envs/appvocai/lib/python3.10/site-packages/pandas/core/frame.py:4108, in DataFrame.__getitem__(self, key)
#    4106     if is_iterator(key):
#    4107         key = list(key)
# -> 4108     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    4110 # take() does not accept boolean indexers
#    4111 if getattr(indexer, "dtype", None) == bool:
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20877483 entries, 0 to 20877482
# Data columns (total 11 columns):
#  #   Column       Dtype
# ---  ------       -----
#  0   id           string
#  1   app_id       string
#  2   app_name     string
#  3   category_id  category
#  4   author       string
#  5   rating       int16
#  6   content      object
#  7   vote_sum     int64
#  8   vote_count   int64
#  9   date         datetime64[ms]
#  10  category     category
# dtypes: category(2), datetime64[ms](1), int16(1), int64(2), object(1), string(4)
# memory usage: 1.3+ GB

# %%
ndf = df.select_dtypes(include=np.number)
p = CorrelationPlot()
p(df=ndf)
