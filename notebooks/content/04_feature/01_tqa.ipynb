# %%
import warnings

warnings.filterwarnings("ignore")
import os

if "jbook" in os.getcwd():
    os.chdir(os.path.abspath(os.path.join("../..")))
FORCE = True

# %% [markdown]
# # Text Quality Analysis
# ---

# %% [markdown]
# ### Import Libraries
# ---

# %%
from genailab.setup import auto_wire_container
from genailab.core.dtypes import DFType
from genailab.infra.utils.file.fileset import FileFormat
from genailab.asset.dataset.config import DatasetConfig
from genailab.flow.feature.tqa.builder import TQAStageBuilder
from genailab.asset.dataset.config import DatasetConfig
from genailab.core.flow import PhaseDef, StageDef


# Wire container
container = auto_wire_container()

# %% [markdown]
# ## Dask Analyst

# %%
# Source Dataset Configuration
source_config = DatasetConfig(
    phase=PhaseDef.DATAPREP,
    stage=StageDef.CLEAN,
    name="review",
    file_format=FileFormat.PARQUET,
    asset_type="dataset",
    dftype=DFType.PANDAS,
)

# Target Dataset Configuration
target_config = DatasetConfig(
    phase=PhaseDef.FEATURE,
    stage=StageDef.TQA,
    name="review",
    file_format=FileFormat.PARQUET,
    asset_type="dataset",
    dftype=DFType.PANDAS,
)

# %%
# Create builder
stage = (
    TQAStageBuilder()
        .with_dask(normalized=True, batched=False)
        .build(source_config=source_config, target_config=target_config))
# Run the stage
dataset = stage.run(force=FORCE)
# Out:
# [01/31/2025 05:23:54 PM] [DEBUG] [genailab.infra.persist.repo.object.rao.RAO] [__init__] : RAO created at workspace/test/datasets/ral/
# [01/31/2025 05:23:54 PM] [DEBUG] [genailab.infra.persist.repo.object.dao.DAO] [__init__] : DAO created at workspace/test/datasets/dal/
# [01/31/2025 05:23:55 PM] [DEBUG] [genailab.flow.base.stage.TQAStage] [run] : Inside TQAStage: run
# [01/31/2025 05:23:55 PM] [DEBUG] [genailab.flow.base.stage.TQAStage] [_dataset_exists] : Inside TQAStage: _dataset_exists
# [01/31/2025 05:23:55 PM] [DEBUG] [genailab.flow.base.stage.TQAStage] [_fresh_cache_exists] : Inside TQAStage: _fresh_cache_exists
# [01/31/2025 05:23:55 PM] [DEBUG] [genailab.flow.base.stage.TQAStage] [_get_dataset] : Inside TQAStage: _get_dataset
# [01/31/2025 05:23:55 PM] [DEBUG] [genailab.flow.base.stage.TQAStage] [_dataset_exists] : Inside TQAStage: _dataset_exists
# [01/31/2025 05:23:55 PM] [DEBUG] [genailab.flow.base.stage.TQAStage] [_fresh_cache_exists] : The target dataset cache for Feature Engineering Phase/Text Quality Analysis Stage does not exist in the repository.
# [01/31/2025 05:23:55 PM] [DEBUG] [genailab.flow.base.stage.TQAStage] [_run] : Inside TQAStage: _run
# [01/31/2025 05:23:55 PM] [DEBUG] [genailab.flow.base.stage.TQAStage] [_remove_dataset] : Inside TQAStage: _remove_dataset
# [01/31/2025 05:23:55 PM] [DEBUG] [genailab.flow.base.stage.TQAStage] [_get_dataset] : Inside TQAStage: _get_dataset
# [01/31/2025 05:23:55 PM] [DEBUG] [root] [get_reader] : Requesting a pandas_parquet reader from the DataFrameIOFactory
# [01/31/2025 05:23:55 PM] [DEBUG] [genailab.infra.persist.repo.file.pandas.PandasDataFrameParquetReader] [read] : PandasDataFrameParquetReader read from workspace/test/datasets/fal/dataprep/dataprep_clean_dataset_review.parquet
# [01/31/2025 05:23:55 PM] [DEBUG] [genailab.asset.dataset.state.DatasetState] [add_event] : Added {'timestamp': datetime.datetime(2025, 1, 31, 17, 23, 55, 684892), 'entity': 'TQAStage', 'event': 'Accessed by TQAStage'} to the event log at 2025-01-31 17:23:55.684896.
# [01/31/2025 05:23:55 PM] [DEBUG] [genailab.asset.dataset.state.DatasetState] [access] : Dataset accessed by TQAStage at 2025-01-31 17:23:55.684883
# [01/31/2025 05:23:55 PM] [DEBUG] [genailab.flow.base.stage.TQAStage] [_validate_dataframe_type] : Inside TQAStage: _validate_dataframe_type
# # ============================================================================== #
# #             Text Quality Analysis Stage Fri, 31 Jan 2025 17:23:55              #
# # ============================================================================== #
# [01/31/2025 05:23:55 PM] [DEBUG] [genailab.flow.feature.tqa.task.TQAnalystDask] [analyze] : Inside TQAnalystDask: analyze
# [01/31/2025 05:23:55 PM] [DEBUG] [asyncio] [__init__] : Using selector: EpollSelector
# [01/31/2025 05:23:57 PM] [DEBUG] [genailab.flow.feature.tqa.task.TQAnalystDask] [to_dash] : Inside TQAnalystDask: to_dash
# [01/31/2025 05:23:57 PM] [DEBUG] [genailab.flow.feature.tqa.task.TQAnalystDask] [analyze] : Converted pandas to <class 'dask.dataframe.core.DataFrame'>..
# [01/31/2025 05:23:57 PM] [DEBUG] [genailab.flow.feature.tqa.task.TQAnalystDask] [analyze] : Processing row at a time..
# [01/31/2025 05:23:58 PM] [DEBUG] [genailab.flow.feature.tqa.task.TQAnalystDask] [analyze] : Persisted results of type <class 'dask.dataframe.core.DataFrame'>.
# 2025-01-31 17:24:15,186 - distributed.worker - WARNING - Compute Failed
# Key:       ('apply-82525338bbc19b1a7e5566135f44957a', 10)
# Function:  subgraph_callable-18882d88-1218-4e25-92ed-8db34805
# args:      (              id      app_id                   app_name category_id  \
# 1666  7206339760   634598719  Noom: Healthy Weight Loss        6013
# 1867  8234346929  1505852279            Colgate Connect        6013
#
#                     author  rating  \
# 1666  ea33b3bca0d17d3a3125       5
# 1867  fec663b6c641d8fa5c0a       5
#
#                                                 content  vote_sum  vote_count  \
# 1666  i have been up and down a lot this time i am l...         0           0
# 1867  my teeth have never felt so clean me and my fi...         0           0
#
#                           date          category
# 1666 2021-04-10 14:15:14+00:00  Health & Fitness
# 1867 2022-01-13 03:49:12+00:00  Health & Fitness  , <function TQAnalystDask.analyze.<locals>.<lambda> at 0x7ff3d1589280>, 'from_pandas-2930a2eb8d99b5429642156c368c7fef')
# kwargs:    {}
# Exception: 'AttributeError("\'DataFrame\' object has no attribute \'name\'")'
#
# 2025-01-31 17:24:15,193 - distributed.worker - WARNING - Compute Failed
# Key:       ('apply-82525338bbc19b1a7e5566135f44957a', 11)
# Function:  subgraph_callable-18882d88-1218-4e25-92ed-8db34805
# args:      (              id      app_id                      app_name category_id  \
# 1893  8338754494  1244690083  Sleepiest: Sleep Meditations        6013
# 2037  8946082330  1415922936               KIRA STOKES FIT        6013
#
#                     author  rating  \
# 1893  16d4cf02a8c3a048be0b       5
# 2037  aeb8fffa9d7f176ecdab       5
#
#                                                 content  vote_sum  vote_count  \
# 1893                         love it total game changer         0           0
# 2037  i found kira just at the right moment in my li...         0           0
#
#                           date          category
# 1893 2022-02-10 05:21:13+00:00  Health & Fitness
# 2037 2022-08-05 02:44:44+00:00  Health & Fitness  , <function TQAnalystDask.analyze.<locals>.<lambda> at 0x7ff3d3b5d1f0>, 'from_pandas-2930a2eb8d99b5429642156c368c7fef')
# kwargs:    {}
# Exception: 'AttributeError("\'DataFrame\' object has no attribute \'name\'")'
#
# 2025-01-31 17:24:15,200 - distributed.worker - WARNING - Compute Failed
# Key:       ('apply-82525338bbc19b1a7e5566135f44957a', 15)
# Function:  subgraph_callable-18882d88-1218-4e25-92ed-8db34805
# args:      (               id      app_id                        app_name category_id  \
# 2974  10108342074  1500855883           CapCut - Video Editor        6008
# 3193   9244896171   544007664  YouTube: Watch, Listen, Stream        6008
#
#                     author  rating  \
# 2974  c2a33925c7a1e2ccdc65       5
# 3193  27df2ccb87562aaea805       5
#
#                                                 content  vote_sum  vote_count  \
# 2974                      bro doesnt let me download it         0           0
# 3193  never leave reviews on stuff and jus saying th...         0           0
#
#                           date       category
# 2974 2023-07-06 01:17:31+00:00  Photo & Video
# 3193 2022-11-01 19:13:45+00:00  Photo & Video  , <function TQAnalystDask.analyze.<locals>.<lambda> at 0x7ff3d360f160>, 'from_pandas-2930a2eb8d99b5429642156c368c7fef')
# kwargs:    {}
# Exception: 'AttributeError("\'DataFrame\' object has no attribute \'name\'")'
#
# 2025-01-31 17:24:15,207 - distributed.worker - WARNING - Compute Failed
# Key:       ('apply-82525338bbc19b1a7e5566135f44957a', 14)
# Function:  subgraph_callable-18882d88-1218-4e25-92ed-8db34805
# args:      (               id      app_id                       app_name category_id  \
# 2358  10224348275   547702041  Tinder - Dating. Meet Friends        6012
# 2468   7845786577  1374212456    Hint: Horoscope & Astrology        6012
#
#                     author  rating  \
# 2358  e489289dd51a734e0fc7       1
# 2468  71fbb1807705dc887246       1
#
#                                                 content  vote_sum  vote_count  \
# 2358  without any reason these people banned me on t...         0           0
# 2468  dont waste your time or money with this app ho...         0           0
#
#                           date   category
# 2358 2023-08-06 01:23:18+00:00  Lifestyle
# 2468 2021-09-26 02:50:06+00:00  Lifestyle  , <function TQAnalystDask.analyze.<locals>.<lambda> at 0x7ff3ad2949d0>, 'from_pandas-2930a2eb8d99b5429642156c368c7fef')
# kwargs:    {}
# Exception: 'AttributeError("\'DataFrame\' object has no attribute \'name\'")'
#
# 2025-01-31 17:24:15,214 - distributed.worker - WARNING - Compute Failed
# Key:       ('apply-82525338bbc19b1a7e5566135f44957a', 13)
# Function:  subgraph_callable-18882d88-1218-4e25-92ed-8db34805
# args:      (               id      app_id                      app_name category_id  \
# 2300   9910752552  1158048301                   Hatch Sleep        6013
# 2343  10131221891   930441707  Bumble: Dating App & Friends        6012
#
#                     author  rating  \
# 2300  27b6eaa98b5942896788       2
# 2343  f83ab4eb4a4c5d323dc1       1
#
#                                                 content  vote_sum  vote_count  \
# 2300  the device and app was perfect with no flaws b...         0           0
# 2343  they keep sending me hookers and gold diggers ...         0           0
#
#                           date          category
# 2300 2023-05-10 01:44:40+00:00  Health & Fitness
# 2343 2023-07-12 08:28:36+00:00         Lifestyle  , <function TQAnalystDask.analyze.<locals>.<lambda> at 0x7ff3d3b63700>, 'from_pandas-2930a2eb8d99b5429642156c368c7fef')
# kwargs:    {}
# Exception: 'AttributeError("\'DataFrame\' object has no attribute \'name\'")'
#
# 2025-01-31 17:24:15,221 - distributed.worker - WARNING - Compute Failed
# Key:       ('apply-82525338bbc19b1a7e5566135f44957a', 1)
# Function:  subgraph_callable-18882d88-1218-4e25-92ed-8db34805
# args:      (             id      app_id                      app_name category_id  \
# 201  7114159658  1451754591             DoorDash - Dasher        6000
# 221  7387684046   383126470  When I Work Staff Scheduling        6000
#
#                    author  rating  \
# 201  9a150ed242f485591115       4
# 221  645c07694d728e598788       5
#
#                                                content  vote_sum  vote_count  \
# 201              thank you for the opportunity to work         0           0
# 221  great for keeping schedule and the great reminder         0           0
#
#                          date  category
# 201 2021-03-17 19:30:00+00:00  Business
# 221 2021-05-25 18:54:00+00:00  Business  , <function TQAnalystDask.analyze.<locals>.<lambda> at 0x7ff3d131aaf0>, 'from_pandas-2930a2eb8d99b5429642156c368c7fef')
# kwargs:    {}
# Exception: 'AttributeError("\'DataFrame\' object has no attribute \'name\'")'
#
# 2025-01-31 17:24:15,228 - distributed.worker - WARNING - Compute Failed
# Key:       ('apply-82525338bbc19b1a7e5566135f44957a', 12)
# Function:  subgraph_callable-18882d88-1218-4e25-92ed-8db34805
# args:      (              id      app_id                   app_name category_id  \
# 2084  9136822990  1067860796  Asana Rebel: Get in Shape        6013
# 2174  9494232503  1032100065          Collective Health        6013
#
#                     author  rating  \
# 2084  1a9361c8176e52a8204e       3
# 2174  c4787ea4a01afbbe23b0       1
#
#                                                 content  vote_sum  vote_count  \
# 2084  it seems so simple to want to prop your ipad u...         0           0
# 2174  get care tab never loads properly so the searc...         0           0
#
#                           date          category
# 2084 2022-09-30 15:13:48+00:00  Health & Fitness
# 2174 2023-01-11 03:59:21+00:00  Health & Fitness  , <function TQAnalystDask.analyze.<locals>.<lambda> at 0x7ff3d360f0d0>, 'from_pandas-2930a2eb8d99b5429642156c368c7fef')
# kwargs:    {}
# Exception: 'AttributeError("\'DataFrame\' object has no attribute \'name\'")'
#
# 2025-01-31 17:24:15,235 - distributed.worker - WARNING - Compute Failed
# Key:       ('apply-82525338bbc19b1a7e5566135f44957a', 0)
# Function:  subgraph_callable-18882d88-1218-4e25-92ed-8db34805
# args:      (             id      app_id                       app_name category_id  \
# 0   10019409512  1380362212   GALATEA: Novels & Audiobooks        6018
# 49   7693850242  1031002863  Color Therapy Coloring Number        6018
#
#                   author  rating  \
# 0   c011c66aae3e668b150e       5
# 49  c81f4a644dcf09fa62e7       5
#
#                                               content  vote_sum  vote_count  \
# 0   i love it but the chapter and waiting hours fo...         0           0
# 49  hi everyone crystalclearart here thought id ta...         0           0
#
#                         date category
# 0  2023-06-10 15:09:00+00:00     Book
# 49 2021-08-15 01:47:00+00:00     Book  , <function TQAnalystDask.analyze.<locals>.<lambda> at 0x7ff3d131a280>, 'from_pandas-2930a2eb8d99b5429642156c368c7fef')
# kwargs:    {}
# Exception: 'AttributeError("\'DataFrame\' object has no attribute \'name\'")'
#
# 2025-01-31 17:24:20,199 - distributed.worker - WARNING - Compute Failed
# Key:       ('apply-82525338bbc19b1a7e5566135f44957a', 22)
# Function:  subgraph_callable-18882d88-1218-4e25-92ed-8db34805
# args:      (              id     app_id app_name category_id                author  \
# 3794  9752761243  282935706    Bible        6006  1bcaa8a2c46ca8ba0c48
#
#       rating                                            content  vote_sum  \
# 3794       5  its a wonderful app that allows you to get an ...         0
#
#       vote_count                      date   category
# 3794           0 2023-03-26 04:50:12+00:00  Reference  , <function TQAnalystDask.analyze.<locals>.<lambda> at 0x7ff3d131c8b0>, 'from_pandas-2930a2eb8d99b5429642156c368c7fef')
# kwargs:    {}
# Exception: 'AttributeError("\'DataFrame\' object has no attribute \'name\'")'
#
# 2025-01-31 17:24:20,209 - distributed.worker - WARNING - Compute Failed
# Key:       ('apply-82525338bbc19b1a7e5566135f44957a', 19)
# Function:  subgraph_callable-18882d88-1218-4e25-92ed-8db34805
# args:      (              id     app_id app_name category_id                author  \
# 3672  9059687334  282935706    Bible        6006  26cc2a5aa99211a23722
#
#       rating                                            content  vote_sum  \
# 3672       5  my daughter and i have this app and we both lo...         0
#
#       vote_count                      date   category
# 3672           0 2022-09-07 01:43:43+00:00  Reference  , <function TQAnalystDask.analyze.<locals>.<lambda> at 0x7ff3d3ece1f0>, 'from_pandas-2930a2eb8d99b5429642156c368c7fef')
# kwargs:    {}
# Exception: 'AttributeError("\'DataFrame\' object has no attribute \'name\'")'
#
# 2025-01-31 17:24:20,221 - distributed.worker - WARNING - Compute Failed
# Key:       ('apply-82525338bbc19b1a7e5566135f44957a', 20)
# Function:  subgraph_callable-18882d88-1218-4e25-92ed-8db34805
# args:      (              id      app_id                       app_name category_id  \
# 3697  9235261951  1581370229  KnowMe-AI Face Editor&Quizzes        6006
#
#                     author  rating  \
# 3697  590f7bdd9d51e38322a5       5
#
#                                                 content  vote_sum  vote_count  \
# 3697  im only giving you five star so people can see...         0           0
#
#                           date   category
# 3697 2022-10-29 22:36:42+00:00  Reference  , <function TQAnalystDask.analyze.<locals>.<lambda> at 0x7ff3af4cda60>, 'from_pandas-2930a2eb8d99b5429642156c368c7fef')
# kwargs:    {}
# Exception: 'AttributeError("\'DataFrame\' object has no attribute \'name\'")'
#
# 2025-01-31 17:24:20,242 - distributed.worker - WARNING - Compute Failed
# Key:       ('apply-82525338bbc19b1a7e5566135f44957a', 21)
# Function:  subgraph_callable-18882d88-1218-4e25-92ed-8db34805
# args:      (              id     app_id app_name category_id                author  \
# 3702  9287550281  282935706    Bible        6006  f93469ea03700d92981b
#
#       rating                                            content  vote_sum  \
# 3702       5  overall just an amazing app offline mode is ve...         0
#
#       vote_count                      date   category
# 3702           0 2022-11-14 04:02:03+00:00  Reference  , <function TQAnalystDask.analyze.<locals>.<lambda> at 0x7ff3d131c160>, 'from_pandas-2930a2eb8d99b5429642156c368c7fef')
# kwargs:    {}
# Exception: 'AttributeError("\'DataFrame\' object has no attribute \'name\'")'
#
# 2025-01-31 17:24:20,415 - distributed.worker - WARNING - Compute Failed
# Key:       ('apply-82525338bbc19b1a7e5566135f44957a', 18)
# Function:  subgraph_callable-18882d88-1218-4e25-92ed-8db34805
# args:      (              id     app_id app_name category_id                author  \
# 3661  8997904455  282935706    Bible        6006  9dc1a7702e1affb80eae
#
#       rating                                            content  vote_sum  \
# 3661       5  so glad to have bible at my fingertips and wit...         0
#
#       vote_count                      date   category
# 3661           0 2022-08-20 11:53:25+00:00  Reference  , <function TQAnalystDask.analyze.<locals>.<lambda> at 0x7ff3d3ece310>, 'from_pandas-2930a2eb8d99b5429642156c368c7fef')
# kwargs:    {}
# Exception: 'AttributeError("\'DataFrame\' object has no attribute \'name\'")'
#
# 2025-01-31 17:24:20,448 - distributed.worker - WARNING - Compute Failed
# Key:       ('apply-82525338bbc19b1a7e5566135f44957a', 17)
# Function:  subgraph_callable-18882d88-1218-4e25-92ed-8db34805
# args:      (              id     app_id app_name category_id                author  \
# 3474  6904589879  282935706    Bible        6006  a64ee6d423a0bb9f9c21
# 3560  8049227399  282935706    Bible        6006  88ad49d0447eeb80e551
#
#       rating                                            content  vote_sum  \
# 3474       5  im glad i downloaded this app and learn so muc...         0
# 3560       5               birds are not more valuable than man         0
#
#       vote_count                      date   category
# 3474           0 2021-01-23 16:39:29+00:00  Reference
# 3560           0 2021-11-21 22:42:17+00:00  Reference  , <function TQAnalystDask.analyze.<locals>.<lambda> at 0x7ff3af4cdc10>, 'from_pandas-2930a2eb8d99b5429642156c368c7fef')
# kwargs:    {}
# Exception: 'AttributeError("\'DataFrame\' object has no attribute \'name\'")'
#
# 2025-01-31 17:24:20,485 - distributed.worker - WARNING - Compute Failed
# Key:       ('apply-82525338bbc19b1a7e5566135f44957a', 16)
# Function:  subgraph_callable-18882d88-1218-4e25-92ed-8db34805
# args:      (               id     app_id app_name category_id                author  \
# 3423  10161013174  282935706    Bible        6006  7c019a02ec207b1afbf4
# 3440  10226492097  282935706    Bible        6006  9ac10aa7db50f77a773a
#
#       rating                                            content  vote_sum  \
# 3423       5     this app helps me to keep me in god word daily         0
# 3440       5  love the way you can download may versions of ...         0
#
#       vote_count                      date   category
# 3423           0 2023-07-20 10:50:27+00:00  Reference
# 3440           0 2023-08-06 15:03:42+00:00  Reference  , <function TQAnalystDask.analyze.<locals>.<lambda> at 0x7ff3d1589430>, 'from_pandas-2930a2eb8d99b5429642156c368c7fef')
# kwargs:    {}
# Exception: 'AttributeError("\'DataFrame\' object has no attribute \'name\'")'
#
# [01/31/2025 05:24:20 PM] [ERROR] [genailab.flow.base.stage.TQAStage] [_run] : Error in task TQATask: 'DataFrame' object has no attribute 'name'
# [01/31/2025 05:24:20 PM] [ERROR] [Stage.run] [wrapper] : Exception occurred in Stage.run called with force=True
# Error in task TQATask: 'DataFrame' object has no attribute 'name'
# Traceback (most recent call last):
#   File "/home/john/projects/genailab/genailab/flow/feature/tqa/stage.py", line 94, in _run
#     dataframe = task.run(dataframe)
#   File "/home/john/projects/genailab/genailab/flow/feature/tqa/task.py", line 147, in run
#     return self._analyst.analyze(data=data)
#   File "/home/john/projects/genailab/genailab/flow/feature/tqa/task.py", line 369, in analyze
#     results = results.compute()
#   File "/home/john/miniconda3/envs/genai/lib/python3.8/site-packages/dask/base.py", line 314, in compute
#     (result,) = compute(self, traverse=False, **kwargs)
#   File "/home/john/miniconda3/envs/genai/lib/python3.8/site-packages/dask/base.py", line 599, in compute
#     results = schedule(dsk, keys, **kwargs)
#   File "/home/john/miniconda3/envs/genai/lib/python3.8/site-packages/distributed/client.py", line 3226, in get
#     results = self.gather(packed, asynchronous=asynchronous, direct=direct)
#   File "/home/john/miniconda3/envs/genai/lib/python3.8/site-packages/distributed/client.py", line 2361, in gather
#     return self.sync(
#   File "/home/john/miniconda3/envs/genai/lib/python3.8/site-packages/distributed/utils.py", line 351, in sync
#     return sync(
#   File "/home/john/miniconda3/envs/genai/lib/python3.8/site-packages/distributed/utils.py", line 418, in sync
#     raise exc.with_traceback(tb)
#   File "/home/john/miniconda3/envs/genai/lib/python3.8/site-packages/distributed/utils.py", line 391, in f
#     result = yield future
#   File "/home/john/miniconda3/envs/genai/lib/python3.8/site-packages/tornado/gen.py", line 766, in run
#     value = future.result()
#   File "/home/john/miniconda3/envs/genai/lib/python3.8/site-packages/distributed/client.py", line 2224, in _gather
#     raise exception.with_traceback(traceback)
#   File "/home/john/miniconda3/envs/genai/lib/python3.8/site-packages/dask/optimization.py", line 990, in __call__
#     return core.get(self.dsk, self.outkey, dict(zip(self.inkeys, args)))
#   File "/home/john/miniconda3/envs/genai/lib/python3.8/site-packages/dask/core.py", line 149, in get
#     result = _execute_task(task, cache)
#   File "/home/john/miniconda3/envs/genai/lib/python3.8/site-packages/dask/core.py", line 119, in _execute_task
#     return func(*(_execute_task(a, cache) for a in args))
#   File "/home/john/miniconda3/envs/genai/lib/python3.8/site-packages/dask/utils.py", line 73, in apply
#     return func(*args, **kwargs)
#   File "/home/john/miniconda3/envs/genai/lib/python3.8/site-packages/dask/dataframe/core.py", line 7031, in apply_and_enforce
#     c = meta.name
#   File "/home/john/miniconda3/envs/genai/lib/python3.8/site-packages/pandas/core/generic.py", line 5989, in __getattr__
#     return object.__getattribute__(self, name)
# AttributeError: 'DataFrame' object has no attribute 'name'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/john/projects/genailab/genailab/infra/service/logging/stage.py", line 58, in wrapper
#     result = func(self, *args, **kwargs)
#   File "/home/john/projects/genailab/genailab/flow/base/stage.py", line 147, in run
#     return self._run()
#   File "/home/john/projects/genailab/genailab/flow/feature/tqa/stage.py", line 97, in _run
#     raise RuntimeError(f"Error in task {task.__class__.__name__}: {e}")
# RuntimeError: Error in task TQATask: 'DataFrame' object has no attribute 'name'
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~/projects/genailab/genailab/flow/feature/tqa/stage.py in ?(self)
#      95             except Exception as e:
#      96                 self._logger.error(f"Error in task {task.__class__.__name__}: {e}")
# ---> 97                 raise RuntimeError(f"Error in task {task.__class__.__name__}: {e}")
#      98
#
# ~/projects/genailab/genailab/flow/feature/tqa/task.py in ?(self, data)
#     145             pd.DataFrame: A DataFrame with the computed syntactic features and TQA score for each review.
#     146         """
# --> 147         return self._analyst.analyze(data=data)
#
# ~/projects/genailab/genailab/flow/feature/tqa/task.py in ?(self, data)
#     380                 client.close()
#     381             if cluster:
# --> 382                 cluster.close()
#
# ~/miniconda3/envs/genai/lib/python3.8/site-packages/dask/base.py in ?(self, **kwargs)
#     312         dask.compute
#     313         """
# --> 314         (result,) = compute(self, traverse=False, **kwargs)
#     315         return result
#
# ~/miniconda3/envs/genai/lib/python3.8/site-packages/dask/base.py in ?(traverse, optimize_graph, scheduler, get, *args, **kwargs)
#     597         postcomputes.append(x.__dask_postcompute__())
#     598
# --> 599     results = schedule(dsk, keys, **kwargs)
#     600     return repack([f(r, *a) for r, (f, a) in zip(results, postcomputes)])
#
# ~/miniconda3/envs/genai/lib/python3.8/site-packages/distributed/client.py in ?(self, dsk, keys, workers, allow_other_workers, resources, sync, asynchronous, direct, retries, priority, fifo_timeout, actors, **kwargs)
#    3229                     f.release()
#    3230                 if getattr(thread_state, "key", False) and should_rejoin:
# -> 3231                     rejoin()
#    3232             return results
#
# ~/miniconda3/envs/genai/lib/python3.8/site-packages/distributed/client.py in ?(self, futures, errors, direct, asynchronous)
#    2359             else:
#    2360                 local_worker = None
# -> 2361             return self.sync(
#    2362                 self._gather,
#
# ~/miniconda3/envs/genai/lib/python3.8/site-packages/distributed/utils.py in ?(self, func, asynchronous, callback_timeout, *args, **kwargs)
#     349             return future
#     350         else:
# --> 351             return sync(
#     352                 self.loop, func, *args, callback_timeout=callback_timeout, **kwargs
#
# ~/miniconda3/envs/genai/lib/python3.8/site-packages/distributed/utils.py in ?(loop, func, callback_timeout, *args, **kwargs)
#     416     if error:
#     417         typ, exc, tb = error
# --> 418         raise exc.with_traceback(tb)
#     419     else:
#
# ~/miniconda3/envs/genai/lib/python3.8/site-packages/distributed/utils.py in ?()
#     393             error = sys.exc_info()
#     394         finally:
# --> 395             e.set()
#
# ~/miniconda3/envs/genai/lib/python3.8/site-packages/tornado/gen.py in ?(self)
#     792                     )
#     793                     self.result_future = None  # type: ignore
# --> 794                     return
#     795                 except Exception:
#
# ~/miniconda3/envs/genai/lib/python3.8/site-packages/distributed/client.py in ?(self, futures, errors, direct, local_worker)
#    2222                             exc = CancelledError(key)
#    2223                         else:
# -> 2224                             raise exception.with_traceback(traceback)
#    2225                         raise exc
#
# ~/miniconda3/envs/genai/lib/python3.8/site-packages/dask/optimization.py in ?()
# --> 990     def __call__(self, *args):
#     991         if not len(args) == len(self.inkeys):
#
# ~/miniconda3/envs/genai/lib/python3.8/site-packages/dask/core.py in ?()
# --> 149     >>> inc = lambda x: x + 1
#
# ~/miniconda3/envs/genai/lib/python3.8/site-packages/dask/core.py in ?()
# --> 119     >>> add = lambda x, y: x + y
#
# ~/miniconda3/envs/genai/lib/python3.8/site-packages/dask/utils.py in ?()
# ---> 73 def apply(func, args, kwargs=None):
#      74     """Apply a function given its positional and keyword arguments.
#
# ~/miniconda3/envs/genai/lib/python3.8/site-packages/dask/dataframe/core.py in ?()
# -> 7031 def apply_and_enforce(*args, **kwargs):
#    7032     """Apply a function, and enforce the output to match meta
#
# ~/miniconda3/envs/genai/lib/python3.8/site-packages/pandas/core/generic.py in ?()
# -> 5989     def __getattr__(self, name: str):
#    5990         """
#
# AttributeError: 'DataFrame' object has no attribute 'name'
#
# During handling of the above exception, another exception occurred:
#
# RuntimeError                              Traceback (most recent call last)
# Cell In[4], line 7
#       2 stage = (
#       3     TQAStageBuilder()
#       4         .with_dask(normalized=True, batched=False)
#       5         .build(source_config=source_config, target_config=target_config))
#       6 # Run the stage
# ----> 7 dataset = stage.run(force=FORCE)
#
# File ~/projects/genailab/genailab/infra/service/logging/stage.py:58, in stage_logger.<locals>.wrapper(self, *args, **kwargs)
#      55 start_fmt = start.strftime(format="%H:%M:%S")
#      57 # Execute the original function being decorated, passing all args and kwargs.
# ---> 58 result = func(self, *args, **kwargs)
#      60 # Log runtime.
#      61 end = datetime.now()
#
# File ~/projects/genailab/genailab/flow/base/stage.py:147, in Stage.run(self, force)
#     145         return dataset
#     146     else:
# --> 147         return self._run()
#     148 else:
#     149     self._stop_spark()
#
# File ~/projects/genailab/genailab/flow/feature/tqa/stage.py:97, in TQAStage._run(self)
#      95     except Exception as e:
#      96         self._logger.error(f"Error in task {task.__class__.__name__}: {e}")
# ---> 97         raise RuntimeError(f"Error in task {task.__class__.__name__}: {e}")
#      99 target = self._create_dataset(
#     100     source=source.passport, config=self._target_config, dataframe=dataframe
#     101 )
#     102 target = self._repo.add(dataset=target, entity=self.__class__.__name__)
#
# RuntimeError: Error in task TQATask: 'DataFrame' object has no attribute 'name'

# %%
dataset.dataframe.head()
