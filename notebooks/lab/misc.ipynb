# %%
import pandas as pd

# %%
columns = {
    "id": "core",
    "app_id": "core",
    "app_name": "core",
    "category": "core",
    "author": "core",
    "rating": "core",
    "content": "core",
    "vote_count": "core",
    "vote_sum": "core",
    "date": "core",
    "enr_review_age": "temporal",
    "enr_review_length": "lexical",
    "enr_review_month": "temporal",
    "enr_review_day_of_week": "temporal",
    "enr_review_hour": "temporal",
    "sentiment": "sentiment",
    "sentiment_classification": "sentiment",
    "enrichment_tqa_score_final": "quality",
    "enrichment_pct_deviation_rating": "deviation",
    "enrichment_pct_deviation_review_length": "deviation",
    "enrichment_pct_deviation_sentiment": "deviation",
    "enrichment_pct_deviation_tqa_score_final": "deviation",
    "pos_n_nouns": "syntactic",
    "pos_n_verbs": "syntactic",
    "pos_n_adjectives": "syntactic",
    "pos_n_adverbs": "syntactic",
    "pos_p_nouns": "syntactic",
    "pos_p_verbs": "syntactic",
    "pos_p_adjectives": "syntactic",
    "pos_p_adverbs": "syntactic",
    "stats_char_count": "lexical",
    "stats_unique_word_count": "lexical",
    "stats_unique_word_proportion": "lexical",
    "tqm_pos_count_score": "quality",
    "tqm_pos_diversity_score": "quality",
    "tqm_structural_complexity_score": "quality",
    "tqm_pos_intensity_score": "quality",
}

# %%
df = pd.DataFrame.from_dict(
    data=columns, orient="index", columns=["label"]
).reset_index(names=["column"])
df
# Out:
#                                       column      label
# 0                                         id       core
# 1                                     app_id       core
# 2                                   app_name       core
# 3                                   category       core
# 4                                     author       core
# 5                                     rating       core
# 6                                    content       core
# 7                                 vote_count       core
# 8                                   vote_sum       core
# 9                                       date       core
# 10                enr_review_age   temporal
# 11             enr_review_length    lexical
# 12              enr_review_month   temporal
# 13        enr_review_day_of_week   temporal
# 14               enr_review_hour   temporal
# 15                      sentiment  sentiment
# 16       sentiment_classification  sentiment
# ...

# %%
txt = "dqa_non_english_app_name_html"
txt = txt.replace("dqa_", "")
txt = txt.replace("_", " ")
txt.title()
# Out:
# 'Non English App Name Html'
