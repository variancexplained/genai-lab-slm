# %%
from appvocai-discover.shared.storage.file import IOService
from appvocai-discover.data.analysis.overview import DatasetOverview

# %%
FP = "data/prod/00_raw/reviews.pkl"

# %%
df = IOService.read(FP)
ds = DatasetOverview(data=df)
ds.info
ds.structure
ds.dtypes
ds.overview
ds.size
ds.summarize()
# Out:
#            Column        DataType  Complete  Null  Completeness    Unique  \
# 0              id  string[python]  18301035     0          1.00  17990555
# 1          app_id  string[python]  18301035     0          1.00     34064
# 2        app_name  string[python]  18301035     0          1.00     34051
# 3     category_id        category  18301035     0          1.00        11
# 4        category        category  18301035     0          1.00        11
# 5          author  string[python]  18301035     0          1.00  13242130
# 6          rating         float64  18301035     0          1.00         5
# 7           title  string[python]  18301035     0          1.00   6252017
# 8         content  string[python]  18301035     0          1.00  15411179
# 9        vote_sum           int64  18301035     0          1.00       481
# 10     vote_count           int64  18301035     0          1.00       641
# 11           date  datetime64[ns]  18301035     0          1.00  16826060
# ...
