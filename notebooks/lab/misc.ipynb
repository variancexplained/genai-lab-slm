# %%
import dask.dataframe as dd
import pyarrow

# Try reading a Parquet file to verify that Dask can use pyarrow
df = dd.read_parquet('path_to_your_parquet_file')
print(df.head())
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# File ~/miniconda3/envs/genai/lib/python3.10/site-packages/dask/backends.py:140, in CreationDispatch.register_inplace.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     139 try:
# --> 140     return func(*args, **kwargs)
#     141 except Exception as e:
#
# File ~/miniconda3/envs/genai/lib/python3.10/site-packages/dask/dataframe/dask_expr/_collection.py:5371, in read_parquet(path, columns, filters, categories, index, storage_options, dtype_backend, calculate_divisions, ignore_metadata_file, metadata_task_size, split_row_groups, blocksize, aggregate_files, parquet_file_extension, filesystem, engine, arrow_to_pandas, **kwargs)
#    5352     return new_collection(
#    5353         ReadParquetPyarrowFS(
#    5354             path,
#    (...)
#    5367         )
#    5368     )
#    5370 return new_collection(
# ...
