# %%
import warnings

warnings.filterwarnings("ignore")
import os

if "jbook" in os.getcwd():
    os.chdir(os.path.abspath(os.path.join("../..")))
FORCE = True

# %% [markdown]
# # Text Quality Analysis
# ---

# %% [markdown]
# ### Import Libraries
# ---

# %%
from dask.distributed import Client
from genailab.setup import auto_wire_container
from genailab.core.dtypes import DFType
from genailab.infra.utils.file.fileset import FileFormat
from genailab.asset.dataset.config import DatasetConfig
from genailab.flow.feature.tqa.builder import TQAStageBuilder
from genailab.asset.dataset.config import DatasetConfig
from genailab.core.flow import PhaseDef, StageDef


# Wire container
container = auto_wire_container()

# %% [markdown]
# ## Datasets

# %%
# Source Dataset Configuration
source_config = DatasetConfig(
    phase=PhaseDef.DATAPREP,
    stage=StageDef.CLEAN,
    name="review",
    file_format=FileFormat.PARQUET,
    asset_type="dataset",
    dftype=DFType.PANDAS,
)

# Target Dataset Configuration
target_config = DatasetConfig(
    phase=PhaseDef.FEATURE,
    stage=StageDef.TQADASK,
    name="review",
    file_format=FileFormat.PARQUET,
    asset_type="dataset",
    dftype=DFType.PANDAS,
)

# %%
# Create builder
stage = (
    TQAStageBuilder()
        .with_dask(normalized=True, batched=False)
        .build(source_config=source_config, target_config=target_config))
# Run the stage
dataset = stage.run(force=FORCE)
# Out:
# # ============================================================================== #
# #             Text Quality Analysis Stage Fri, 31 Jan 2025 01:56:53              #
# # ============================================================================== #
#
#
#
#                            TQADaskTask Configuration
#                             n_partitions | 8
#                                n_workers | 12
#                             memory_limit | 6GiB
#                       threads_per_worker | 1
#                                n_process | 4
#
# Task                                    Start       End         Runtime
# ----------------------------------------------------------------------------
# TQADaskTask                             01:56:53    01:57:03    9.61 seconds
# ____________________________________________________________________________
# Text Quality Analysis Stage             01:56:53    01:57:03    9.86 seconds
#
#
# # ============================================================================ #

# %%
dataset.dataframe.head()
# Out:
#              id      app_id                        app_name category_id  \
# 32   7356876939  1380362212    GALATEA: Novels & Audiobooks        6018
# 124  9587785392  1085047737  Bookly: Book Tracker & TBR Log        6018
# 236  7536002474  1123819773     Instawork: Be your own boss        6000
# 306  8181862602   377672876   Genius Scan - PDF Scanner App        6000
# 316  8303202194  1553307859  Aspirant : Your Local Services        6000
#
#                    author  rating  \
# 32   b885af87438701424310       5
# 124  029a75ddbb01b0f144e4       4
# 236  37e1da0be3c0660501f8       5
# 306  92b4b8783652b197eca1       5
# 316  78510aefd9ca2ee6a3cc       5
#
#                                                content  vote_sum  vote_count  \
# 32   very exciting book hard to put down but timer ...         0           0
# 124  cute app for keeping track of my books wish it...         0           0
# 236  instawork is the best app there is if your loo...         0           0
# 306  good app i have an office in my iphone best sc...         0           0
# 316  ingenious way to look for home services in you...         0           0
#
#                          date  category  noun_count  verb_count  \
# 32  2021-05-18 17:50:00+00:00      Book    2.302585    2.484907
# 124 2023-02-06 01:29:00+00:00      Book    1.609438    1.386294
# 236 2021-07-03 22:08:00+00:00  Business    2.079442    1.609438
# 306 2021-12-29 17:42:00+00:00  Business    1.386294    0.693147
# 316 2022-01-31 12:45:00+00:00  Business    2.302585    1.609438
#
#      adjective_count  adverb_count  aspect_verb_pairs  noun_phrases  \
# 32          2.079442      1.791759           1.098612      1.945910
# 124         1.098612      0.693147           1.386294      1.609438
# 236         1.098612      0.000000           0.693147      1.945910
# 306         1.098612      0.693147           0.693147      1.386294
# 316         1.098612      0.693147           1.609438      2.079442
#
#      verb_phrases  adverbial_phrases  review_length
# 32       2.484907           0.693147       4.143135
# 124      1.386294           0.000000       2.708050
# 236      1.386294           0.000000       3.218876
# 306      0.693147           0.000000       2.564949
# 316      1.609438           0.000000       3.295837
