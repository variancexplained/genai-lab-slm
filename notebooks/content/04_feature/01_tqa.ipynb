# %%
import warnings

warnings.filterwarnings("ignore")
import os

if "jbook" in os.getcwd():
    os.chdir(os.path.abspath(os.path.join("../..")))
FORCE = True

# %% [markdown]
# # Text Quality Analysis
# ---

# %% [markdown]
# ### Import Libraries
# ---

# %%
from genailab.setup import auto_wire_container
from genailab.core.dtypes import DFType
from genailab.infra.utils.file.fileset import FileFormat
from genailab.asset.dataset.config import DatasetConfig
from genailab.flow.feature.tqa.builder import TQAStageBuilder
from genailab.asset.dataset.config import DatasetConfig
from genailab.core.flow import PhaseDef, StageDef


# Wire container
container = auto_wire_container()

# %% [markdown]
# ## Dask Analyst

# %%
# Source Dataset Configuration
source_config = DatasetConfig(
    phase=PhaseDef.DATAPREP,
    stage=StageDef.CLEAN,
    name="review",
    file_format=FileFormat.PARQUET,
    asset_type="dataset",
    dftype=DFType.PANDAS,
)

# Target Dataset Configuration
target_config = DatasetConfig(
    phase=PhaseDef.FEATURE,
    stage=StageDef.TQA,
    name="review",
    file_format=FileFormat.PARQUET,
    asset_type="dataset",
    dftype=DFType.PANDAS,
)

# %%
# Create builder
stage = (
    TQAStageBuilder()
        .with_dask(normalized=True, batched=True)
        .build(source_config=source_config, target_config=target_config))
# Run the stage
dataset = stage.run(force=FORCE)
# Out:
# # ============================================================================== #
# #             Text Quality Analysis Stage Sun, 02 Feb 2025 12:14:18              #
# # ============================================================================== #
#
# ____________________________________________________________________________
# Text Quality Analysis Stage             12:14:18    12:19:21    5.0 minutes and 3.81 seconds
#
#
# # ============================================================================ #

# %%
dataset.dataframe.head()
# Out:
#             id      app_id                      app_name category_id  \
# 0  10019409512  1380362212  GALATEA: Novels & Audiobooks        6018
# 1  10027124164  1380362212  GALATEA: Novels & Audiobooks        6018
# 2  10036938913  1076402606           Libby, by OverDrive        6018
# 3  10047764706  1076402606           Libby, by OverDrive        6018
# 4  10064456025  1535748732  Storyroom - Webnovel & Story        6018
#
#                  author  rating  \
# 0  c011c66aae3e668b150e       5
# 1  5a2741393dd20358b609       5
# 2  46117640263dddac9294       5
# 3  a0e95f8868233439444d       5
# 4  bb43c451a876165c2abf       1
#
#                                              content  vote_sum  vote_count  \
# 0  i love it but the chapter and waiting hours fo...         0           0
# 1  i like the books that i have read so far if th...         0           0
# 2  i have read dozens upon dozens of books after ...         0           0
# 3  happy with the app i use it primarily for audi...         0           0
# 4  im going to be honest the books are really gre...         0           0
#
#                        date  ... adjective_count  adverb_count  \
# 0 2023-06-10 15:09:00+00:00  ...        0.000000      0.000000
# 1 2023-06-12 20:14:00+00:00  ...        1.386294      1.098612
# 2 2023-06-15 17:01:00+00:00  ...        1.945910      1.098612
# 3 2023-06-18 19:40:00+00:00  ...        1.609438      1.386294
# 4 2023-06-23 15:23:00+00:00  ...        2.197225      1.609438
#
#    aspect_verb_pairs  noun_phrases  verb_phrases  adverbial_phrases  \
# 0           0.000000      0.693147      0.693147           0.000000
# 1           1.609438      2.079442      2.302585           0.693147
# 2           1.386294      1.609438      2.079442           0.693147
# 3           1.098612      1.945910      1.386294           0.693147
# 4           1.609438      2.302585      2.639057           0.000000
#
#    review_length  lexical_density  dependency_depth  tqa_score
# 0       2.639057         3.675326          2.708050  16.176484
# 1       3.912023         3.683251          3.931826  37.360035
# 2       3.850148         3.795001          3.850148  35.486515
# 3       3.555348         3.987894          3.583519  32.536492
# 4       4.418841         3.804492          4.477337  41.925267
#
# [5 rows x 23 columns]

# %%
# Create builder
stage = (
    TQAStageBuilder()
        .with_dask(normalized=True, batched=False)
        .build(source_config=source_config, target_config=target_config))
# Run the stage
dataset = stage.run(force=FORCE)
# Out:
# # ============================================================================== #
# #             Text Quality Analysis Stage Sun, 02 Feb 2025 12:19:22              #
# # ============================================================================== #
#
# ____________________________________________________________________________
# Text Quality Analysis Stage             12:19:22    12:24:39    5.0 minutes and 16.59 seconds
#
#
# # ============================================================================ #

# %%
dataset.dataframe.head()
# Out:
#             id      app_id                      app_name category_id  \
# 0  10019409512  1380362212  GALATEA: Novels & Audiobooks        6018
# 1  10027124164  1380362212  GALATEA: Novels & Audiobooks        6018
# 2  10036938913  1076402606           Libby, by OverDrive        6018
# 3  10047764706  1076402606           Libby, by OverDrive        6018
# 4  10064456025  1535748732  Storyroom - Webnovel & Story        6018
#
#                  author  rating  \
# 0  c011c66aae3e668b150e       5
# 1  5a2741393dd20358b609       5
# 2  46117640263dddac9294       5
# 3  a0e95f8868233439444d       5
# 4  bb43c451a876165c2abf       1
#
#                                              content  vote_sum  vote_count  \
# 0  i love it but the chapter and waiting hours fo...         0           0
# 1  i like the books that i have read so far if th...         0           0
# 2  i have read dozens upon dozens of books after ...         0           0
# 3  happy with the app i use it primarily for audi...         0           0
# 4  im going to be honest the books are really gre...         0           0
#
#                        date  ... adjective_count  adverb_count  \
# 0 2023-06-10 15:09:00+00:00  ...        0.000000      0.000000
# 1 2023-06-12 20:14:00+00:00  ...        1.386294      1.098612
# 2 2023-06-15 17:01:00+00:00  ...        1.945910      1.098612
# 3 2023-06-18 19:40:00+00:00  ...        1.609438      1.386294
# 4 2023-06-23 15:23:00+00:00  ...        2.197225      1.609438
#
#    aspect_verb_pairs  noun_phrases  verb_phrases  adverbial_phrases  \
# 0           0.000000      0.693147      0.693147           0.000000
# 1           1.609438      2.079442      2.302585           0.693147
# 2           1.386294      1.609438      2.079442           0.693147
# 3           1.098612      1.945910      1.386294           0.693147
# 4           1.609438      2.302585      2.639057           0.000000
#
#    review_length  lexical_density  dependency_depth  tqa_score
# 0       2.639057         3.675326          2.708050  16.176484
# 1       3.912023         3.683251          3.931826  37.360035
# 2       3.850148         3.795001          3.850148  35.486515
# 3       3.555348         3.987894          3.583519  32.536492
# 4       4.418841         3.804492          4.477337  41.925267
#
# [5 rows x 23 columns]
