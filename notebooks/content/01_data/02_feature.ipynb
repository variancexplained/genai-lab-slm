# %%
import warnings

warnings.filterwarnings("ignore")
import os

if "jbook" in os.getcwd():
    os.chdir(os.path.abspath(os.path.join("../..")))

# %% [markdown]
# # Feature Engineering

# %% [markdown]
# ## Import Libraries

# %%
from discover.container import DiscoverContainer
from discover.infra.config.flow import FlowConfigReader
from discover.flow.data_prep.feature.stage import FeatureEngineeringStage

# %% [markdown]
# ## Dependency Container

# %%
container = DiscoverContainer()
container.init_resources()
container.wire(
    modules=[
        "discover.flow.data_prep.stage",
    ],
)

# %% [markdown]
# ## Feature Engineering Pipeline

# %%
# Obtain the configuration
reader = FlowConfigReader()
config = reader.get_config("phases", namespace=False)
stage_config = config["dataprep"]["stages"]["feature"]

# Build and run Data Ingestion Stage
stage = FeatureEngineeringStage.build(stage_config=stage_config, force=True)
asset_id = stage.run()
# Out:
# # ============================================================================== #
# #                           Feature Engineering Stage                            #
# # ============================================================================== #
#
#
#
#                                     NLPTask
#                                     -------
#                           Start Datetime | Sat, 26 Oct 2024 15:34:58
# pos_ud_ewt download started this may take some time.
# Approximate size to download 2.2 MB
# [OK!]
#                        Complete Datetime | Sat, 26 Oct 2024 15:35:02
#                                  Runtime | 3.73 seconds
# [10/26/2024 03:35:03 PM] [ERROR] [DataPrepStage.run] [wrapper] : Exception occurred in DataPrepStage.run called with
# [DATATYPE_MISMATCH.UNEXPECTED_INPUT_TYPE] Cannot resolve "aggregate(word_lengths, 0, lambdafunction((namedlambdavariable() + pow((namedlambdavariable() - stats_word_length_mean), 2)), namedlambdavariable(), namedlambdavariable()), lambdafunction(namedlambdavariable(), namedlambdavariable()))" due to data type mismatch: Parameter 3 requires the "INT" type, however "lambdafunction((namedlambdavariable() + pow((namedlambdavariable() - stats_word_length_mean), 2)), namedlambdavariable(), namedlambdavariable())" has the type "DOUBLE".;
# Project [id#991, app_id#992, app_name#993, category_id#994, author#995, rating#996, content#997, vote_sum#998L, vote_count#999L, date#1000, review_length#1001L, dc_non_english_app_name#1002, dc_non_english_review#1003, category#1004, tp_tokens#1105, tp_pos#1125, pos_n_nouns#1198, pos_n_verbs#1218, pos_n_adjectives#1239, pos_n_adverbs#1261, pos_n_determiners#1284, pos_p_nouns#1308, pos_p_verbs#1332, pos_p_adjectives#1357, ... 15 more fields]
# +- Project [id#991, app_id#992, app_name#993, category_id#994, author#995, rating#996, content#997, vote_sum#998L, vote_count#999L, date#1000, review_length#1001L, dc_non_english_app_name#1002, dc_non_english_review#1003, category#1004, tp_tokens#1105, tp_pos#1125, pos_n_nouns#1198, pos_n_verbs#1218, pos_n_adjectives#1239, pos_n_adverbs#1261, pos_n_determiners#1284, pos_p_nouns#1308, pos_p_verbs#1332, pos_p_adjectives#1357, ... 14 more fields]
#    +- Project [id#991, app_id#992, app_name#993, category_id#994, author#995, rating#996, content#997, vote_sum#998L, vote_count#999L, date#1000, review_length#1001L, dc_non_english_app_name#1002, dc_non_english_review#1003, category#1004, tp_tokens#1105, tp_pos#1125, pos_n_nouns#1198, pos_n_verbs#1218, pos_n_adjectives#1239, pos_n_adverbs#1261, pos_n_determiners#1284, pos_p_nouns#1308, pos_p_verbs#1332, pos_p_adjectives#1357, ... 13 more fields]
#       +- Project [id#991, app_id#992, app_name#993, category_id#994, author#995, rating#996, content#997, vote_sum#998L, vote_count#999L, date#1000, review_length#1001L, dc_non_english_app_name#1002, dc_non_english_review#1003, category#1004, tp_tokens#1105, tp_pos#1125, pos_n_nouns#1198, pos_n_verbs#1218, pos_n_adjectives#1239, pos_n_adverbs#1261, pos_n_determiners#1284, pos_p_nouns#1308, pos_p_verbs#1332, pos_p_adjectives#1357, ... 12 more fields]
#          +- Project [id#991, app_id#992, app_name#993, category_id#994, author#995, rating#996, content#997, vote_sum#998L, vote_count#999L, date#1000, review_length#1001L, dc_non_english_app_name#1002, dc_non_english_review#1003, category#1004, tp_tokens#1105, tp_pos#1125, pos_n_nouns#1198, pos_n_verbs#1218, pos_n_adjectives#1239, pos_n_adverbs#1261, pos_n_determiners#1284, pos_p_nouns#1308, pos_p_verbs#1332, pos_p_adjectives#1357, ... 11 more fields]
#             +- Project [id#991, app_id#992, app_name#993, category_id#994, author#995, rating#996, content#997, vote_sum#998L, vote_count#999L, date#1000, review_length#1001L, dc_non_english_app_name#1002, dc_non_english_review#1003, category#1004, tp_tokens#1105, tp_pos#1125, pos_n_nouns#1198, pos_n_verbs#1218, pos_n_adjectives#1239, pos_n_adverbs#1261, pos_n_determiners#1284, pos_p_nouns#1308, pos_p_verbs#1332, pos_p_adjectives#1357, ... 10 more fields]
#                +- Project [id#991, app_id#992, app_name#993, category_id#994, author#995, rating#996, content#997, vote_sum#998L, vote_count#999L, date#1000, review_length#1001L, dc_non_english_app_name#1002, dc_non_english_review#1003, category#1004, tp_tokens#1105, tp_pos#1125, pos_n_nouns#1198, pos_n_verbs#1218, pos_n_adjectives#1239, pos_n_adverbs#1261, pos_n_determiners#1284, pos_p_nouns#1308, pos_p_verbs#1332, pos_p_adjectives#1357, ... 12 more fields]
#                   +- Project [id#991, app_id#992, app_name#993, category_id#994, author#995, rating#996, content#997, vote_sum#998L, vote_count#999L, date#1000, review_length#1001L, dc_non_english_app_name#1002, dc_non_english_review#1003, category#1004, tp_tokens#1105, tp_pos#1125, pos_n_nouns#1198, pos_n_verbs#1218, pos_n_adjectives#1239, pos_n_adverbs#1261, pos_n_determiners#1284, pos_p_nouns#1308, pos_p_verbs#1332, pos_p_adjectives#1357, ... 11 more fields]
#                      +- Project [id#991, app_id#992, app_name#993, category_id#994, author#995, rating#996, content#997, vote_sum#998L, vote_count#999L, date#1000, review_length#1001L, dc_non_english_app_name#1002, dc_non_english_review#1003, category#1004, tp_tokens#1105, tp_pos#1125, pos_n_nouns#1198, pos_n_verbs#1218, pos_n_adjectives#1239, pos_n_adverbs#1261, pos_n_determiners#1284, pos_p_nouns#1308, pos_p_verbs#1332, pos_p_adjectives#1357, ... 10 more fields]
#                         +- Project [id#991, app_id#992, app_name#993, category_id#994, author#995, rating#996, content#997, vote_sum#998L, vote_count#999L, date#1000, review_length#1001L, dc_non_english_app_name#1002, dc_non_english_review#1003, category#1004, tp_tokens#1105, tp_pos#1125, pos_n_nouns#1198, pos_n_verbs#1218, pos_n_adjectives#1239, pos_n_adverbs#1261, pos_n_determiners#1284, pos_p_nouns#1308, pos_p_verbs#1332, pos_p_adjectives#1357, ... 9 more fields]
#                            +- Project [id#991, app_id#992, app_name#993, category_id#994, author#995, rating#996, content#997, vote_sum#998L, vote_count#999L, date#1000, review_length#1001L, dc_non_english_app_name#1002, dc_non_english_review#1003, category#1004, tp_tokens#1105, tp_pos#1125, pos_n_nouns#1198, pos_n_verbs#1218, pos_n_adjectives#1239, pos_n_adverbs#1261, pos_n_determiners#1284, pos_p_nouns#1308, pos_p_verbs#1332, pos_p_adjectives#1357, ... 8 more fields]
#                               +- Project [id#991, app_id#992, app_name#993, category_id#994, author#995, rating#996, content#997, vote_sum#998L, vote_count#999L, date#1000, review_length#1001L, dc_non_english_app_name#1002, dc_non_english_review#1003, category#1004, tp_tokens#1105, tp_pos#1125, pos_n_nouns#1198, pos_n_verbs#1218, pos_n_adjectives#1239, pos_n_adverbs#1261, pos_n_determiners#1284, pos_p_nouns#1308, pos_p_verbs#1332, pos_p_adjectives#1357, ... 7 more fields]
#                                  +- Project [id#991, app_id#992, app_name#993, category_id#994, author#995, rating#996, content#997, vote_sum#998L, vote_count#999L, date#1000, review_length#1001L, dc_non_english_app_name#1002, dc_non_english_review#1003, category#1004, tp_tokens#1105, tp_pos#1125, pos_n_nouns#1198, pos_n_verbs#1218, pos_n_adjectives#1239, pos_n_adverbs#1261, pos_n_determiners#1284, pos_p_nouns#1308, pos_p_verbs#1332, pos_p_adjectives#1357, ... 6 more fields]
#                                     +- Project [id#991, app_id#992, app_name#993, category_id#994, author#995, rating#996, content#997, vote_sum#998L, vote_count#999L, date#1000, review_length#1001L, dc_non_english_app_name#1002, dc_non_english_review#1003, category#1004, tp_tokens#1105, tp_pos#1125, pos_n_nouns#1198, pos_n_verbs#1218, pos_n_adjectives#1239, pos_n_adverbs#1261, pos_n_determiners#1284, pos_p_nouns#1308, pos_p_verbs#1332, pos_p_adjectives#1357, ... 5 more fields]
#                                        +- Project [id#991, app_id#992, app_name#993, category_id#994, author#995, rating#996, content#997, vote_sum#998L, vote_count#999L, date#1000, review_length#1001L, dc_non_english_app_name#1002, dc_non_english_review#1003, category#1004, tp_tokens#1105, tp_pos#1125, pos_n_nouns#1198, pos_n_verbs#1218, pos_n_adjectives#1239, pos_n_adverbs#1261, pos_n_determiners#1284, pos_p_nouns#1308, pos_p_verbs#1332, pos_p_adjectives#1357, ... 4 more fields]
#                                           +- Project [id#991, app_id#992, app_name#993, category_id#994, author#995, rating#996, content#997, vote_sum#998L, vote_count#999L, date#1000, review_length#1001L, dc_non_english_app_name#1002, dc_non_english_review#1003, category#1004, tp_tokens#1105, tp_pos#1125, pos_n_nouns#1198, pos_n_verbs#1218, pos_n_adjectives#1239, pos_n_adverbs#1261, pos_n_determiners#1284, pos_p_nouns#1308, pos_p_verbs#1332, pos_p_adjectives#1357, ... 3 more fields]
#                                              +- Project [id#991, app_id#992, app_name#993, category_id#994, author#995, rating#996, content#997, vote_sum#998L, vote_count#999L, date#1000, review_length#1001L, dc_non_english_app_name#1002, dc_non_english_review#1003, category#1004, tp_tokens#1105, tp_pos#1125, pos_n_nouns#1198, pos_n_verbs#1218, pos_n_adjectives#1239, pos_n_adverbs#1261, pos_n_determiners#1284, pos_p_nouns#1308, pos_p_verbs#1332, pos_p_adjectives#1357, ... 2 more fields]
#                                                 +- Project [id#991, app_id#992, app_name#993, category_id#994, author#995, rating#996, content#997, vote_sum#998L, vote_count#999L, date#1000, review_length#1001L, dc_non_english_app_name#1002, dc_non_english_review#1003, category#1004, tp_tokens#1105, tp_pos#1125, pos_count#1180, pos_n_nouns#1198, pos_n_verbs#1218, pos_n_adjectives#1239, pos_n_adverbs#1261, pos_n_determiners#1284, pos_p_nouns#1308, pos_p_verbs#1332, ... 3 more fields]
#                                                    +- Project [id#991, app_id#992, app_name#993, category_id#994, author#995, rating#996, content#997, vote_sum#998L, vote_count#999L, date#1000, review_length#1001L, dc_non_english_app_name#1002, dc_non_english_review#1003, category#1004, tp_tokens#1105, tp_pos#1125, pos_count#1180, pos_n_nouns#1198, pos_n_verbs#1218, pos_n_adjectives#1239, pos_n_adverbs#1261, pos_n_determiners#1284, pos_p_nouns#1308, pos_p_verbs#1332, ... 2 more fields]
#                                                       +- Project [id#991, app_id#992, app_name#993, category_id#994, author#995, rating#996, content#997, vote_sum#998L, vote_count#999L, date#1000, review_length#1001L, dc_non_english_app_name#1002, dc_non_english_review#1003, category#1004, tp_tokens#1105, tp_pos#1125, pos_count#1180, pos_n_nouns#1198, pos_n_verbs#1218, pos_n_adjectives#1239, pos_n_adverbs#1261, pos_n_determiners#1284, pos_p_nouns#1308, pos_p_verbs#1332, CASE WHEN (pos_count#1180 > 0) THEN (cast(pos_n_adjectives#1239 as double) / cast(pos_count#1180 as double)) ELSE cast(0 as double) END AS pos_p_adjectives#1357]
#                                                          +- Project [id#991, app_id#992, app_name#993, category_id#994, author#995, rating#996, content#997, vote_sum#998L, vote_count#999L, date#1000, review_length#1001L, dc_non_english_app_name#1002, dc_non_english_review#1003, category#1004, tp_tokens#1105, tp_pos#1125, pos_count#1180, pos_n_nouns#1198, pos_n_verbs#1218, pos_n_adjectives#1239, pos_n_adverbs#1261, pos_n_determiners#1284, pos_p_nouns#1308, CASE WHEN (pos_count#1180 > 0) THEN (cast(pos_n_verbs#1218 as double) / cast(pos_count#1180 as double)) ELSE cast(0 as double) END AS pos_p_verbs#1332]
#                                                             +- Project [id#991, app_id#992, app_name#993, category_id#994, author#995, rating#996, content#997, vote_sum#998L, vote_count#999L, date#1000, review_length#1001L, dc_non_english_app_name#1002, dc_non_english_review#1003, category#1004, tp_tokens#1105, tp_pos#1125, pos_count#1180, pos_n_nouns#1198, pos_n_verbs#1218, pos_n_adjectives#1239, pos_n_adverbs#1261, pos_n_determiners#1284, CASE WHEN (pos_count#1180 > 0) THEN (cast(pos_n_nouns#1198 as double) / cast(pos_count#1180 as double)) ELSE cast(0 as double) END AS pos_p_nouns#1308]
#                                                                +- Project [id#991, app_id#992, app_name#993, category_id#994, author#995, rating#996, content#997, vote_sum#998L, vote_count#999L, date#1000, review_length#1001L, dc_non_english_app_name#1002, dc_non_english_review#1003, category#1004, tp_tokens#1105, tp_pos#1125, pos_count#1180, pos_n_nouns#1198, pos_n_verbs#1218, pos_n_adjectives#1239, pos_n_adverbs#1261, size(filter(tp_pos#1125, lambdafunction((lambda x#1285 = DET), lambda x#1285, false)), true) AS pos_n_determiners#1284]
#                                                                   +- Project [id#991, app_id#992, app_name#993, category_id#994, author#995, rating#996, content#997, vote_sum#998L, vote_count#999L, date#1000, review_length#1001L, dc_non_english_app_name#1002, dc_non_english_review#1003, category#1004, tp_tokens#1105, tp_pos#1125, pos_count#1180, pos_n_nouns#1198, pos_n_verbs#1218, pos_n_adjectives#1239, size(filter(tp_pos#1125, lambdafunction((lambda x#1262 = ADV), lambda x#1262, false)), true) AS pos_n_adverbs#1261]
#                                                                      +- Project [id#991, app_id#992, app_name#993, category_id#994, author#995, rating#996, content#997, vote_sum#998L, vote_count#999L, date#1000, review_length#1001L, dc_non_english_app_name#1002, dc_non_english_review#1003, category#1004, tp_tokens#1105, tp_pos#1125, pos_count#1180, pos_n_nouns#1198, pos_n_verbs#1218, size(filter(tp_pos#1125, lambdafunction((lambda x#1240 = ADJ), lambda x#1240, false)), true) AS pos_n_adjectives#1239]
#                                                                         +- Project [id#991, app_id#992, app_name#993, category_id#994, author#995, rating#996, content#997, vote_sum#998L, vote_count#999L, date#1000, review_length#1001L, dc_non_english_app_name#1002, dc_non_english_review#1003, category#1004, tp_tokens#1105, tp_pos#1125, pos_count#1180, pos_n_nouns#1198, size(filter(tp_pos#1125, lambdafunction((lambda x#1219 = VERB), lambda x#1219, false)), true) AS pos_n_verbs#1218]
#                                                                            +- Project [id#991, app_id#992, app_name#993, category_id#994, author#995, rating#996, content#997, vote_sum#998L, vote_count#999L, date#1000, review_length#1001L, dc_non_english_app_name#1002, dc_non_english_review#1003, category#1004, tp_tokens#1105, tp_pos#1125, pos_count#1180, size(filter(tp_pos#1125, lambdafunction((lambda x#1199 = NOUN), lambda x#1199, false)), true) AS pos_n_nouns#1198]
#                                                                               +- Project [id#991, app_id#992, app_name#993, category_id#994, author#995, rating#996, content#997, vote_sum#998L, vote_count#999L, date#1000, review_length#1001L, dc_non_english_app_name#1002, dc_non_english_review#1003, category#1004, tp_tokens#1105, tp_pos#1125, size(tp_pos#1125, true) AS pos_count#1180]
#                                                                                  +- Project [id#991, app_id#992, app_name#993, category_id#994, author#995, rating#996, content#997, vote_sum#998L, vote_count#999L, date#1000, review_length#1001L, dc_non_english_app_name#1002, dc_non_english_review#1003, category#1004, tp_tokens#1105, tp_pos#1125]
#                                                                                     +- Project [id#991, app_id#992, app_name#993, category_id#994, author#995, rating#996, content#997, vote_sum#998L, vote_count#999L, date#1000, review_length#1001L, dc_non_english_app_name#1002, dc_non_english_review#1003, category#1004, document#1046, tokens#1067, pos_tags#1086, tp_tokens#1105, UDF(pos_tags#1086) AS tp_pos#1125]
#                                                                                        +- Project [id#991, app_id#992, app_name#993, category_id#994, author#995, rating#996, content#997, vote_sum#998L, vote_count#999L, date#1000, review_length#1001L, dc_non_english_app_name#1002, dc_non_english_review#1003, category#1004, document#1046, tokens#1067, pos_tags#1086, UDF(tokens#1067) AS tp_tokens#1105]
#                                                                                           +- Project [id#991, app_id#992, app_name#993, category_id#994, author#995, rating#996, content#997, vote_sum#998L, vote_count#999L, date#1000, review_length#1001L, dc_non_english_app_name#1002, dc_non_english_review#1003, category#1004, document#1046, tokens#1067, UDF(array(document#1046, tokens#1067)) AS pos_tags#1086]
#                                                                                              +- Project [id#991, app_id#992, app_name#993, category_id#994, author#995, rating#996, content#997, vote_sum#998L, vote_count#999L, date#1000, review_length#1001L, dc_non_english_app_name#1002, dc_non_english_review#1003, category#1004, document#1046, UDF(array(document#1046)) AS tokens#1067]
#                                                                                                 +- Project [id#991, app_id#992, app_name#993, category_id#994, author#995, rating#996, content#997, vote_sum#998L, vote_count#999L, date#1000, review_length#1001L, dc_non_english_app_name#1002, dc_non_english_review#1003, category#1004, UDF(content#997) AS document#1046]
#                                                                                                    +- Relation [id#991,app_id#992,app_name#993,category_id#994,author#995,rating#996,content#997,vote_sum#998L,vote_count#999L,date#1000,review_length#1001L,dc_non_english_app_name#1002,dc_non_english_review#1003,category#1004] parquet
# Traceback (most recent call last):
#   File "/home/john/projects/appvocai-discover/discover/infra/service/logging/stage.py", line 49, in wrapper
#     result = func(self, *args, **kwargs)
#   File "/home/john/projects/appvocai-discover/discover/flow/data_prep/stage.py", line 163, in run
#     data = task.run(data=data)
#   File "/home/john/projects/appvocai-discover/discover/flow/data_prep/feature/task.py", line 363, in run
#   File "/home/john/miniconda3/envs/appvocai/lib/python3.10/site-packages/pyspark/sql/dataframe.py", line 5176, in withColumn
#     return DataFrame(self._jdf.withColumn(colName, col._jc), self.sparkSession)
#   File "/home/john/miniconda3/envs/appvocai/lib/python3.10/site-packages/py4j/java_gateway.py", line 1322, in __call__
#     return_value = get_return_value(
#   File "/home/john/miniconda3/envs/appvocai/lib/python3.10/site-packages/pyspark/errors/exceptions/captured.py", line 185, in deco
#     raise converted from None
# pyspark.errors.exceptions.captured.AnalysisException: [DATATYPE_MISMATCH.UNEXPECTED_INPUT_TYPE] Cannot resolve "aggregate(word_lengths, 0, lambdafunction((namedlambdavariable() + pow((namedlambdavariable() - stats_word_length_mean), 2)), namedlambdavariable(), namedlambdavariable()), lambdafunction(namedlambdavariable(), namedlambdavariable()))" due to data type mismatch: Parameter 3 requires the "INT" type, however "lambdafunction((namedlambdavariable() + pow((namedlambdavariable() - stats_word_length_mean), 2)), namedlambdavariable(), namedlambdavariable())" has the type "DOUBLE".;
# Project [id#991, app_id#992, app_name#993, category_id#994, author#995, rating#996, content#997, vote_sum#998L, vote_count#999L, date#1000, review_length#1001L, dc_non_english_app_name#1002, dc_non_english_review#1003, category#1004, tp_tokens#1105, tp_pos#1125, pos_n_nouns#1198, pos_n_verbs#1218, pos_n_adjectives#1239, pos_n_adverbs#1261, pos_n_determiners#1284, pos_p_nouns#1308, pos_p_verbs#1332, pos_p_adjectives#1357, ... 15 more fields]
# +- Project [id#991, app_id#992, app_name#993, category_id#994, author#995, rating#996, content#997, vote_sum#998L, vote_count#999L, date#1000, review_length#1001L, dc_non_english_app_name#1002, dc_non_english_review#1003, category#1004, tp_tokens#1105, tp_pos#1125, pos_n_nouns#1198, pos_n_verbs#1218, pos_n_adjectives#1239, pos_n_adverbs#1261, pos_n_determiners#1284, pos_p_nouns#1308, pos_p_verbs#1332, pos_p_adjectives#1357, ... 14 more fields]
#    +- Project [id#991, app_id#992, app_name#993, category_id#994, author#995, rating#996, content#997, vote_sum#998L, vote_count#999L, date#1000, review_length#1001L, dc_non_english_app_name#1002, dc_non_english_review#1003, category#1004, tp_tokens#1105, tp_pos#1125, pos_n_nouns#1198, pos_n_verbs#1218, pos_n_adjectives#1239, pos_n_adverbs#1261, pos_n_determiners#1284, pos_p_nouns#1308, pos_p_verbs#1332, pos_p_adjectives#1357, ... 13 more fields]
#       +- Project [id#991, app_id#992, app_name#993, category_id#994, author#995, rating#996, content#997, vote_sum#998L, vote_count#999L, date#1000, review_length#1001L, dc_non_english_app_name#1002, dc_non_english_review#1003, category#1004, tp_tokens#1105, tp_pos#1125, pos_n_nouns#1198, pos_n_verbs#1218, pos_n_adjectives#1239, pos_n_adverbs#1261, pos_n_determiners#1284, pos_p_nouns#1308, pos_p_verbs#1332, pos_p_adjectives#1357, ... 12 more fields]
#          +- Project [id#991, app_id#992, app_name#993, category_id#994, author#995, rating#996, content#997, vote_sum#998L, vote_count#999L, date#1000, review_length#1001L, dc_non_english_app_name#1002, dc_non_english_review#1003, category#1004, tp_tokens#1105, tp_pos#1125, pos_n_nouns#1198, pos_n_verbs#1218, pos_n_adjectives#1239, pos_n_adverbs#1261, pos_n_determiners#1284, pos_p_nouns#1308, pos_p_verbs#1332, pos_p_adjectives#1357, ... 11 more fields]
#             +- Project [id#991, app_id#992, app_name#993, category_id#994, author#995, rating#996, content#997, vote_sum#998L, vote_count#999L, date#1000, review_length#1001L, dc_non_english_app_name#1002, dc_non_english_review#1003, category#1004, tp_tokens#1105, tp_pos#1125, pos_n_nouns#1198, pos_n_verbs#1218, pos_n_adjectives#1239, pos_n_adverbs#1261, pos_n_determiners#1284, pos_p_nouns#1308, pos_p_verbs#1332, pos_p_adjectives#1357, ... 10 more fields]
#                +- Project [id#991, app_id#992, app_name#993, category_id#994, author#995, rating#996, content#997, vote_sum#998L, vote_count#999L, date#1000, review_length#1001L, dc_non_english_app_name#1002, dc_non_english_review#1003, category#1004, tp_tokens#1105, tp_pos#1125, pos_n_nouns#1198, pos_n_verbs#1218, pos_n_adjectives#1239, pos_n_adverbs#1261, pos_n_determiners#1284, pos_p_nouns#1308, pos_p_verbs#1332, pos_p_adjectives#1357, ... 12 more fields]
#                   +- Project [id#991, app_id#992, app_name#993, category_id#994, author#995, rating#996, content#997, vote_sum#998L, vote_count#999L, date#1000, review_length#1001L, dc_non_english_app_name#1002, dc_non_english_review#1003, category#1004, tp_tokens#1105, tp_pos#1125, pos_n_nouns#1198, pos_n_verbs#1218, pos_n_adjectives#1239, pos_n_adverbs#1261, pos_n_determiners#1284, pos_p_nouns#1308, pos_p_verbs#1332, pos_p_adjectives#1357, ... 11 more fields]
#                      +- Project [id#991, app_id#992, app_name#993, category_id#994, author#995, rating#996, content#997, vote_sum#998L, vote_count#999L, date#1000, review_length#1001L, dc_non_english_app_name#1002, dc_non_english_review#1003, category#1004, tp_tokens#1105, tp_pos#1125, pos_n_nouns#1198, pos_n_verbs#1218, pos_n_adjectives#1239, pos_n_adverbs#1261, pos_n_determiners#1284, pos_p_nouns#1308, pos_p_verbs#1332, pos_p_adjectives#1357, ... 10 more fields]
#                         +- Project [id#991, app_id#992, app_name#993, category_id#994, author#995, rating#996, content#997, vote_sum#998L, vote_count#999L, date#1000, review_length#1001L, dc_non_english_app_name#1002, dc_non_english_review#1003, category#1004, tp_tokens#1105, tp_pos#1125, pos_n_nouns#1198, pos_n_verbs#1218, pos_n_adjectives#1239, pos_n_adverbs#1261, pos_n_determiners#1284, pos_p_nouns#1308, pos_p_verbs#1332, pos_p_adjectives#1357, ... 9 more fields]
#                            +- Project [id#991, app_id#992, app_name#993, category_id#994, author#995, rating#996, content#997, vote_sum#998L, vote_count#999L, date#1000, review_length#1001L, dc_non_english_app_name#1002, dc_non_english_review#1003, category#1004, tp_tokens#1105, tp_pos#1125, pos_n_nouns#1198, pos_n_verbs#1218, pos_n_adjectives#1239, pos_n_adverbs#1261, pos_n_determiners#1284, pos_p_nouns#1308, pos_p_verbs#1332, pos_p_adjectives#1357, ... 8 more fields]
#                               +- Project [id#991, app_id#992, app_name#993, category_id#994, author#995, rating#996, content#997, vote_sum#998L, vote_count#999L, date#1000, review_length#1001L, dc_non_english_app_name#1002, dc_non_english_review#1003, category#1004, tp_tokens#1105, tp_pos#1125, pos_n_nouns#1198, pos_n_verbs#1218, pos_n_adjectives#1239, pos_n_adverbs#1261, pos_n_determiners#1284, pos_p_nouns#1308, pos_p_verbs#1332, pos_p_adjectives#1357, ... 7 more fields]
#                                  +- Project [id#991, app_id#992, app_name#993, category_id#994, author#995, rating#996, content#997, vote_sum#998L, vote_count#999L, date#1000, review_length#1001L, dc_non_english_app_name#1002, dc_non_english_review#1003, category#1004, tp_tokens#1105, tp_pos#1125, pos_n_nouns#1198, pos_n_verbs#1218, pos_n_adjectives#1239, pos_n_adverbs#1261, pos_n_determiners#1284, pos_p_nouns#1308, pos_p_verbs#1332, pos_p_adjectives#1357, ... 6 more fields]
#                                     +- Project [id#991, app_id#992, app_name#993, category_id#994, author#995, rating#996, content#997, vote_sum#998L, vote_count#999L, date#1000, review_length#1001L, dc_non_english_app_name#1002, dc_non_english_review#1003, category#1004, tp_tokens#1105, tp_pos#1125, pos_n_nouns#1198, pos_n_verbs#1218, pos_n_adjectives#1239, pos_n_adverbs#1261, pos_n_determiners#1284, pos_p_nouns#1308, pos_p_verbs#1332, pos_p_adjectives#1357, ... 5 more fields]
#                                        +- Project [id#991, app_id#992, app_name#993, category_id#994, author#995, rating#996, content#997, vote_sum#998L, vote_count#999L, date#1000, review_length#1001L, dc_non_english_app_name#1002, dc_non_english_review#1003, category#1004, tp_tokens#1105, tp_pos#1125, pos_n_nouns#1198, pos_n_verbs#1218, pos_n_adjectives#1239, pos_n_adverbs#1261, pos_n_determiners#1284, pos_p_nouns#1308, pos_p_verbs#1332, pos_p_adjectives#1357, ... 4 more fields]
#                                           +- Project [id#991, app_id#992, app_name#993, category_id#994, author#995, rating#996, content#997, vote_sum#998L, vote_count#999L, date#1000, review_length#1001L, dc_non_english_app_name#1002, dc_non_english_review#1003, category#1004, tp_tokens#1105, tp_pos#1125, pos_n_nouns#1198, pos_n_verbs#1218, pos_n_adjectives#1239, pos_n_adverbs#1261, pos_n_determiners#1284, pos_p_nouns#1308, pos_p_verbs#1332, pos_p_adjectives#1357, ... 3 more fields]
#                                              +- Project [id#991, app_id#992, app_name#993, category_id#994, author#995, rating#996, content#997, vote_sum#998L, vote_count#999L, date#1000, review_length#1001L, dc_non_english_app_name#1002, dc_non_english_review#1003, category#1004, tp_tokens#1105, tp_pos#1125, pos_n_nouns#1198, pos_n_verbs#1218, pos_n_adjectives#1239, pos_n_adverbs#1261, pos_n_determiners#1284, pos_p_nouns#1308, pos_p_verbs#1332, pos_p_adjectives#1357, ... 2 more fields]
#                                                 +- Project [id#991, app_id#992, app_name#993, category_id#994, author#995, rating#996, content#997, vote_sum#998L, vote_count#999L, date#1000, review_length#1001L, dc_non_english_app_name#1002, dc_non_english_review#1003, category#1004, tp_tokens#1105, tp_pos#1125, pos_count#1180, pos_n_nouns#1198, pos_n_verbs#1218, pos_n_adjectives#1239, pos_n_adverbs#1261, pos_n_determiners#1284, pos_p_nouns#1308, pos_p_verbs#1332, ... 3 more fields]
#                                                    +- Project [id#991, app_id#992, app_name#993, category_id#994, author#995, rating#996, content#997, vote_sum#998L, vote_count#999L, date#1000, review_length#1001L, dc_non_english_app_name#1002, dc_non_english_review#1003, category#1004, tp_tokens#1105, tp_pos#1125, pos_count#1180, pos_n_nouns#1198, pos_n_verbs#1218, pos_n_adjectives#1239, pos_n_adverbs#1261, pos_n_determiners#1284, pos_p_nouns#1308, pos_p_verbs#1332, ... 2 more fields]
#                                                       +- Project [id#991, app_id#992, app_name#993, category_id#994, author#995, rating#996, content#997, vote_sum#998L, vote_count#999L, date#1000, review_length#1001L, dc_non_english_app_name#1002, dc_non_english_review#1003, category#1004, tp_tokens#1105, tp_pos#1125, pos_count#1180, pos_n_nouns#1198, pos_n_verbs#1218, pos_n_adjectives#1239, pos_n_adverbs#1261, pos_n_determiners#1284, pos_p_nouns#1308, pos_p_verbs#1332, CASE WHEN (pos_count#1180 > 0) THEN (cast(pos_n_adjectives#1239 as double) / cast(pos_count#1180 as double)) ELSE cast(0 as double) END AS pos_p_adjectives#1357]
#                                                          +- Project [id#991, app_id#992, app_name#993, category_id#994, author#995, rating#996, content#997, vote_sum#998L, vote_count#999L, date#1000, review_length#1001L, dc_non_english_app_name#1002, dc_non_english_review#1003, category#1004, tp_tokens#1105, tp_pos#1125, pos_count#1180, pos_n_nouns#1198, pos_n_verbs#1218, pos_n_adjectives#1239, pos_n_adverbs#1261, pos_n_determiners#1284, pos_p_nouns#1308, CASE WHEN (pos_count#1180 > 0) THEN (cast(pos_n_verbs#1218 as double) / cast(pos_count#1180 as double)) ELSE cast(0 as double) END AS pos_p_verbs#1332]
#                                                             +- Project [id#991, app_id#992, app_name#993, category_id#994, author#995, rating#996, content#997, vote_sum#998L, vote_count#999L, date#1000, review_length#1001L, dc_non_english_app_name#1002, dc_non_english_review#1003, category#1004, tp_tokens#1105, tp_pos#1125, pos_count#1180, pos_n_nouns#1198, pos_n_verbs#1218, pos_n_adjectives#1239, pos_n_adverbs#1261, pos_n_determiners#1284, CASE WHEN (pos_count#1180 > 0) THEN (cast(pos_n_nouns#1198 as double) / cast(pos_count#1180 as double)) ELSE cast(0 as double) END AS pos_p_nouns#1308]
#                                                                +- Project [id#991, app_id#992, app_name#993, category_id#994, author#995, rating#996, content#997, vote_sum#998L, vote_count#999L, date#1000, review_length#1001L, dc_non_english_app_name#1002, dc_non_english_review#1003, category#1004, tp_tokens#1105, tp_pos#1125, pos_count#1180, pos_n_nouns#1198, pos_n_verbs#1218, pos_n_adjectives#1239, pos_n_adverbs#1261, size(filter(tp_pos#1125, lambdafunction((lambda x#1285 = DET), lambda x#1285, false)), true) AS pos_n_determiners#1284]
#                                                                   +- Project [id#991, app_id#992, app_name#993, category_id#994, author#995, rating#996, content#997, vote_sum#998L, vote_count#999L, date#1000, review_length#1001L, dc_non_english_app_name#1002, dc_non_english_review#1003, category#1004, tp_tokens#1105, tp_pos#1125, pos_count#1180, pos_n_nouns#1198, pos_n_verbs#1218, pos_n_adjectives#1239, size(filter(tp_pos#1125, lambdafunction((lambda x#1262 = ADV), lambda x#1262, false)), true) AS pos_n_adverbs#1261]
#                                                                      +- Project [id#991, app_id#992, app_name#993, category_id#994, author#995, rating#996, content#997, vote_sum#998L, vote_count#999L, date#1000, review_length#1001L, dc_non_english_app_name#1002, dc_non_english_review#1003, category#1004, tp_tokens#1105, tp_pos#1125, pos_count#1180, pos_n_nouns#1198, pos_n_verbs#1218, size(filter(tp_pos#1125, lambdafunction((lambda x#1240 = ADJ), lambda x#1240, false)), true) AS pos_n_adjectives#1239]
#                                                                         +- Project [id#991, app_id#992, app_name#993, category_id#994, author#995, rating#996, content#997, vote_sum#998L, vote_count#999L, date#1000, review_length#1001L, dc_non_english_app_name#1002, dc_non_english_review#1003, category#1004, tp_tokens#1105, tp_pos#1125, pos_count#1180, pos_n_nouns#1198, size(filter(tp_pos#1125, lambdafunction((lambda x#1219 = VERB), lambda x#1219, false)), true) AS pos_n_verbs#1218]
#                                                                            +- Project [id#991, app_id#992, app_name#993, category_id#994, author#995, rating#996, content#997, vote_sum#998L, vote_count#999L, date#1000, review_length#1001L, dc_non_english_app_name#1002, dc_non_english_review#1003, category#1004, tp_tokens#1105, tp_pos#1125, pos_count#1180, size(filter(tp_pos#1125, lambdafunction((lambda x#1199 = NOUN), lambda x#1199, false)), true) AS pos_n_nouns#1198]
#                                                                               +- Project [id#991, app_id#992, app_name#993, category_id#994, author#995, rating#996, content#997, vote_sum#998L, vote_count#999L, date#1000, review_length#1001L, dc_non_english_app_name#1002, dc_non_english_review#1003, category#1004, tp_tokens#1105, tp_pos#1125, size(tp_pos#1125, true) AS pos_count#1180]
#                                                                                  +- Project [id#991, app_id#992, app_name#993, category_id#994, author#995, rating#996, content#997, vote_sum#998L, vote_count#999L, date#1000, review_length#1001L, dc_non_english_app_name#1002, dc_non_english_review#1003, category#1004, tp_tokens#1105, tp_pos#1125]
#                                                                                     +- Project [id#991, app_id#992, app_name#993, category_id#994, author#995, rating#996, content#997, vote_sum#998L, vote_count#999L, date#1000, review_length#1001L, dc_non_english_app_name#1002, dc_non_english_review#1003, category#1004, document#1046, tokens#1067, pos_tags#1086, tp_tokens#1105, UDF(pos_tags#1086) AS tp_pos#1125]
#                                                                                        +- Project [id#991, app_id#992, app_name#993, category_id#994, author#995, rating#996, content#997, vote_sum#998L, vote_count#999L, date#1000, review_length#1001L, dc_non_english_app_name#1002, dc_non_english_review#1003, category#1004, document#1046, tokens#1067, pos_tags#1086, UDF(tokens#1067) AS tp_tokens#1105]
#                                                                                           +- Project [id#991, app_id#992, app_name#993, category_id#994, author#995, rating#996, content#997, vote_sum#998L, vote_count#999L, date#1000, review_length#1001L, dc_non_english_app_name#1002, dc_non_english_review#1003, category#1004, document#1046, tokens#1067, UDF(array(document#1046, tokens#1067)) AS pos_tags#1086]
#                                                                                              +- Project [id#991, app_id#992, app_name#993, category_id#994, author#995, rating#996, content#997, vote_sum#998L, vote_count#999L, date#1000, review_length#1001L, dc_non_english_app_name#1002, dc_non_english_review#1003, category#1004, document#1046, UDF(array(document#1046)) AS tokens#1067]
#                                                                                                 +- Project [id#991, app_id#992, app_name#993, category_id#994, author#995, rating#996, content#997, vote_sum#998L, vote_count#999L, date#1000, review_length#1001L, dc_non_english_app_name#1002, dc_non_english_review#1003, category#1004, UDF(content#997) AS document#1046]
#                                                                                                    +- Relation [id#991,app_id#992,app_name#993,category_id#994,author#995,rating#996,content#997,vote_sum#998L,vote_count#999L,date#1000,review_length#1001L,dc_non_english_app_name#1002,dc_non_english_review#1003,category#1004] parquet
# ---------------------------------------------------------------------------
# AnalysisException                         Traceback (most recent call last)
# Cell In[8], line 8
#       6 # Build and run Data Ingestion Stage
#       7 stage = FeatureEngineeringStage.build(stage_config=stage_config, force=True)
# ----> 8 asset_id = stage.run()
#
# File ~/projects/appvocai-discover/discover/infra/service/logging/stage.py:49, in stage_logger.<locals>.wrapper(self, *args, **kwargs)
#      46 start_fmt = dt4mtr.to_HTTP_format(start)
#      48 # Execute the original function being decorated, passing all args and kwargs.
# ---> 49 result = func(self, *args, **kwargs)
#      51 # Log runtime.
#      52 end = datetime.now()
#
# File ~/projects/appvocai-discover/discover/flow/data_prep/stage.py:163, in DataPrepStage.run(self)
#     160 data = self._load_source_data()
#     162 for task in self._tasks:
# --> 163     data = task.run(data=data)
#     165 dataset = self._create_destination_dataset(data=data)
#     167 self._save_destination_dataset(dataset=dataset)
#
# File ~/projects/appvocai-discover/discover/flow/data_prep/feature/task.py:363, in ComputeBasicStatsTask.run(self, data)
#     355 data = data.withColumn(
#     356     "stats_word_length_mean",
#     357     F.expr(
#     358         "aggregate(word_lengths, 0, (acc, x) -> acc + x) / size(word_lengths)"
#     359     ),
#     360 )
#     362 # Standard deviation of word length
# --> 363 data = data.withColumn(
#     364     "stats_word_length_std",
#     365     F.when(
#     366         F.size("word_lengths") > 1,
#     367         F.sqrt(
#     368             F.expr(
#     369                 "aggregate(word_lengths, 0, (acc, x) -> acc + pow(x - stats_word_length_mean, 2)) / size(word_lengths)"
#     370             )
#     371         ),
#     372     ).otherwise(F.lit(None)),
#     373 )
#     375 # Drop intermediate column if not needed
#     376 data = data.drop("word_lengths")
#
# File ~/miniconda3/envs/appvocai/lib/python3.10/site-packages/pyspark/sql/dataframe.py:5176, in DataFrame.withColumn(self, colName, col)
#    5171 if not isinstance(col, Column):
#    5172     raise PySparkTypeError(
#    5173         error_class="NOT_COLUMN",
#    5174         message_parameters={"arg_name": "col", "arg_type": type(col).__name__},
#    5175     )
# -> 5176 return DataFrame(self._jdf.withColumn(colName, col._jc), self.sparkSession)
#
# File ~/miniconda3/envs/appvocai/lib/python3.10/site-packages/py4j/java_gateway.py:1322, in JavaMember.__call__(self, *args)
#    1316 command = proto.CALL_COMMAND_NAME +\
#    1317     self.command_header +\
#    1318     args_command +\
#    1319     proto.END_COMMAND_PART
#    1321 answer = self.gateway_client.send_command(command)
# -> 1322 return_value = get_return_value(
#    1323     answer, self.gateway_client, self.target_id, self.name)
#    1325 for temp_arg in temp_args:
#    1326     if hasattr(temp_arg, "_detach"):
#
# File ~/miniconda3/envs/appvocai/lib/python3.10/site-packages/pyspark/errors/exceptions/captured.py:185, in capture_sql_exception.<locals>.deco(*a, **kw)
#     181 converted = convert_exception(e.java_exception)
#     182 if not isinstance(converted, UnknownException):
#     183     # Hide where the exception came from that shows a non-Pythonic
#     184     # JVM exception message.
# --> 185     raise converted from None
#     186 else:
#     187     raise
#
# AnalysisException: [DATATYPE_MISMATCH.UNEXPECTED_INPUT_TYPE] Cannot resolve "aggregate(word_lengths, 0, lambdafunction((namedlambdavariable() + pow((namedlambdavariable() - stats_word_length_mean), 2)), namedlambdavariable(), namedlambdavariable()), lambdafunction(namedlambdavariable(), namedlambdavariable()))" due to data type mismatch: Parameter 3 requires the "INT" type, however "lambdafunction((namedlambdavariable() + pow((namedlambdavariable() - stats_word_length_mean), 2)), namedlambdavariable(), namedlambdavariable())" has the type "DOUBLE".;
# Project [id#991, app_id#992, app_name#993, category_id#994, author#995, rating#996, content#997, vote_sum#998L, vote_count#999L, date#1000, review_length#1001L, dc_non_english_app_name#1002, dc_non_english_review#1003, category#1004, tp_tokens#1105, tp_pos#1125, pos_n_nouns#1198, pos_n_verbs#1218, pos_n_adjectives#1239, pos_n_adverbs#1261, pos_n_determiners#1284, pos_p_nouns#1308, pos_p_verbs#1332, pos_p_adjectives#1357, ... 15 more fields]
# +- Project [id#991, app_id#992, app_name#993, category_id#994, author#995, rating#996, content#997, vote_sum#998L, vote_count#999L, date#1000, review_length#1001L, dc_non_english_app_name#1002, dc_non_english_review#1003, category#1004, tp_tokens#1105, tp_pos#1125, pos_n_nouns#1198, pos_n_verbs#1218, pos_n_adjectives#1239, pos_n_adverbs#1261, pos_n_determiners#1284, pos_p_nouns#1308, pos_p_verbs#1332, pos_p_adjectives#1357, ... 14 more fields]
#    +- Project [id#991, app_id#992, app_name#993, category_id#994, author#995, rating#996, content#997, vote_sum#998L, vote_count#999L, date#1000, review_length#1001L, dc_non_english_app_name#1002, dc_non_english_review#1003, category#1004, tp_tokens#1105, tp_pos#1125, pos_n_nouns#1198, pos_n_verbs#1218, pos_n_adjectives#1239, pos_n_adverbs#1261, pos_n_determiners#1284, pos_p_nouns#1308, pos_p_verbs#1332, pos_p_adjectives#1357, ... 13 more fields]
#       +- Project [id#991, app_id#992, app_name#993, category_id#994, author#995, rating#996, content#997, vote_sum#998L, vote_count#999L, date#1000, review_length#1001L, dc_non_english_app_name#1002, dc_non_english_review#1003, category#1004, tp_tokens#1105, tp_pos#1125, pos_n_nouns#1198, pos_n_verbs#1218, pos_n_adjectives#1239, pos_n_adverbs#1261, pos_n_determiners#1284, pos_p_nouns#1308, pos_p_verbs#1332, pos_p_adjectives#1357, ... 12 more fields]
#          +- Project [id#991, app_id#992, app_name#993, category_id#994, author#995, rating#996, content#997, vote_sum#998L, vote_count#999L, date#1000, review_length#1001L, dc_non_english_app_name#1002, dc_non_english_review#1003, category#1004, tp_tokens#1105, tp_pos#1125, pos_n_nouns#1198, pos_n_verbs#1218, pos_n_adjectives#1239, pos_n_adverbs#1261, pos_n_determiners#1284, pos_p_nouns#1308, pos_p_verbs#1332, pos_p_adjectives#1357, ... 11 more fields]
#             +- Project [id#991, app_id#992, app_name#993, category_id#994, author#995, rating#996, content#997, vote_sum#998L, vote_count#999L, date#1000, review_length#1001L, dc_non_english_app_name#1002, dc_non_english_review#1003, category#1004, tp_tokens#1105, tp_pos#1125, pos_n_nouns#1198, pos_n_verbs#1218, pos_n_adjectives#1239, pos_n_adverbs#1261, pos_n_determiners#1284, pos_p_nouns#1308, pos_p_verbs#1332, pos_p_adjectives#1357, ... 10 more fields]
#                +- Project [id#991, app_id#992, app_name#993, category_id#994, author#995, rating#996, content#997, vote_sum#998L, vote_count#999L, date#1000, review_length#1001L, dc_non_english_app_name#1002, dc_non_english_review#1003, category#1004, tp_tokens#1105, tp_pos#1125, pos_n_nouns#1198, pos_n_verbs#1218, pos_n_adjectives#1239, pos_n_adverbs#1261, pos_n_determiners#1284, pos_p_nouns#1308, pos_p_verbs#1332, pos_p_adjectives#1357, ... 12 more fields]
#                   +- Project [id#991, app_id#992, app_name#993, category_id#994, author#995, rating#996, content#997, vote_sum#998L, vote_count#999L, date#1000, review_length#1001L, dc_non_english_app_name#1002, dc_non_english_review#1003, category#1004, tp_tokens#1105, tp_pos#1125, pos_n_nouns#1198, pos_n_verbs#1218, pos_n_adjectives#1239, pos_n_adverbs#1261, pos_n_determiners#1284, pos_p_nouns#1308, pos_p_verbs#1332, pos_p_adjectives#1357, ... 11 more fields]
#                      +- Project [id#991, app_id#992, app_name#993, category_id#994, author#995, rating#996, content#997, vote_sum#998L, vote_count#999L, date#1000, review_length#1001L, dc_non_english_app_name#1002, dc_non_english_review#1003, category#1004, tp_tokens#1105, tp_pos#1125, pos_n_nouns#1198, pos_n_verbs#1218, pos_n_adjectives#1239, pos_n_adverbs#1261, pos_n_determiners#1284, pos_p_nouns#1308, pos_p_verbs#1332, pos_p_adjectives#1357, ... 10 more fields]
#                         +- Project [id#991, app_id#992, app_name#993, category_id#994, author#995, rating#996, content#997, vote_sum#998L, vote_count#999L, date#1000, review_length#1001L, dc_non_english_app_name#1002, dc_non_english_review#1003, category#1004, tp_tokens#1105, tp_pos#1125, pos_n_nouns#1198, pos_n_verbs#1218, pos_n_adjectives#1239, pos_n_adverbs#1261, pos_n_determiners#1284, pos_p_nouns#1308, pos_p_verbs#1332, pos_p_adjectives#1357, ... 9 more fields]
#                            +- Project [id#991, app_id#992, app_name#993, category_id#994, author#995, rating#996, content#997, vote_sum#998L, vote_count#999L, date#1000, review_length#1001L, dc_non_english_app_name#1002, dc_non_english_review#1003, category#1004, tp_tokens#1105, tp_pos#1125, pos_n_nouns#1198, pos_n_verbs#1218, pos_n_adjectives#1239, pos_n_adverbs#1261, pos_n_determiners#1284, pos_p_nouns#1308, pos_p_verbs#1332, pos_p_adjectives#1357, ... 8 more fields]
#                               +- Project [id#991, app_id#992, app_name#993, category_id#994, author#995, rating#996, content#997, vote_sum#998L, vote_count#999L, date#1000, review_length#1001L, dc_non_english_app_name#1002, dc_non_english_review#1003, category#1004, tp_tokens#1105, tp_pos#1125, pos_n_nouns#1198, pos_n_verbs#1218, pos_n_adjectives#1239, pos_n_adverbs#1261, pos_n_determiners#1284, pos_p_nouns#1308, pos_p_verbs#1332, pos_p_adjectives#1357, ... 7 more fields]
#                                  +- Project [id#991, app_id#992, app_name#993, category_id#994, author#995, rating#996, content#997, vote_sum#998L, vote_count#999L, date#1000, review_length#1001L, dc_non_english_app_name#1002, dc_non_english_review#1003, category#1004, tp_tokens#1105, tp_pos#1125, pos_n_nouns#1198, pos_n_verbs#1218, pos_n_adjectives#1239, pos_n_adverbs#1261, pos_n_determiners#1284, pos_p_nouns#1308, pos_p_verbs#1332, pos_p_adjectives#1357, ... 6 more fields]
#                                     +- Project [id#991, app_id#992, app_name#993, category_id#994, author#995, rating#996, content#997, vote_sum#998L, vote_count#999L, date#1000, review_length#1001L, dc_non_english_app_name#1002, dc_non_english_review#1003, category#1004, tp_tokens#1105, tp_pos#1125, pos_n_nouns#1198, pos_n_verbs#1218, pos_n_adjectives#1239, pos_n_adverbs#1261, pos_n_determiners#1284, pos_p_nouns#1308, pos_p_verbs#1332, pos_p_adjectives#1357, ... 5 more fields]
#                                        +- Project [id#991, app_id#992, app_name#993, category_id#994, author#995, rating#996, content#997, vote_sum#998L, vote_count#999L, date#1000, review_length#1001L, dc_non_english_app_name#1002, dc_non_english_review#1003, category#1004, tp_tokens#1105, tp_pos#1125, pos_n_nouns#1198, pos_n_verbs#1218, pos_n_adjectives#1239, pos_n_adverbs#1261, pos_n_determiners#1284, pos_p_nouns#1308, pos_p_verbs#1332, pos_p_adjectives#1357, ... 4 more fields]
#                                           +- Project [id#991, app_id#992, app_name#993, category_id#994, author#995, rating#996, content#997, vote_sum#998L, vote_count#999L, date#1000, review_length#1001L, dc_non_english_app_name#1002, dc_non_english_review#1003, category#1004, tp_tokens#1105, tp_pos#1125, pos_n_nouns#1198, pos_n_verbs#1218, pos_n_adjectives#1239, pos_n_adverbs#1261, pos_n_determiners#1284, pos_p_nouns#1308, pos_p_verbs#1332, pos_p_adjectives#1357, ... 3 more fields]
#                                              +- Project [id#991, app_id#992, app_name#993, category_id#994, author#995, rating#996, content#997, vote_sum#998L, vote_count#999L, date#1000, review_length#1001L, dc_non_english_app_name#1002, dc_non_english_review#1003, category#1004, tp_tokens#1105, tp_pos#1125, pos_n_nouns#1198, pos_n_verbs#1218, pos_n_adjectives#1239, pos_n_adverbs#1261, pos_n_determiners#1284, pos_p_nouns#1308, pos_p_verbs#1332, pos_p_adjectives#1357, ... 2 more fields]
#                                                 +- Project [id#991, app_id#992, app_name#993, category_id#994, author#995, rating#996, content#997, vote_sum#998L, vote_count#999L, date#1000, review_length#1001L, dc_non_english_app_name#1002, dc_non_english_review#1003, category#1004, tp_tokens#1105, tp_pos#1125, pos_count#1180, pos_n_nouns#1198, pos_n_verbs#1218, pos_n_adjectives#1239, pos_n_adverbs#1261, pos_n_determiners#1284, pos_p_nouns#1308, pos_p_verbs#1332, ... 3 more fields]
#                                                    +- Project [id#991, app_id#992, app_name#993, category_id#994, author#995, rating#996, content#997, vote_sum#998L, vote_count#999L, date#1000, review_length#1001L, dc_non_english_app_name#1002, dc_non_english_review#1003, category#1004, tp_tokens#1105, tp_pos#1125, pos_count#1180, pos_n_nouns#1198, pos_n_verbs#1218, pos_n_adjectives#1239, pos_n_adverbs#1261, pos_n_determiners#1284, pos_p_nouns#1308, pos_p_verbs#1332, ... 2 more fields]
#                                                       +- Project [id#991, app_id#992, app_name#993, category_id#994, author#995, rating#996, content#997, vote_sum#998L, vote_count#999L, date#1000, review_length#1001L, dc_non_english_app_name#1002, dc_non_english_review#1003, category#1004, tp_tokens#1105, tp_pos#1125, pos_count#1180, pos_n_nouns#1198, pos_n_verbs#1218, pos_n_adjectives#1239, pos_n_adverbs#1261, pos_n_determiners#1284, pos_p_nouns#1308, pos_p_verbs#1332, CASE WHEN (pos_count#1180 > 0) THEN (cast(pos_n_adjectives#1239 as double) / cast(pos_count#1180 as double)) ELSE cast(0 as double) END AS pos_p_adjectives#1357]
#                                                          +- Project [id#991, app_id#992, app_name#993, category_id#994, author#995, rating#996, content#997, vote_sum#998L, vote_count#999L, date#1000, review_length#1001L, dc_non_english_app_name#1002, dc_non_english_review#1003, category#1004, tp_tokens#1105, tp_pos#1125, pos_count#1180, pos_n_nouns#1198, pos_n_verbs#1218, pos_n_adjectives#1239, pos_n_adverbs#1261, pos_n_determiners#1284, pos_p_nouns#1308, CASE WHEN (pos_count#1180 > 0) THEN (cast(pos_n_verbs#1218 as double) / cast(pos_count#1180 as double)) ELSE cast(0 as double) END AS pos_p_verbs#1332]
#                                                             +- Project [id#991, app_id#992, app_name#993, category_id#994, author#995, rating#996, content#997, vote_sum#998L, vote_count#999L, date#1000, review_length#1001L, dc_non_english_app_name#1002, dc_non_english_review#1003, category#1004, tp_tokens#1105, tp_pos#1125, pos_count#1180, pos_n_nouns#1198, pos_n_verbs#1218, pos_n_adjectives#1239, pos_n_adverbs#1261, pos_n_determiners#1284, CASE WHEN (pos_count#1180 > 0) THEN (cast(pos_n_nouns#1198 as double) / cast(pos_count#1180 as double)) ELSE cast(0 as double) END AS pos_p_nouns#1308]
#                                                                +- Project [id#991, app_id#992, app_name#993, category_id#994, author#995, rating#996, content#997, vote_sum#998L, vote_count#999L, date#1000, review_length#1001L, dc_non_english_app_name#1002, dc_non_english_review#1003, category#1004, tp_tokens#1105, tp_pos#1125, pos_count#1180, pos_n_nouns#1198, pos_n_verbs#1218, pos_n_adjectives#1239, pos_n_adverbs#1261, size(filter(tp_pos#1125, lambdafunction((lambda x#1285 = DET), lambda x#1285, false)), true) AS pos_n_determiners#1284]
#                                                                   +- Project [id#991, app_id#992, app_name#993, category_id#994, author#995, rating#996, content#997, vote_sum#998L, vote_count#999L, date#1000, review_length#1001L, dc_non_english_app_name#1002, dc_non_english_review#1003, category#1004, tp_tokens#1105, tp_pos#1125, pos_count#1180, pos_n_nouns#1198, pos_n_verbs#1218, pos_n_adjectives#1239, size(filter(tp_pos#1125, lambdafunction((lambda x#1262 = ADV), lambda x#1262, false)), true) AS pos_n_adverbs#1261]
#                                                                      +- Project [id#991, app_id#992, app_name#993, category_id#994, author#995, rating#996, content#997, vote_sum#998L, vote_count#999L, date#1000, review_length#1001L, dc_non_english_app_name#1002, dc_non_english_review#1003, category#1004, tp_tokens#1105, tp_pos#1125, pos_count#1180, pos_n_nouns#1198, pos_n_verbs#1218, size(filter(tp_pos#1125, lambdafunction((lambda x#1240 = ADJ), lambda x#1240, false)), true) AS pos_n_adjectives#1239]
#                                                                         +- Project [id#991, app_id#992, app_name#993, category_id#994, author#995, rating#996, content#997, vote_sum#998L, vote_count#999L, date#1000, review_length#1001L, dc_non_english_app_name#1002, dc_non_english_review#1003, category#1004, tp_tokens#1105, tp_pos#1125, pos_count#1180, pos_n_nouns#1198, size(filter(tp_pos#1125, lambdafunction((lambda x#1219 = VERB), lambda x#1219, false)), true) AS pos_n_verbs#1218]
#                                                                            +- Project [id#991, app_id#992, app_name#993, category_id#994, author#995, rating#996, content#997, vote_sum#998L, vote_count#999L, date#1000, review_length#1001L, dc_non_english_app_name#1002, dc_non_english_review#1003, category#1004, tp_tokens#1105, tp_pos#1125, pos_count#1180, size(filter(tp_pos#1125, lambdafunction((lambda x#1199 = NOUN), lambda x#1199, false)), true) AS pos_n_nouns#1198]
#                                                                               +- Project [id#991, app_id#992, app_name#993, category_id#994, author#995, rating#996, content#997, vote_sum#998L, vote_count#999L, date#1000, review_length#1001L, dc_non_english_app_name#1002, dc_non_english_review#1003, category#1004, tp_tokens#1105, tp_pos#1125, size(tp_pos#1125, true) AS pos_count#1180]
#                                                                                  +- Project [id#991, app_id#992, app_name#993, category_id#994, author#995, rating#996, content#997, vote_sum#998L, vote_count#999L, date#1000, review_length#1001L, dc_non_english_app_name#1002, dc_non_english_review#1003, category#1004, tp_tokens#1105, tp_pos#1125]
#                                                                                     +- Project [id#991, app_id#992, app_name#993, category_id#994, author#995, rating#996, content#997, vote_sum#998L, vote_count#999L, date#1000, review_length#1001L, dc_non_english_app_name#1002, dc_non_english_review#1003, category#1004, document#1046, tokens#1067, pos_tags#1086, tp_tokens#1105, UDF(pos_tags#1086) AS tp_pos#1125]
#                                                                                        +- Project [id#991, app_id#992, app_name#993, category_id#994, author#995, rating#996, content#997, vote_sum#998L, vote_count#999L, date#1000, review_length#1001L, dc_non_english_app_name#1002, dc_non_english_review#1003, category#1004, document#1046, tokens#1067, pos_tags#1086, UDF(tokens#1067) AS tp_tokens#1105]
#                                                                                           +- Project [id#991, app_id#992, app_name#993, category_id#994, author#995, rating#996, content#997, vote_sum#998L, vote_count#999L, date#1000, review_length#1001L, dc_non_english_app_name#1002, dc_non_english_review#1003, category#1004, document#1046, tokens#1067, UDF(array(document#1046, tokens#1067)) AS pos_tags#1086]
#                                                                                              +- Project [id#991, app_id#992, app_name#993, category_id#994, author#995, rating#996, content#997, vote_sum#998L, vote_count#999L, date#1000, review_length#1001L, dc_non_english_app_name#1002, dc_non_english_review#1003, category#1004, document#1046, UDF(array(document#1046)) AS tokens#1067]
#                                                                                                 +- Project [id#991, app_id#992, app_name#993, category_id#994, author#995, rating#996, content#997, vote_sum#998L, vote_count#999L, date#1000, review_length#1001L, dc_non_english_app_name#1002, dc_non_english_review#1003, category#1004, UDF(content#997) AS document#1046]
#                                                                                                    +- Relation [id#991,app_id#992,app_name#993,category_id#994,author#995,rating#996,content#997,vote_sum#998L,vote_count#999L,date#1000,review_length#1001L,dc_non_english_app_name#1002,dc_non_english_review#1003,category#1004] parquet
