# %%
import os
if 'jbook' in os.getcwd():
    os.chdir(os.path.abspath(os.path.join("../..")))
import warnings
warnings.filterwarnings("ignore", category=FutureWarning)

# %%
from importlib import reload  # Not needed in Python 2
import logging
reload(logging)
logging.basicConfig(format='%(asctime)s %(levelname)s:%(message)s', level=logging.DEBUG, datefmt='%I:%M:%S')

# %% [markdown]
# # Data Quality Assessment
# The second stage of data processing is the Data Quality Assessment. This stage ensures that our dataset is ready for subsequent analysis and modeling tasks. By identifying and rectifying data quality issues early, we can avoid potential pitfalls that might compromise the integrity and accuracy of our results.
#
# ## Data Quality Checks
# In this stage, we employ a series of tasks designed to identify and address any noise or irregularities within the dataset. Each task focuses on a specific aspect of data quality, ranging from detecting duplicate entries to identifying profanity, special patterns, and other potential sources of bias or distortion.
# 1. **Duplicate Rows**: We identify and remove duplicate entries to ensure that each observation is unique, preventing skewed analyses and inflated metrics.
# 2. **Null Values**: We detect and handle missing data appropriately, which could involve imputation, deletion, or flagging incomplete records for further investigation.
# 3. **Outliers**: Check for outliers in numeric columns using the non-parametric Interquartile Range (IQR) method.
# 4. **Non-English Text**: We check for and address non-English text in reviews and app names, as they may not be relevant to our analysis or could require special handling.
# 5. **Emojis**: Emojis can carry significant meaning in certain contexts but might also introduce noise. We identify and decide on their treatment—whether to retain, remove, or translate them into textual representations.
# 6. **Excessive Special Characters**: Special characters can disrupt text analysis and need to be managed, either by cleaning or encoding them appropriately.
# 7. **Invalid Dates**: We verify that date values fall within expected ranges and formats, correcting or flagging anomalies for further review.
# 8. **Invalid Ratings**: Ratings that fall outside the expected scale (e.g., 1 to 5) are identified and corrected or flagged.
# 9. **Profanity**: We detect and handle profane content to ensure that our dataset adheres to appropriate usage standards, especially if it's intended for public or sensitive applications.
# 10. **Special Patterns**: We identify and manage special patterns such as URLs, phone numbers, and emails. These patterns could be indicative of spam or need to be anonymized to protect privacy.
#
# By conducting these data quality checks, we ensure that our dataset is clean, reliable, and ready for detailed analysis. This foundational step sets the stage for accurate insights and robust conclusions in the subsequent phases of our data processing pipeline.

# %%
from appinsight.data_prep.dqa import DataQualityAssessment, DQAConfig
# Out:
# 04:58:02 INFO:Note: NumExpr detected 24 cores but "NUMEXPR_MAX_THREADS" not set, so enforcing safe limit of 8.
# 04:58:02 INFO:NumExpr defaulting to 8 threads.

# %% [markdown]
# We've encapsulated the data quality assessment process in a `DataQualityAssessment` class. Configured with source and target files, this class conducts the 10 data quality checks, marking the observations that require attention.

# %%
config = DQAConfig(force=True)
warnings.filterwarnings("ignore", category=FutureWarning)
dqa = DataQualityAssessment(config=config)
data = dqa.execute()
# Out:
# 04:58:03 DEBUG:Instantiated the dqa cache manager.
# 04:58:03 DEBUG:Instantiated the dqa cache manager.
# 04:58:03 DEBUG:Instantiated the dqa cache manager.
# 04:58:03 DEBUG:Instantiated the dqa cache manager.
# 04:58:03 DEBUG:Instantiated the dqa cache manager.
# 04:58:03 DEBUG:Instantiated the dqa cache manager.
# 04:58:03 DEBUG:Instantiated the dqa cache manager.
# 04:58:03 DEBUG:Instantiated the dqa cache manager.
# 04:58:03 DEBUG:Instantiated the dqa cache manager.
# 04:58:03 DEBUG:Instantiated the dqa cache manager.
# 04:58:03 DEBUG:Instantiated the dqa cache manager.
# 04:58:03 DEBUG:Instantiated the dqa cache manager.
# 04:58:03 DEBUG:Instantiated the dqa cache manager.
# 04:58:03 DEBUG:Instantiated the dqa cache manager.
# 04:58:03 DEBUG:Instantiated the dqa cache manager.
# 04:58:03 DEBUG:Instantiated the dqa cache manager.
# 04:58:03 DEBUG:Checking if endpoint exists.
# 04:58:03 DEBUG:Creating pipeline
# 04:58:03 DEBUG:Instantiated the dqa cache manager.
# 04:58:03 DEBUG:Instantiated the dqa cache manager.
# 04:58:03 DEBUG:Instantiated the dqa cache manager.
# 04:58:03 DEBUG:Instantiated the dqa cache manager.
# 04:58:03 DEBUG:Instantiated the dqa cache manager.
# 04:58:03 DEBUG:Instantiated the dqa cache manager.
# 04:58:03 DEBUG:Instantiated the dqa cache manager.
# 04:58:03 DEBUG:Instantiated the dqa cache manager.
# 04:58:03 DEBUG:Instantiated the dqa cache manager.
# 04:58:03 DEBUG:Instantiated the dqa cache manager.
# 04:58:03 DEBUG:Instantiated the dqa cache manager.
# 04:58:03 DEBUG:Instantiated the dqa cache manager.
# 04:58:03 DEBUG:Instantiated the dqa cache manager.
# 04:58:03 DEBUG:Instantiated the dqa cache manager.
# 04:58:03 DEBUG:Instantiated the dqa cache manager.
# 04:58:03 DEBUG:Pipeline created.
# 04:58:03 DEBUG:Executing ReadTask
# 04:58:03 DEBUG:Reading from data/dev/01_norm/reviews
# # ============================================================================ #
# #                        DataQualityAssessment Pipeline                        #
# # ============================================================================ #
#
# Task ReadTask completed successfully. Runtime: 00 Minutes 00.482469 Seconds
# 04:58:05 DEBUG:Cache for dqa_is_duplicate already exists. Skipping task.
# 04:58:05 DEBUG:Cache for dqa_is_duplicate_review_id already exists. Skipping task.
# 04:58:05 DEBUG:Cache for dqa_has_null_values already exists. Skipping task.
# 04:58:05 DEBUG:Cache for dqa_vote_sum_outlier already exists. Skipping task.
# 04:58:05 DEBUG:Cache for dqa_vote_count_outlier already exists. Skipping task.
# 04:58:05 DEBUG:Cache for dqa_has_emojis already exists. Skipping task.
# 04:58:05 DEBUG:Cache for dqa_has_excessive_special_chars already exists. Skipping task.
# 04:58:05 DEBUG:Cache for dqa_has_invalid_date already exists. Skipping task.
# 04:58:05 DEBUG:Cache for dqa_has_invalid_rating already exists. Skipping task.
# 04:58:05 DEBUG:Cache for dqa_contains_email already exists. Skipping task.
# 04:58:05 DEBUG:Cache for dqa_contains_url already exists. Skipping task.
# 04:58:05 DEBUG:Cache for dqa_contains_phone_number already exists. Skipping task.
# 04:58:05 DEBUG:Cache for dqa_has_non_english_review already exists. Skipping task.
# 04:58:05 DEBUG:Cache for dqa_has_non_english_app_name already exists. Skipping task.
# 04:58:05 DEBUG:Cache for dqa_has_profanity already exists. Skipping task.
# 04:58:05 DEBUG:Instantiated the dqa cache iterator.
# 04:58:05 DEBUG:Obtaining dqa_is_duplicate from cache with 221666 rows.
# Task DQAInitTask completed successfully. Runtime: 00 Minutes 00.969415 Seconds
# Task DetectDuplicateRowTask completed successfully. Runtime: 00 Minutes 00.003864 Seconds
# Task DetectDuplicateRowTask completed successfully. Runtime: 00 Minutes 00.002504 Seconds
# Task DetectNullValuesTask completed successfully. Runtime: 00 Minutes 00.002175 Seconds
# Task DetectOutliersTask completed successfully. Runtime: 00 Minutes 00.002124 Seconds
# Task DetectOutliersTask completed successfully. Runtime: 00 Minutes 00.002083 Seconds
# Task DetectEmojiTask completed successfully. Runtime: 00 Minutes 00.001888 Seconds
# Task DetectSpecialCharacterTask completed successfully. Runtime: 00 Minutes 00.002324 Seconds
# Task DetectInvalidDatesTask completed successfully. Runtime: 00 Minutes 00.002663 Seconds
# Task DetectInvalidRatingsTask completed successfully. Runtime: 00 Minutes 00.001605 Seconds
# Task DetectEmailTask completed successfully. Runtime: 00 Minutes 00.002068 Seconds
# Task DetectURLTask completed successfully. Runtime: 00 Minutes 00.002338 Seconds
# Task DetectPhoneNumberTask completed successfully. Runtime: 00 Minutes 00.002700 Seconds
# Task DetectNonEnglishTask completed successfully. Runtime: 00 Minutes 00.001527 Seconds
# Task DetectNonEnglishTask completed successfully. Runtime: 00 Minutes 00.002004 Seconds
# Task DetectProfanityTask completed successfully. Runtime: 00 Minutes 00.002361 Seconds
# 04:58:05 DEBUG:Data now has 13 columns.
# 04:58:05 DEBUG:Obtaining dqa_is_duplicate_review_id from cache with 221666 rows.
# 04:58:05 DEBUG:Data now has 14 columns.
# 04:58:05 DEBUG:Obtaining dqa_has_null_values from cache with 221666 rows.
# 04:58:05 DEBUG:Data now has 15 columns.
# 04:58:05 DEBUG:Obtaining dqa_vote_sum_outlier from cache with 221666 rows.
# 04:58:06 DEBUG:Data now has 16 columns.
# 04:58:06 DEBUG:Obtaining dqa_vote_count_outlier from cache with 221666 rows.
# 04:58:06 DEBUG:Data now has 17 columns.
# 04:58:06 DEBUG:Obtaining dqa_has_emojis from cache with 221666 rows.
# 04:58:06 DEBUG:Data now has 18 columns.
# 04:58:06 DEBUG:Obtaining dqa_has_excessive_special_chars from cache with 221666 rows.
# 04:58:07 DEBUG:Data now has 19 columns.
# 04:58:07 DEBUG:Obtaining dqa_has_invalid_date from cache with 221666 rows.
# 04:58:07 DEBUG:Data now has 20 columns.
# 04:58:07 DEBUG:Obtaining dqa_has_invalid_rating from cache with 221666 rows.
# 04:58:07 DEBUG:Data now has 21 columns.
# 04:58:07 DEBUG:Obtaining dqa_contains_email from cache with 221666 rows.
# 04:58:07 DEBUG:Data now has 22 columns.
# 04:58:07 DEBUG:Obtaining dqa_contains_url from cache with 221666 rows.
# 04:58:08 DEBUG:Data now has 23 columns.
# 04:58:08 DEBUG:Obtaining dqa_contains_phone_number from cache with 221666 rows.
# 04:58:08 DEBUG:Data now has 24 columns.
# 04:58:08 DEBUG:Obtaining dqa_has_non_english_review from cache with 221666 rows.
# 04:58:08 DEBUG:Data now has 25 columns.
# 04:58:08 DEBUG:Obtaining dqa_has_non_english_app_name from cache with 221666 rows.
# 04:58:09 DEBUG:Data now has 26 columns.
# 04:58:09 DEBUG:Obtaining dqa_has_profanity from cache with 221666 rows.
# 04:58:09 DEBUG:Data now has 27 columns.
# 04:58:09 DEBUG:Final Data Head:
#             id     index      app_id                       app_name  \
# 0  10000003936   7683930  1405003794                 Naked Training
# 1  10000016967  15434668   282935706                          Bible
# 2  10000065230  11242008  1579079858         Watch Faces Gallery #1
# 3  10000074244  11525009  1470186592  FWB Hookup, Dating for Adults
# 4  10000074478  20808259   504750161        Norton Password Manager
#
#   category_id                author  rating  \
# 0        6013  6489f4655768055fe569       5
# 1        6006  45a4c0229ccc465c70f5       5
# 2        6012  089f098b7761d1c493e7       1
# 3        6012  fffb8f1d4e5126732901       1
# 4        6002  0bc12e16e4c6a442f50b       5
#
#                                              content  vote_sum  vote_count  \
# 0  I have been doing the Naked programming over 2...         0           0
# 1   What a gift! So many options. I use it everyday.         0           0
# 2  Temperature and weather conditions consistentl...         0           0
# 3  So I gave this app a try thinking it looked pr...         0           0
# 4                             Can’t live without it!         0           0
#
#    ... dqa_has_emojis dqa_has_excessive_special_chars  dqa_has_invalid_date  \
# 0  ...          False                           False                 False
# 1  ...          False                           False                 False
# 2  ...          False                           False                 False
# 3  ...           True                           False                 False
# 4  ...          False                           False                 False
#
#    dqa_has_invalid_rating  dqa_contains_email  dqa_contains_url  \
# 0                   False               False             False
# 1                   False               False             False
# 2                   False               False             False
# 3                   False               False             False
# 4                   False               False             False
#
#    dqa_contains_phone_number  dqa_has_non_english_review  \
# 0                      False                       False
# 1                      False                       False
# 2                      False                       False
# 3                      False                       False
# 4                      False                        True
#
#    dqa_has_non_english_app_name  dqa_has_profanity
# 0                         False              False
# 1                         False              False
# 2                         False              False
# 3                         False              False
# 4                          True              False
#
# [5 rows x 27 columns]
# 04:58:09 DEBUG:Final Data Tail:
#                 id     index      app_id                        app_name  \
# 221661  9999888955  12665275   748920931            MyQuest for Patients
# 221662  9999903635   5740259  1058959277        Uber Eats: Food Delivery
# 221663  9999910411  20931525  1368674385                   CSCPay Mobile
# 221664  9999936571   5921334   321560858  Pizza Hut - Delivery & Takeout
# 221665  9999946177  13287898   587366035         Picsart AI Photo Editor
#
#        category_id                author  rating  \
# 221661        6020  161a02a57c66ab51201b       3
# 221662        6023  07ea0baeddeb0b8f43c8       5
# 221663        6002  c0e309f0aa382db2f602       1
# 221664        6023  846bb4790dd429814d3e       1
# 221665        6008  7678b6de26986881abc9       5
#
#                                                   content  vote_sum  \
# 221661  Why isn’t basic Medicare listed as an insuranc...         0
# 221662      Great service!! Love Uber eats!! Fast as well         0
# 221663  Worst app ever, wish my apartment would just s...         1
# 221664  We ended up having to call to order. The glute...         0
# 221665                                         It’s great         0
#
#         vote_count  ... dqa_has_emojis dqa_has_excessive_special_chars  \
# 221661           0  ...          False                           False
# 221662           0  ...          False                           False
# 221663           1  ...          False                           False
# 221664           0  ...          False                           False
# 221665           0  ...          False                           False
#
#         dqa_has_invalid_date  dqa_has_invalid_rating  dqa_contains_email  \
# 221661                 False                   False               False
# 221662                 False                   False               False
# 221663                 False                   False               False
# 221664                 False                   False               False
# 221665                 False                   False               False
#
#         dqa_contains_url  dqa_contains_phone_number  \
# 221661             False                      False
# 221662             False                      False
# 221663             False                      False
# 221664             False                      False
# 221665             False                      False
#
#         dqa_has_non_english_review  dqa_has_non_english_app_name  \
# 221661                       False                         False
# 221662                       False                         False
# 221663                       False                         False
# 221664                       False                         False
# 221665                        True                          True
#
#         dqa_has_profanity
# 221661              False
# 221662              False
# 221663              False
# 221664              False
# 221665              False
#
# [5 rows x 27 columns]
# 04:58:09 DEBUG:Executing WriteTask
# 04:58:09 DEBUG:Writing to data/dev/02_dqa/reviews
# Task DQAFinalizeTask completed successfully. Runtime: 00 Minutes 04.271583 Seconds
# Task WriteTask completed successfully. Runtime: 00 Minutes 00.799485 Seconds
#
#
#                              DataQualityAssessment
#                           Pipeline Start | 2024-06-29 16:58:03.562412
#                            Pipeline Stop | 2024-06-29 16:58:10.165033
#                         Pipeline Runtime | 00 Minutes 06.602621 Seconds
#
#
#
#
# # ============================================================================ #

# %% [markdown]
# Let's get a summary of the data quality issues by type.

# %%
dqa.overview()
# Out:
# 04:58:10 DEBUG:matplotlib data path: /home/john/miniconda3/envs/appinsight/lib/python3.10/site-packages/matplotlib/mpl-data
# 04:58:10 DEBUG:CONFIGDIR=/home/john/.config/matplotlib
# 04:58:10 DEBUG:interactive is False
# 04:58:10 DEBUG:platform is linux
# 04:58:10 DEBUG:CACHEDIR=/home/john/.cache/matplotlib
# 04:58:10 DEBUG:Using fontManager instance from /home/john/.cache/matplotlib/fontlist-v330.json
# <style type="text/css">
# </style>
# <table id="T_6b8c6">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_6b8c6_level0_col0" class="col_heading level0 col0" >Count</th>
#       <th id="T_6b8c6_level0_col1" class="col_heading level0 col1" >Percent</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6b8c6_level0_row0" class="row_heading level0 row0" >dqa_is_duplicate</th>
#       <td id="T_6b8c6_row0_col0" class="data row0 col0" >0</td>
#       <td id="T_6b8c6_row0_col1" class="data row0 col1" >0.00</td>
#     </tr>
#     <tr>
#       <th id="T_6b8c6_level0_row1" class="row_heading level0 row1" >dqa_is_duplicate_review_id</th>
#       <td id="T_6b8c6_row1_col0" class="data row1 col0" >0</td>
#       <td id="T_6b8c6_row1_col1" class="data row1 col1" >0.00</td>
#     </tr>
#     <tr>
#       <th id="T_6b8c6_level0_row2" class="row_heading level0 row2" >dqa_has_null_values</th>
#       <td id="T_6b8c6_row2_col0" class="data row2 col0" >0</td>
#       <td id="T_6b8c6_row2_col1" class="data row2 col1" >0.00</td>
#     </tr>
#     <tr>
#       <th id="T_6b8c6_level0_row3" class="row_heading level0 row3" >dqa_vote_sum_outlier</th>
#       <td id="T_6b8c6_row3_col0" class="data row3 col0" >8,310</td>
#       <td id="T_6b8c6_row3_col1" class="data row3 col1" >3.75</td>
#     </tr>
#     <tr>
#       <th id="T_6b8c6_level0_row4" class="row_heading level0 row4" >dqa_vote_count_outlier</th>
#       <td id="T_6b8c6_row4_col0" class="data row4 col0" >11,011</td>
#       <td id="T_6b8c6_row4_col1" class="data row4 col1" >4.97</td>
#     </tr>
#     <tr>
#       <th id="T_6b8c6_level0_row5" class="row_heading level0 row5" >dqa_has_emojis</th>
#       <td id="T_6b8c6_row5_col0" class="data row5 col0" >10,802</td>
#       <td id="T_6b8c6_row5_col1" class="data row5 col1" >4.87</td>
#     </tr>
#     <tr>
#       <th id="T_6b8c6_level0_row6" class="row_heading level0 row6" >dqa_has_excessive_special_chars</th>
#       <td id="T_6b8c6_row6_col0" class="data row6 col0" >2,545</td>
#       <td id="T_6b8c6_row6_col1" class="data row6 col1" >1.15</td>
#     </tr>
#     <tr>
#       <th id="T_6b8c6_level0_row7" class="row_heading level0 row7" >dqa_has_invalid_date</th>
#       <td id="T_6b8c6_row7_col0" class="data row7 col0" >0</td>
#       <td id="T_6b8c6_row7_col1" class="data row7 col1" >0.00</td>
#     </tr>
#     <tr>
#       <th id="T_6b8c6_level0_row8" class="row_heading level0 row8" >dqa_has_invalid_rating</th>
#       <td id="T_6b8c6_row8_col0" class="data row8 col0" >0</td>
#       <td id="T_6b8c6_row8_col1" class="data row8 col1" >0.00</td>
#     </tr>
#     <tr>
#       <th id="T_6b8c6_level0_row9" class="row_heading level0 row9" >dqa_contains_email</th>
#       <td id="T_6b8c6_row9_col0" class="data row9 col0" >0</td>
#       <td id="T_6b8c6_row9_col1" class="data row9 col1" >0.00</td>
#     </tr>
#     <tr>
#       <th id="T_6b8c6_level0_row10" class="row_heading level0 row10" >dqa_contains_url</th>
#       <td id="T_6b8c6_row10_col0" class="data row10 col0" >2</td>
#       <td id="T_6b8c6_row10_col1" class="data row10 col1" >0.00</td>
#     </tr>
#     <tr>
#       <th id="T_6b8c6_level0_row11" class="row_heading level0 row11" >dqa_contains_phone_number</th>
#       <td id="T_6b8c6_row11_col0" class="data row11 col0" >70</td>
#       <td id="T_6b8c6_row11_col1" class="data row11 col1" >0.03</td>
#     </tr>
#     <tr>
#       <th id="T_6b8c6_level0_row12" class="row_heading level0 row12" >dqa_has_non_english_review</th>
#       <td id="T_6b8c6_row12_col0" class="data row12 col0" >9,153</td>
#       <td id="T_6b8c6_row12_col1" class="data row12 col1" >4.13</td>
#     </tr>
#     <tr>
#       <th id="T_6b8c6_level0_row13" class="row_heading level0 row13" >dqa_has_non_english_app_name</th>
#       <td id="T_6b8c6_row13_col0" class="data row13 col0" >32,968</td>
#       <td id="T_6b8c6_row13_col1" class="data row13 col1" >14.87</td>
#     </tr>
#     <tr>
#       <th id="T_6b8c6_level0_row14" class="row_heading level0 row14" >dqa_has_profanity</th>
#       <td id="T_6b8c6_row14_col0" class="data row14 col0" >2,172</td>
#       <td id="T_6b8c6_row14_col1" class="data row14 col1" >0.98</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## Data Quality Impressions
#
# The data quality assessment (DQA) conducted on the AppVoC dataset revealed several key issues that need to be addressed to ensure the integrity and reliability of the analysis. These issues include:
#
# - **Duplicates**: A small percentage (<1%) have duplicate review ids.
# - **Null Values**: Fortunately, there were no null values detected in the dataset.
# - **Invalid Entries**: There were no invalid dates or invalid ratings found.
# - **Outliers**: Outliers were identified in vote sums, and vote counts which *could* potentially distort analysis results.
# - **Non-English**: A notable proportion of the app names (15%) and review content (4.2%) was flagged for being non-English.
# - **Special Characters**: A small percentage of reviews were noted for the presence of special characters in excessive proportions.
# - **Profanity & Sensitive Information**: Instances of profanity and the presence of email addresses, URLs, or phone numbers were minimal.
#
# Given these findings, the next step is to identify and treat the high-impact data quality issues. This may involve, without limitation:
#
# - **Removing Duplicates**: Eliminating observations with duplicate review IDs.
# - **Handling Outliers**: Identifying and appropriately managing outliers in vote sums, and vote counts.
# - **Addressing Non-English Text**: Filtering or translating non-English reviews.
# - **filtering Noise**: Filtering or removing excessive special characters from reviews.
# - **Ensuring Clean Content**: Censor or remove reviews containing profanity, and personal identifying information such as phone numbers, URLs, and email addresses.
#
# Cue the action!
