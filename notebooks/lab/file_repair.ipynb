# %% [markdown]
# # File Repair

# %%
import pandas as pd

# %%
FILEPATH = "data/ext/review_Utilities.tsv"

# %%
df = pd.read_csv(FILEPATH, sep="\t", lineterminator='\n')
df.head()
# Out:
#                  id      app_id                        app_name  category_id  \
# 2070     1451324857   966121660   Search Track Mobile Number UL         6002
# 17085    8041775917  1363760897              TimeStamp Keyboard         6002
# 17585     748780487   347713516          Paper Calc Office Lite         6002
# 26185     605702393   454337716         Westminster Chimes Full         6002
# 28829    1451324857   966121660   Search Track Mobile Number UL         6002
# ...             ...         ...                             ...          ...
# 3057906   388390808   304221132                          ePrint         6002
# 3058958    77175925   299311457  Sale Price Discount Calculator         6002
# 3063061   686840644   550039208       Direct Remote for DIRECTV         6002
# 3069754   895203517   539607472      Hours & Minutes Calculator         6002
# 3076331   835349615   635621421                  Tally Counters         6002
#
# ...

# %%
df2 = df.loc[:, df.columns != "title"]
sl = []
df2[df2.isna().any(axis=1)].shape[0]
# Out:
# 98

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3086463 entries, 0 to 3086462
# Data columns (total 12 columns):
#  #   Column       Dtype
# ---  ------       -----
#  0   id           int64
#  1   app_id       int64
#  2   app_name     object
#  3   category_id  int64
#  4   category     object
#  5   author       object
#  6   rating       float64
#  7   title        object
#  8   content      object
#  9   vote_sum     int64
#  10  vote_count   int64
#  11  date         object
# dtypes: float64(1), int64(5), object(6)
# memory usage: 282.6+ MB
